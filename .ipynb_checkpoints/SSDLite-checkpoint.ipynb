# %% [markdown]
# ### Dataset Formation

# %%
import os
import torch
import random
import numpy as np
from PIL import Image
from torch.utils.data import Dataset

import torchvision.transforms as T

class MyRatDataset(Dataset):
    """
    A dataset that reads images and YOLO-format annotations from a folder.
    Expected structure:
        root/
          images/
            img1.jpg
            img2.jpg
            ...
          labels/
            img1.txt
            img2.txt
            ...
    Each label file should contain lines (YOLO format):
        class_id  x_center_norm  y_center_norm  width_norm  height_norm
    In this version, we also create negative samples on the fly.
    With a certain probability, we "remove" the rat(s) by filling the bounding box regions with random noise.
    The resulting image is treated as a negative sample (with no bounding boxes).
    """
    def __init__(self, root, transforms=None, negative_sample_ratio=0.3):
        """
        Args:
            root (str): Path to the subset folder (e.g., 'new_dataset/train').
                        Must contain 'images/' and 'labels/' subfolders.
            transforms (callable, optional): Transformations to apply to the PIL image.
            negative_sample_ratio (float): The probability (0 to 1) of generating a negative sample from a positive image.
        """
        self.root = root
        self.transforms = transforms
        self.negative_sample_ratio = negative_sample_ratio
        
        self.img_dir = os.path.join(root, "images")
        self.lbl_dir = os.path.join(root, "labels")
        
        # Collect image file names
        self.imgs = [f for f in os.listdir(self.img_dir)
                     if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
        self.imgs.sort()  # for consistent ordering

    def __len__(self):
        return len(self.imgs)

    def __getitem__(self, idx):
        # Load image
        img_name = self.imgs[idx]
        img_path = os.path.join(self.img_dir, img_name)
        img = Image.open(img_path).convert("RGB")
        w, h = img.size

        # Load annotations from the corresponding label file
        label_name = os.path.splitext(img_name)[0] + ".txt"
        label_path = os.path.join(self.lbl_dir, label_name)
        
        boxes = []
        labels = []
        if os.path.exists(label_path):
            with open(label_path, 'r') as f:
                for line in f:
                    parts = line.strip().split()
                    if len(parts) != 5:
                        continue
                    # YOLO format: class_id, x_center, y_center, width, height (all normalized)
                    class_id = int(parts[0]) + 1
                    x_center_norm = float(parts[1])
                    y_center_norm = float(parts[2])
                    width_norm    = float(parts[3])
                    height_norm   = float(parts[4])
                    
                    # Convert normalized coords to absolute pixel coordinates
                    x_center = x_center_norm * w
                    y_center = y_center_norm * h
                    box_width = width_norm * w
                    box_height = height_norm * h
                    x_min = x_center - box_width / 2
                    y_min = y_center - box_height / 2
                    x_max = x_center + box_width / 2
                    y_max = y_center + box_height / 2
                    boxes.append([x_min, y_min, x_max, y_max])
                    labels.append(class_id)
        
        # If no annotations, treat image as a negative sample naturally
        if len(boxes) == 0:
            boxes = torch.empty((0, 4), dtype=torch.float32)
            labels = torch.empty((0,), dtype=torch.int64)
        else:
            boxes = torch.as_tensor(boxes, dtype=torch.float32)
            labels = torch.as_tensor(labels, dtype=torch.int64)
        
        # Decide whether to generate a negative sample from this image
        # (only if there are boxes, because otherwise it's already negative)
        if boxes.shape[0] > 0 and random.random() < self.negative_sample_ratio:
            # Generate negative sample by filling each bounding box with random noise
            img = self.generate_negative_sample(img, boxes)
            # Set target to have no boxes or labels
            boxes = torch.empty((0, 4), dtype=torch.float32)
            labels = torch.empty((0,), dtype=torch.int64)
        
        image_id = torch.tensor([idx])
        if boxes.size(0) > 0:
            area = (boxes[:,2] - boxes[:,0]) * (boxes[:,3] - boxes[:,1])
        else:
            area = torch.empty((0,), dtype=torch.float32)
        iscrowd = torch.zeros((labels.shape[0],), dtype=torch.int64)
        
        target = {
            "boxes": boxes,
            "labels": labels,
            "image_id": image_id,
            "area": area,
            "iscrowd": iscrowd
        }
        
        if self.transforms:
            img = self.transforms(img)
        
        return img, target

    def generate_negative_sample(self, img, boxes):
        """
        Generate a negative sample by filling the regions of each bounding box in the image with random noise.
        Args:
            img (PIL.Image): The original image.
            boxes (Tensor): Tensor of shape [N, 4] with bounding box coordinates in absolute pixel values.
        Returns:
            PIL.Image: The image with the rat regions replaced with noise.
        """ 
        # Convert PIL image to NumPy array
        img_np = np.array(img)
        # Iterate through each box and fill the region with random noise
        for box in boxes:
            x_min, y_min, x_max, y_max = box.int().tolist()
            # Clip coordinates to image boundaries
            x_min = max(0, x_min)
            y_min = max(0, y_min)
            x_max = min(img_np.shape[1], x_max)
            y_max = min(img_np.shape[0], y_max)
            if x_max > x_min and y_max > y_min:
                noise = np.random.randint(0, 256, (y_max - y_min, x_max - x_min, 3), dtype=np.uint8)
                img_np[y_min:y_max, x_min:x_max, :] = noise
        # Convert back to PIL image
        return Image.fromarray(img_np)

# Example usage
if __name__ == "__main__":
    import torchvision.transforms as T
    
    # Define transforms: converting image to tensor and normalizing
    transforms = T.Compose([
        T.ToTensor(),
        T.Normalize(mean=[0.485, 0.456, 0.406],
                    std=[0.229, 0.224, 0.225])
    ])
    
    # Create dataset instance. Adjust root path as needed.
    dataset_root = "new_dataset\\train"  # Folder with subfolders: images/ and labels/
    dataset = MyRatDataset(root=dataset_root, transforms=transforms, negative_sample_ratio=0.3)
    
    # Optionally, inspect a sample
    img, target = dataset[0]
    print("Sample target:", target)
    
    # Create DataLoader
    from torch.utils.data import DataLoader
    dataloader = DataLoader(dataset, batch_size=4, shuffle=True, collate_fn=lambda batch: tuple(zip(*batch)))
    
    # Iterate over one batch
    for images, targets in dataloader:
        print(f"Batch has {len(images)} images")
        for t in targets:
            print("Boxes:", t["boxes"], "Labels:", t["labels"])
        break
# Out:
# Sample target: {'boxes': tensor([[ 19.0000, 133.2500, 168.0000, 396.7500]]), 'labels': tensor([1]), 'image_id': tensor([0]), 'area': tensor([39261.5000]), 'iscrowd': tensor([0])}
# Batch has 4 images
# Boxes: tensor([[278.0003,  27.9998, 557.0000, 276.9998]]) Labels: tensor([1])
# Boxes: tensor([], size=(0, 4)) Labels: tensor([], dtype=torch.int64)
# Boxes: tensor([], size=(0, 4)) Labels: tensor([], dtype=torch.int64)
# Boxes: tensor([], size=(0, 4)) Labels: tensor([], dtype=torch.int64)

# %%
import os
import torch
import random
import numpy as np
from PIL import Image
from torch.utils.data import Dataset
import torchvision.transforms as T

class MyRatDataset(Dataset):
    """
    A dataset that reads images and YOLO-format annotations from a folder.
    Expected structure:
        root/
          images/
            img1.jpg
            img2.jpg
            ...
          labels/
            img1.txt
            img2.txt
            ...
    Each label file should contain lines (YOLO format):
        class_id  x_center_norm  y_center_norm  width_norm  height_norm
    Negative samples can be created on the fly with a given probability.
    This updated version prints a warning and ignores any image whose label file contains negative values.
    """
    def __init__(self, root, transforms=None, negative_sample_ratio=0.3):
        """
        Args:
            root (str): Path to the subset folder (e.g., 'new_dataset/train').
                        Must contain 'images/' and 'labels/' subfolders.
            transforms (callable, optional): Transformations to apply to the PIL image.
            negative_sample_ratio (float): The probability (0 to 1) of generating a negative sample from a positive image.
        """
        self.root = root
        self.transforms = transforms
        self.negative_sample_ratio = negative_sample_ratio
        
        self.img_dir = os.path.join(root, "images")
        self.lbl_dir = os.path.join(root, "labels")
        
        # Collect image file names
        self.imgs = [f for f in os.listdir(self.img_dir)
                     if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
        self.imgs.sort()  # for consistent ordering

    def __len__(self):
        return len(self.imgs)

    def __getitem__(self, idx):
        # Load image
        img_name = self.imgs[idx]
        img_path = os.path.join(self.img_dir, img_name)
        img = Image.open(img_path).convert("RGB")
        w, h = img.size

        # Load annotations from the corresponding label file
        label_name = os.path.splitext(img_name)[0] + ".txt"
        label_path = os.path.join(self.lbl_dir, label_name)
        
        boxes = []
        labels = []
        corrupt = False  # flag for negative values in the label file
        
        if os.path.exists(label_path):
            with open(label_path, 'r') as f:
                for line in f:
                    parts = line.strip().split()
                    if len(parts) != 5:
                        continue
                    try:
                        class_id = int(parts[0]) + 1  # shift class indices if needed
                        x_center_norm = float(parts[1])
                        y_center_norm = float(parts[2])
                        width_norm    = float(parts[3])
                        height_norm   = float(parts[4])
                    except ValueError:
                        continue

                    # Check for negative values
                    if x_center_norm < 0 or y_center_norm < 0 or width_norm < 0 or height_norm < 0:
                        # print(f"WARNING {img_path}: ignoring corrupt image/label: negative label values "
                        #       f"[{x_center_norm:.5f}, {y_center_norm:.5f}, {width_norm:.5f}, {height_norm:.5f}]")
                        corrupt = True
                        break

                    # Convert normalized coords to absolute pixel coordinates
                    x_center = x_center_norm * w
                    y_center = y_center_norm * h
                    box_width = width_norm * w
                    box_height = height_norm * h
                    x_min = x_center - box_width / 2
                    y_min = y_center - box_height / 2
                    x_max = x_center + box_width / 2
                    y_max = y_center + box_height / 2
                    boxes.append([x_min, y_min, x_max, y_max])
                    labels.append(class_id)
        
        # If corrupt, treat this image as a negative sample (no boxes)
        if corrupt:
            boxes = []
            labels = []

        # If no annotations, treat image as a negative sample naturally
        if len(boxes) == 0:
            boxes = torch.empty((0, 4), dtype=torch.float32)
            labels = torch.empty((0,), dtype=torch.int64)
        else:
            boxes = torch.as_tensor(boxes, dtype=torch.float32)
            labels = torch.as_tensor(labels, dtype=torch.int64)
        
        # Optionally generate a negative sample from a positive image
        if boxes.shape[0] > 0 and random.random() < self.negative_sample_ratio:
            img = self.generate_negative_sample(img, boxes)
            boxes = torch.empty((0, 4), dtype=torch.float32)
            labels = torch.empty((0,), dtype=torch.int64)
        
        image_id = torch.tensor([idx])
        if boxes.size(0) > 0:
            area = (boxes[:,2] - boxes[:,0]) * (boxes[:,3] - boxes[:,1])
        else:
            area = torch.empty((0,), dtype=torch.float32)
        iscrowd = torch.zeros((labels.shape[0],), dtype=torch.int64)
        
        target = {
            "boxes": boxes,
            "labels": labels,
            "image_id": image_id,
            "area": area,
            "iscrowd": iscrowd
        }
        
        if self.transforms:
            img = self.transforms(img)
        
        return img, target

    def generate_negative_sample(self, img, boxes):
        """
        Generate a negative sample by filling the regions of each bounding box in the image with random noise.
        Args:
            img (PIL.Image): The original image.
            boxes (Tensor): Tensor of shape [N, 4] with bounding box coordinates in absolute pixel values.
        Returns:
            PIL.Image: The image with the rat regions replaced with noise.
        """ 
        img_np = np.array(img)
        for box in boxes:
            x_min, y_min, x_max, y_max = box.int().tolist()
            x_min = max(0, x_min)
            y_min = max(0, y_min)
            x_max = min(img_np.shape[1], x_max)
            y_max = min(img_np.shape[0], y_max)
            if x_max > x_min and y_max > y_min:
                noise = np.random.randint(0, 256, (y_max - y_min, x_max - x_min, 3), dtype=np.uint8)
                img_np[y_min:y_max, x_min:x_max, :] = noise
        return Image.fromarray(img_np)

# Example usage:
if __name__ == "__main__":
    transforms = T.Compose([
        T.ToTensor(),
        T.Normalize(mean=[0.485, 0.456, 0.406],
                    std=[0.229, 0.224, 0.225])
    ])
    
    dataset_root = "new_dataset\\train"  # Folder with subfolders: images/ and labels/
    dataset = MyRatDataset(root=dataset_root, transforms=transforms, negative_sample_ratio=0.3)
    
    # Inspect a sample
    img, target = dataset[0]
    print("Sample target:", target)
    
    from torch.utils.data import DataLoader
    dataloader = DataLoader(dataset, batch_size=4, shuffle=True, collate_fn=lambda batch: tuple(zip(*batch)))
    
    for images, targets in dataloader:
        print(f"Batch has {len(images)} images")
        for t in targets:
            print("Boxes:", t["boxes"], "Labels:", t["labels"])
        break
# Out:
# Sample target: {'boxes': tensor([[ 19.0000, 133.2500, 168.0000, 396.7500]]), 'labels': tensor([1]), 'image_id': tensor([0]), 'area': tensor([39261.5000]), 'iscrowd': tensor([0])}
# Batch has 4 images
# Boxes: tensor([[424.0000, 356.9998, 532.9997, 466.9999]]) Labels: tensor([1])
# Boxes: tensor([[240.0003,  -2.0002, 374.0004, 150.9998]]) Labels: tensor([1])
# Boxes: tensor([], size=(0, 4)) Labels: tensor([], dtype=torch.int64)
# Boxes: tensor([[245.0000, 114.9998, 375.0000, 210.9998],
#         [412.0000, 147.9998, 480.0000, 252.9998],
#         [103.0000, 313.9999, 252.0003, 368.9998]]) Labels: tensor([1, 1, 1])

# %%
import matplotlib.pyplot as plt
import numpy as np

def show_negative_samples(dataset, dataset_name="Dataset"):
    print(f"\nShowing negative samples from: {dataset_name}")
    count = 0
    
    for i in range(len(dataset)):
        img, target = dataset[i]
        
        # Check if there are no bounding boxes (i.e., negative sample)
        if target["boxes"].numel() == 0:
            count += 1
            print(f"  Negative sample index: {i}, image file: {dataset.imgs[i]}")
            
            # Convert the tensor image to NumPy for display
            # If your dataset uses normalization, you may want to 'undo' it for visualization
            img_np = img.permute(1, 2, 0).cpu().numpy()  # [H, W, C]
            
            # Optional: undo normalization for better display
            # mean = np.array([0.485, 0.456, 0.406])
            # std = np.array([0.229, 0.224, 0.225])
            # img_np = std * img_np + mean
            # img_np = np.clip(img_np, 0, 1)
            
            plt.figure(figsize=(6, 6))
            plt.imshow(img_np)
            plt.title(f"{dataset_name} Negative Sample idx={i}")
            plt.axis('off')
            plt.show()
    
    print(f"Found {count} negative samples in {dataset_name}.")

# %% [markdown]
# ## Train

# %%
import os
import torch
import torchvision
import torchvision.transforms as T
from torch.utils.data import DataLoader
from torchsummary import summary
from torch.cuda.amp import autocast, GradScaler
from torch.utils.tensorboard import SummaryWriter
from tqdm import tqdm
from torchvision.models.detection import ssdlite320_mobilenet_v3_large, SSDLite320_MobileNet_V3_Large_Weights
from torch.optim.lr_scheduler import StepLR
os.environ["PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION"] = "python"
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"


# Assume your custom dataset class MyRatDataset is defined elsewhere.
# It should return images (PIL Images) and targets (a dict with keys "boxes", "labels", etc.)

# Define transforms: converting image to tensor and normalizing.
transforms = T.Compose([
    T.ToTensor(),
    T.Normalize(mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225])
])

# Create training and validation datasets and dataloaders.
train_dataset = MyRatDataset(root="new_dataset\\train", transforms=transforms, negative_sample_ratio=0.3)#0.3
val_dataset   = MyRatDataset(root="new_dataset\\valid", transforms=transforms, negative_sample_ratio=0.15)#0.0

# %%
# show_negative_samples(train_dataset, "Train")
# show_negative_samples(val_dataset, "Val")

# %%
train_loader = DataLoader(
    train_dataset,
    batch_size=16,
    shuffle=True,
    collate_fn=lambda batch: tuple(zip(*batch))
)

val_loader = DataLoader(
    val_dataset,
    batch_size=16,
    shuffle=False,
    collate_fn=lambda batch: tuple(zip(*batch))
)

# Load the SSDLite model with a pretrained backbone and 2 classes (background and rat)
model = ssdlite320_mobilenet_v3_large(
    weights=None,
    num_classes=2,
    weights_backbone=torchvision.models.MobileNet_V3_Large_Weights.IMAGENET1K_V1
)

# Move model to device
device = torch.device("cuda:0")
model.to(device)

# Define a helper to freeze all BatchNorm layers
def freeze_bn(module):
    if isinstance(module, torch.nn.BatchNorm2d):
        module.eval()
        for param in module.parameters():
            param.requires_grad = False

# Freeze all BN layers in the model.
model.apply(freeze_bn)

# Create optimizer (train only detection head parameters)
optimizer = torch.optim.SGD(
    [p for p in model.parameters() if p.requires_grad],
    lr=0.005,
    #lr=0.00004
    momentum=0.9,
    weight_decay=0.0005
)
scheduler = StepLR(optimizer, step_size=9, gamma=0.1)


# Set up AMP scaler and TensorBoard writer.
scaler = GradScaler()
writer = SummaryWriter(log_dir=r"C:\Machine Learning\Rat Tracking using TensorFlow\runs")

train_losses = []
val_losses = []
train_cls_losses = []
val_cls_losses = []
train_bbox_losses = []
val_bbox_losses = []
num_epochs = 30

# Optionally, print a model summary.
summary(model, input_size=(3, 320, 320))

# -----------------------------
# Training and Validation Loop
# -----------------------------
for epoch in range(num_epochs):
    model.train()  # Set detection head to train mode.
    model.apply(freeze_bn)  # Re-freeze all BN layers.
    
    epoch_train_loss = 0.0
    epoch_train_cls_loss = 0.0
    epoch_train_bbox_loss = 0.0
    
    for images, targets in tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs}", leave=False):
        images = [img.to(device) for img in images]
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
        
        # Filter out samples with empty bounding boxes.
        filtered_images = []
        filtered_targets = []
        for img, tgt in zip(images, targets):
            if tgt["boxes"].numel() > 0:
                filtered_images.append(img)
                filtered_targets.append(tgt)
        
        optimizer.zero_grad()
        with autocast():
            if len(filtered_images) == 0:
                total_loss = torch.tensor(0., device=device, requires_grad=True)
            else:
                loss_dict = model(filtered_images, filtered_targets)
                cls_loss = loss_dict["classification"]
                bbox_loss = loss_dict["bbox_regression"]
                total_loss = cls_loss + bbox_loss
        
        # Only perform backward, optimizer step, and update if loss is nonzero.
        if total_loss.item() != 0:
            scaler.scale(total_loss).backward()
            scaler.step(optimizer)
            scaler.update()
        # Otherwise, skip these steps.
        
        epoch_train_loss += total_loss.item()
        if len(filtered_images) > 0:
            epoch_train_cls_loss += cls_loss.item()
            epoch_train_bbox_loss += bbox_loss.item()
    
    epoch_train_loss /= len(train_loader)
    epoch_train_cls_loss /= len(train_loader)
    epoch_train_bbox_loss /= len(train_loader)
    train_losses.append(epoch_train_loss)
    train_cls_losses.append(epoch_train_cls_loss)
    train_bbox_losses.append(epoch_train_bbox_loss)
    
    writer.add_scalar("Loss/Train/Total", epoch_train_loss, epoch)
    writer.add_scalar("Loss/Train/Class", epoch_train_cls_loss, epoch)
    writer.add_scalar("Loss/Train/BBox", epoch_train_bbox_loss, epoch)
    print(
        f"Epoch {epoch+1}/{num_epochs}: "
        f"Train Total Loss: {epoch_train_loss:.4f}, "
        f"Train cls Loss: {epoch_train_cls_loss:.4f}, "
        f"Train bbox Loss: {epoch_train_bbox_loss:.4f}"
    )
    
    # ------------------
    # Validation Loop
    # ------------------
    model.train()  # SSDLite returns losses only in train mode.
    model.apply(freeze_bn)
    
    epoch_val_loss = 0.0
    epoch_val_cls_loss = 0.0
    epoch_val_bbox_loss = 0.0
    
    with torch.no_grad():
        for images, targets in val_loader:
            images = [img.to(device) for img in images]
            targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
            
            filtered_images = []
            filtered_targets = []
            for img, tgt in zip(images, targets):
                if tgt["boxes"].numel() > 0:
                    filtered_images.append(img)
                    filtered_targets.append(tgt)
            
            if len(filtered_images) == 0:
                total_loss = torch.tensor(0., device=device)
            else:
                loss_dict = model(filtered_images, filtered_targets)
                cls_loss = loss_dict["classification"]
                bbox_loss = loss_dict["bbox_regression"]
                total_loss = cls_loss + bbox_loss
            
            epoch_val_loss += total_loss.item()
            if len(filtered_images) > 0:
                epoch_val_cls_loss += cls_loss.item()
                epoch_val_bbox_loss += bbox_loss.item()
    
    epoch_val_loss /= len(val_loader)
    epoch_val_cls_loss /= len(val_loader)
    epoch_val_bbox_loss /= len(val_loader)
    val_losses.append(epoch_val_loss)
    val_cls_losses.append(epoch_val_cls_loss)
    val_bbox_losses.append(epoch_val_bbox_loss)
    
    writer.add_scalar("Loss/Val/Total", epoch_val_loss, epoch)
    writer.add_scalar("Loss/Val/Class", epoch_val_cls_loss, epoch)
    writer.add_scalar("Loss/Val/BBox", epoch_val_bbox_loss, epoch)
    
    print(
        f"Epoch {epoch+1}/{num_epochs}: "
        f"Val Total Loss: {epoch_val_loss:.4f}, "
        f"Val cls Loss: {epoch_val_cls_loss:.4f}, "
        f"Val bbox Loss: {epoch_val_bbox_loss:.4f}"
    )

    # scheduler.step()

# Save the trained SSDLite model weights.
save_path = "Model.pth"
torch.save(model.state_dict(), save_path)
print(f"Model saved to {save_path}")
# Out:
# C:\Users\mzarrar\AppData\Local\Temp\ipykernel_4328\3198078346.py:48: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# ===========================================================================
# Layer (type:depth-idx)                             Param #
# ===========================================================================
# ├─SSDLiteFeatureExtractorMobileNet: 1-1            --
# |    └─Sequential: 2-1                             --
# |    |    └─Sequential: 3-1                        (869,096)
# |    |    └─Sequential: 3-2                        (2,102,856)
# |    └─ModuleList: 2-2                             --
# |    |    └─Sequential: 3-3                        (381,184)
# |    |    └─Sequential: 3-4                        (100,480)
# |    |    └─Sequential: 3-5                        (67,712)
# |    |    └─Sequential: 3-6                        (25,664)
# ├─DefaultBoxGenerator: 1-2                         --
# ├─SSDLiteHead: 1-3                                 --
# |    └─SSDLiteClassificationHead: 2-3              --
# |    |    └─ModuleList: 3-7                        (64,104)
# |    └─SSDLiteRegressionHead: 2-4                  --
# |    |    └─ModuleList: 3-8                        (97,584)
# ├─GeneralizedRCNNTransform: 1-4                    --
# ===========================================================================
# Total params: 3,708,680
# Trainable params: 0
# Non-trainable params: 3,708,680
# ===========================================================================
# Epoch 1/30:   0%|          | 0/66 [00:00<?, ?it/s]C:\Users\mzarrar\AppData\Local\Temp\ipykernel_4328\3198078346.py:86: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch 1/30:  12%|█▏        | 8/66 [00:54<02:19,  2.41s/it]

# %%
### PLot
import csv

# Save losses to a CSV file
csv_file = "losses.csv"
with open(csv_file, "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["Epoch", "Train Loss", "Train cls Loss", "Train bbox Loss", "Val Loss", "Val cls Loss", "Val bbox Loss",])
    for epoch, t_loss, t_cls, t_bbox, v_loss, v_cls, v_bbox in zip(range(1, num_epochs + 1), train_losses, train_cls_losses, train_bbox_losses, val_losses, val_cls_losses, val_bbox_losses):
        writer.writerow([epoch, t_loss, t_cls, t_bbox, v_loss, v_cls, v_bbox])
print(f"Losses saved to {csv_file}")
# Out:
# Losses saved to losses.csv

# %%
import csv
import matplotlib.pyplot as plt

epochs = []
train_cls_losses = []
val_cls_losses = []
train_bbox_losses = []
val_bbox_losses = []

# Load data from the CSV file
with open("losses.csv", "r") as f:
    reader = csv.DictReader(f)
    for row in reader:
        epochs.append(int(row["Epoch"]))
        train_cls_losses.append(float(row["Train cls Loss"]))
        val_cls_losses.append(float(row["Val cls Loss"]))
        train_bbox_losses.append(float(row["Train bbox Loss"]))
        val_bbox_losses.append(float(row["Val bbox Loss"]))

# Plot the loss curves with consistent colors and line styles
cls_color = 'blue'
bbox_color = 'red'

plt.plot(epochs, train_cls_losses, color=cls_color, linestyle='-', label="Train CLS Loss")
plt.plot(epochs, val_cls_losses, color=cls_color, linestyle=':', label="Val CLS Loss")
plt.plot(epochs, train_bbox_losses, color=bbox_color, linestyle='-', label="Train BBOX Loss")
plt.plot(epochs, val_bbox_losses, color=bbox_color, linestyle=':', label="Val BBOX Loss")

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training and Validation Loss")
plt.legend()
plt.show()

# %%
import os
import random
import cv2
import numpy as np
from PIL import Image
import torch

# Example predict function (as provided)
def predict(image_path, model, device, threshold=0.7):
    # Load image using PIL
    img = Image.open(image_path).convert("RGB")
    orig_img = np.array(img)  # This will be in RGB format
    # Apply transforms (assume transforms is defined globally)
    img_tensor = transforms(img).to(device)
    img_tensor = img_tensor.unsqueeze(0)
    
    model.eval()
    with torch.no_grad():
        outputs = model(img_tensor)
    output = outputs[0]
    boxes = output['boxes'].cpu().numpy()
    scores = output['scores'].cpu().numpy()
    labels = output['labels'].cpu().numpy()
    
    # Filter out detections below threshold
    keep = scores >= threshold
    boxes = boxes[keep]
    scores = scores[keep]
    labels = labels[keep]
    return orig_img, boxes, scores, labels

# Define your transforms if not already defined.
transforms = T.Compose([
    T.ToTensor(),
    T.Normalize(mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225])
])

# Assume model and device are defined and loaded elsewhere.
# For example:
# device = torch.device("cuda:0")
# model = <your model loaded on device>

# Directory with test images
test_images_dir = "new_dataset/valid/images"  # change this to your actual test images directory

# Get list of image files (supporting common image extensions)
image_files = [f for f in os.listdir(test_images_dir) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
if len(image_files) == 0:
    print("No image files found in", test_images_dir)
    exit()

# Randomly select an image file
selected_file = random.choice(image_files)
image_path = os.path.join(test_images_dir, selected_file)
print("Selected image:", image_path)

# Run the predict function on the selected image
orig_img, boxes, scores, labels = predict(image_path, model, device, threshold=0.7)

# Draw bounding boxes on the original image.
# Note: orig_img is in RGB, convert to BGR for cv2.imshow.
img_bgr = cv2.cvtColor(orig_img, cv2.COLOR_RGB2BGR)

for box, score, label in zip(boxes, scores, labels):
    x1, y1, x2, y2 = box.astype(int)
    cv2.rectangle(img_bgr, (x1, y1), (x2, y2), (0, 255, 0), 2)
    cv2.putText(img_bgr, f"ID:{label} {score:.2f}", (x1, y1 - 10),
                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

# Display the image
cv2.imshow("Test Image with Bounding Boxes", img_bgr)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Selected image: new_dataset/valid/images\20200507080137_000828_jpg.rf.99e3ae845faa3b01c22671f77897b9f6.jpg

# %% [markdown]
# ### Video Detection

# %%
import cv2
import torch
import torchvision
import torchvision.transforms as T
import numpy as np
from PIL import Image
from torchvision.models.detection import ssdlite320_mobilenet_v3_large, SSDLite320_MobileNet_V3_Large_Weights

# Define the transform (same as during training)
transform = T.Compose([
    T.ToTensor(),
    T.Normalize(mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225])
])

device = torch.device("cuda")

# Load and modify the detection model
model = ssdlite320_mobilenet_v3_large(
    weights=None,
    num_classes=2
)
model.to(device)

# Load saved weights
model_path = r"C:\Machine Learning\Rat Tracking using TensorFlow\Model.pth"
model.load_state_dict(torch.load(model_path, map_location=device))
model.eval()

def predict(image_input, model, device, threshold=0.7, nms_threshold=0.3, top_k=1):
    """
    Predict detections on a given image.
    
    Args:
        image_input (str or np.ndarray): If string, treated as file path;
                                           if np.ndarray, treated as an OpenCV BGR image.
        model: The detection model.
        device: Computation device.
        threshold (float): Confidence threshold.
        nms_threshold (float): IoU threshold for non-maximum suppression.
        top_k (int): Number of top detections to display.
    
    Returns:
        orig_img (np.ndarray): The original image in BGR format.
        boxes (np.ndarray): Array of bounding boxes.
        scores (np.ndarray): Detection scores.
        labels (np.ndarray): Detected labels.
        inference_time_ms (float): Inference time in milliseconds.
    """
    # Check input type and convert accordingly
    if isinstance(image_input, np.ndarray):
        # image_input is a frame (BGR)
        pil_img = Image.fromarray(cv2.cvtColor(image_input, cv2.COLOR_BGR2RGB))
        orig_img = image_input.copy()  # keep a copy in BGR for display
    elif isinstance(image_input, str):
        pil_img = Image.open(image_input).convert("RGB")
        orig_img = cv2.cvtColor(np.array(pil_img), cv2.COLOR_RGB2BGR)
    else:
        raise ValueError("Unsupported type for image_input. Must be str or np.ndarray.")
    
    # Apply transforms to create a tensor
    img_tensor = transform(pil_img).to(device)
    img_tensor = img_tensor.unsqueeze(0)  # add batch dimension

    # Measure inference time using OpenCV ticks
    start = cv2.getTickCount()
    with torch.no_grad():
        outputs = model(img_tensor)
    end = cv2.getTickCount()
    inference_time_ms = (end - start) / cv2.getTickFrequency() * 1000.0

    output = outputs[0]
    boxes = output['boxes'].cpu().numpy()
    scores = output['scores'].cpu().numpy()
    labels = output['labels'].cpu().numpy()

    # Filter out detections below confidence threshold
    keep = scores >= threshold
    boxes = boxes[keep]
    scores = scores[keep]
    labels = labels[keep]

    if len(boxes) > 0:
        # Optionally, apply non-maximum suppression (NMS)
        if nms_threshold > 0:
            boxes_tensor = torch.tensor(boxes, device=device)
            scores_tensor = torch.tensor(scores, device=device)
            labels_tensor = torch.tensor(labels, device=device)
            keep_indices = torchvision.ops.nms(boxes_tensor, scores_tensor, nms_threshold)
            keep_indices = keep_indices.cpu().numpy()
            boxes = boxes_tensor[keep_indices].cpu().numpy()
            scores = scores_tensor[keep_indices].cpu().numpy()
            labels = labels_tensor[keep_indices].cpu().numpy()

        # Select top_k detections based on scores
        k = min(top_k, len(scores))
        sorted_indices = np.argsort(scores)[::-1][:k]
        boxes = boxes[sorted_indices]
        scores = scores[sorted_indices]
        labels = labels[sorted_indices]

    return orig_img, boxes, scores, labels, inference_time_ms

def main():
    # Choose one of your video files
    # video_path = r"C:\Machine Learning\Rat Tracking using TensorFlow\Video\3_Mice.mp4"
    # video_path = r"C:\Machine Learning\Rat Tracking using TensorFlow\Video\TestFile_video.mp4"
    # video_path = r"C:\Machine Learning\Rat Tracking using TensorFlow\Video\Cohort_1.mp4"
    video_path = r"C:\Machine Learning\Rat Tracking using TensorFlow\Video\random_youtube_video.mp4"
    # video_path = r"C:\Machine Learning\Rat Tracking using TensorFlow\Video\brown_rats.mp4"
    # video_path = r"C:\Machine Learning\Rat Tracking using TensorFlow\Video\BaselineDark.mp4"
    top_k = 4
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"Error opening video file: {video_path}")
        return

    frame_count = 0  # Initialize a frame counter

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        frame_count += 1  # Increment the frame counter
        
        # Predict on the current frame
        orig_img, boxes, scores, labels, inf_time = predict(
            frame, model, device, threshold=0.2, nms_threshold=0.8, top_k=top_k)
        print("Labels:", labels)
        print("Inference time (ms):", inf_time)

        # Draw bounding boxes, label text, and centroid red dot on the frame
        for box, score, label in zip(boxes, scores, labels):
            x1, y1, x2, y2 = box.astype(int)
            cv2.rectangle(orig_img, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(orig_img, f"Rat: {score:.2f}", (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
            # Compute and draw the centroid as a red dot
            cx = (x1 + x2) // 2
            cy = (y1 + y2) // 2
            cv2.circle(orig_img, (cx, cy), 3, (0, 0, 255), -1)
        
        # Draw inference time on the frame
        cv2.putText(orig_img, f"Inference: {inf_time:.1f} ms", (10, 30),
                    cv2.FONT_HERSHEY_SIMPLEX, 1.0, (0, 255, 255), 2)
        
        # Display the frame number (e.g., at the top left corner)
        cv2.putText(orig_img, f"Frame: {frame_count}", (10, 60),
                    cv2.FONT_HERSHEY_SIMPLEX, 1.0, (255, 0, 0), 2)
        
        # Display the frame with predictions
        cv2.imshow("Predictions", orig_img)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    main()
# Out:
# Labels: []
# Inference time (ms): 21.216700000000003
# Labels: []
# Inference time (ms): 35.8599
# Labels: []
# Inference time (ms): 24.4611
# Labels: []
# Inference time (ms): 25.9098
# Labels: []
# Inference time (ms): 27.5682
# Labels: []
# Inference time (ms): 22.3707
# Labels: []
# Inference time (ms): 23.977999999999998
# Labels: []
# Inference time (ms): 27.9437
# Labels: []
# Inference time (ms): 25.8488
# Labels: []
# Inference time (ms): 26.7088
# Labels: []
# Inference time (ms): 23.066699999999997
# Labels: []
# Inference time (ms): 21.5511
# Labels: []
# Inference time (ms): 21.5874
# Labels: []
# Inference time (ms): 22.1871
# Labels: []
# Inference time (ms): 22.8266
# Labels: []
# Inference time (ms): 22.6105
# Labels: []
# Inference time (ms): 21.9295
# Labels: []
# Inference time (ms): 21.8836
# Labels: []
# Inference time (ms): 22.1967
# Labels: []
# Inference time (ms): 21.9042
# Labels: []
# Inference time (ms): 21.5095
# Labels: []
# Inference time (ms): 21.0902
# Labels: []
# Inference time (ms): 23.0363
# Labels: []
# Inference time (ms): 23.157799999999998
# Labels: []
# Inference time (ms): 22.2703
# Labels: []
# Inference time (ms): 21.2859
# Labels: []
# Inference time (ms): 21.2873
# Labels: []
# Inference time (ms): 21.4981
# Labels: []
# Inference time (ms): 21.5444
# Labels: []
# Inference time (ms): 22.264200000000002
# Labels: []
# Inference time (ms): 21.4076
# Labels: []
# Inference time (ms): 21.0808
# Labels: []
# Inference time (ms): 20.598499999999998
# Labels: []
# Inference time (ms): 21.4314
# Labels: []
# Inference time (ms): 21.1292
# Labels: []
# Inference time (ms): 20.8339
# Labels: []
# Inference time (ms): 20.918699999999998
# Labels: []
# Inference time (ms): 22.043
# Labels: []
# Inference time (ms): 22.4205
# Labels: []
# Inference time (ms): 21.083299999999998
# Labels: []
# Inference time (ms): 24.0385
# Labels: []
# Inference time (ms): 20.9646
# Labels: []
# Inference time (ms): 21.5078
# Labels: []
# Inference time (ms): 21.6022
# Labels: []
# Inference time (ms): 20.203
# Labels: []
# Inference time (ms): 21.3227
# Labels: []
# Inference time (ms): 21.2025
# Labels: []
# Inference time (ms): 20.8353
# Labels: []
# Inference time (ms): 21.6271
# Labels: []
# Inference time (ms): 21.819000000000003
# Labels: []
# Inference time (ms): 20.8616
# Labels: []
# Inference time (ms): 21.4407
# Labels: []
# Inference time (ms): 21.036099999999998
# Labels: []
# Inference time (ms): 21.9638
# Labels: []
# Inference time (ms): 21.9301
# Labels: []
# Inference time (ms): 21.373
# Labels: []
# Inference time (ms): 20.8979
# Labels: []
# Inference time (ms): 21.123099999999997
# Labels: []
# Inference time (ms): 22.0057
# Labels: []
# Inference time (ms): 21.2597
# Labels: []
# Inference time (ms): 21.3969
# Labels: []
# Inference time (ms): 21.1344
# Labels: []
# Inference time (ms): 21.2012
# Labels: []
# Inference time (ms): 25.2501
# Labels: []
# Inference time (ms): 21.230800000000002
# Labels: []
# Inference time (ms): 20.984099999999998
# Labels: []
# Inference time (ms): 21.5164
# Labels: []
# Inference time (ms): 21.0651
# Labels: []
# Inference time (ms): 20.2262
# Labels: []
# Inference time (ms): 21.4666
# Labels: []
# Inference time (ms): 21.287899999999997
# Labels: []
# Inference time (ms): 20.967699999999997
# Labels: []
# Inference time (ms): 20.637
# Labels: []
# Inference time (ms): 23.1615
# Labels: []
# Inference time (ms): 21.7177
# Labels: []
# Inference time (ms): 21.2181
# Labels: []
# Inference time (ms): 20.7713
# Labels: []
# Inference time (ms): 21.2942
# Labels: []
# Inference time (ms): 25.4127
# Labels: []
# Inference time (ms): 21.028000000000002
# Labels: []
# Inference time (ms): 20.266099999999998
# Labels: []
# Inference time (ms): 20.7617
# Labels: []
# Inference time (ms): 20.3078
# Labels: []
# Inference time (ms): 21.5686
# Labels: []
# Inference time (ms): 20.828
# Labels: []
# Inference time (ms): 21.0609
# Labels: []
# Inference time (ms): 21.017500000000002
# Labels: []
# Inference time (ms): 20.3912
# Labels: []
# Inference time (ms): 21.7026
# Labels: []
# Inference time (ms): 20.939
# Labels: []
# Inference time (ms): 20.5502
# Labels: []
# Inference time (ms): 20.763299999999997
# Labels: []
# Inference time (ms): 20.617
# Labels: []
# Inference time (ms): 21.118100000000002
# Labels: []
# Inference time (ms): 21.1
# Labels: []
# Inference time (ms): 22.1048
# Labels: []
# Inference time (ms): 20.8542
# Labels: []
# Inference time (ms): 20.674000000000003
# Labels: []
# Inference time (ms): 20.4439
# Labels: []
# Inference time (ms): 20.9045
# Labels: []
# Inference time (ms): 21.1544
# Labels: []
# Inference time (ms): 20.695999999999998
# Labels: []
# Inference time (ms): 21.2436
# Labels: []
# Inference time (ms): 21.7673
# Labels: []
# Inference time (ms): 20.960199999999997
# Labels: []
# Inference time (ms): 20.5871
# Labels: []
# Inference time (ms): 20.4767
# Labels: []
# Inference time (ms): 20.7352
# Labels: []
# Inference time (ms): 21.227
# Labels: []
# Inference time (ms): 23.9901
# Labels: []
# Inference time (ms): 20.2583
# Labels: []
# Inference time (ms): 21.4421
# Labels: []
# Inference time (ms): 21.0611
# Labels: []
# Inference time (ms): 21.0656
# Labels: []
# Inference time (ms): 21.3992
# Labels: []
# Inference time (ms): 21.4327
# Labels: []
# Inference time (ms): 20.855800000000002
# Labels: []
# Inference time (ms): 20.596
# Labels: []
# Inference time (ms): 20.983600000000003
# Labels: []
# Inference time (ms): 21.6685
# Labels: []
# Inference time (ms): 21.4127
# Labels: []
# Inference time (ms): 20.798299999999998
# Labels: []
# Inference time (ms): 21.585
# Labels: []
# Inference time (ms): 21.791700000000002
# Labels: []
# Inference time (ms): 21.005200000000002
# Labels: []
# Inference time (ms): 20.342
# Labels: []
# Inference time (ms): 21.518
# Labels: []
# Inference time (ms): 20.965799999999998
# Labels: []
# Inference time (ms): 21.0424
# Labels: []
# Inference time (ms): 21.1334
# Labels: []
# Inference time (ms): 21.3899
# Labels: []
# Inference time (ms): 21.0103
# Labels: []
# Inference time (ms): 24.174500000000002
# Labels: []
# Inference time (ms): 21.765900000000002
# Labels: []
# Inference time (ms): 21.1063
# Labels: []
# Inference time (ms): 20.873800000000003
# Labels: []
# Inference time (ms): 20.3032
# Labels: []
# Inference time (ms): 21.6473
# Labels: []
# Inference time (ms): 21.113500000000002
# Labels: []
# Inference time (ms): 20.7984
# Labels: []
# Inference time (ms): 20.7898
# Labels: []
# Inference time (ms): 20.9401
# Labels: []
# Inference time (ms): 21.0637
# Labels: []
# Inference time (ms): 21.228199999999998
# Labels: []
# Inference time (ms): 20.9362
# Labels: []
# Inference time (ms): 21.6577
# Labels: []
# Inference time (ms): 20.6846
# Labels: []
# Inference time (ms): 20.8158
# Labels: []
# Inference time (ms): 20.397599999999997
# Labels: []
# Inference time (ms): 20.752799999999997
# Labels: []
# Inference time (ms): 20.7228
# Labels: []
# Inference time (ms): 20.2804
# Labels: []
# Inference time (ms): 21.7855
# Labels: []
# Inference time (ms): 21.5717
# Labels: []
# Inference time (ms): 20.7892
# Labels: []
# Inference time (ms): 20.775100000000002
# Labels: []
# Inference time (ms): 21.6042
# Labels: []
# Inference time (ms): 21.1638
# Labels: []
# Inference time (ms): 20.597399999999997
# Labels: []
# Inference time (ms): 21.343
# Labels: []
# Inference time (ms): 20.919900000000002
# Labels: []
# Inference time (ms): 20.4603
# Labels: []
# Inference time (ms): 20.591
# Labels: []
# Inference time (ms): 20.8847
# Labels: []
# Inference time (ms): 20.485699999999998
# Labels: []
# Inference time (ms): 21.3149
# Labels: []
# Inference time (ms): 20.8678
# Labels: []
# Inference time (ms): 20.9435
# Labels: []
# Inference time (ms): 20.7742
# Labels: []
# Inference time (ms): 21.3509
# Labels: []
# Inference time (ms): 20.9949
# Labels: []
# Inference time (ms): 20.7074
# Labels: []
# Inference time (ms): 21.0691
# Labels: [1]
# Inference time (ms): 21.5942
# Labels: []
# Inference time (ms): 21.3494
# Labels: []
# Inference time (ms): 21.068099999999998
# Labels: []
# Inference time (ms): 20.800900000000002
# Labels: []
# Inference time (ms): 20.505599999999998
# Labels: [1]
# Inference time (ms): 22.829700000000003
# Labels: []
# Inference time (ms): 20.8505
# Labels: []
# Inference time (ms): 20.6026
# Labels: []
# Inference time (ms): 21.651699999999998
# Labels: []
# Inference time (ms): 20.8866
# Labels: [1]
# Inference time (ms): 21.7134
# Labels: [1]
# Inference time (ms): 20.5079
# Labels: [1]
# Inference time (ms): 20.8817
# Labels: [1]
# Inference time (ms): 21.4345
# Labels: [1 1]
# Inference time (ms): 20.7027
# Labels: []
# Inference time (ms): 21.6972
# Labels: []
# Inference time (ms): 21.6159
# Labels: []
# Inference time (ms): 21.038700000000002
# Labels: [1]
# Inference time (ms): 20.683500000000002
# Labels: [1]
# Inference time (ms): 21.75
# Labels: []
# Inference time (ms): 21.9285
# Labels: []
# Inference time (ms): 21.0247
# Labels: [1]
# Inference time (ms): 20.892500000000002
# Labels: []
# Inference time (ms): 20.4616
# Labels: []
# Inference time (ms): 20.9155
# Labels: []
# Inference time (ms): 23.0943
# Labels: []
# Inference time (ms): 20.950300000000002
# Labels: []
# Inference time (ms): 20.6316
# Labels: []
# Inference time (ms): 21.580599999999997
# Labels: []
# Inference time (ms): 20.9119
# Labels: []
# Inference time (ms): 22.3498
# Labels: []
# Inference time (ms): 20.6942
# Labels: []
# Inference time (ms): 21.548000000000002
# Labels: []
# Inference time (ms): 20.999899999999997
# Labels: []
# Inference time (ms): 20.4636
# Labels: []
# Inference time (ms): 24.7816
# Labels: [1 1]
# Inference time (ms): 30.1589
# Labels: [1]
# Inference time (ms): 20.5164
# Labels: [1 1]
# Inference time (ms): 20.613200000000003
# Labels: [1 1 1]
# Inference time (ms): 20.4803
# Labels: [1]
# Inference time (ms): 21.255300000000002
# Labels: [1]
# Inference time (ms): 20.0936
# Labels: [1]
# Inference time (ms): 20.57
# Labels: [1]
# Inference time (ms): 20.1341
# Labels: []
# Inference time (ms): 20.9039
# Labels: [1]
# Inference time (ms): 20.5155
# Labels: [1 1]
# Inference time (ms): 20.8856
# Labels: []
# Inference time (ms): 20.4838
# Labels: [1]
# Inference time (ms): 20.641199999999998
# Labels: []
# Inference time (ms): 21.3661
# Labels: []
# Inference time (ms): 20.6013
# Labels: [1 1]
# Inference time (ms): 20.5607
# Labels: [1 1]
# Inference time (ms): 20.3959
# Labels: []
# Inference time (ms): 20.8399
# Labels: [1]
# Inference time (ms): 22.556199999999997
# Labels: [1]
# Inference time (ms): 20.7175
# Labels: [1 1 1 1]
# Inference time (ms): 20.3649
# Labels: [1]
# Inference time (ms): 20.5152
# Labels: []
# Inference time (ms): 20.6578
# Labels: [1 1]
# Inference time (ms): 21.919500000000003
# Labels: []
# Inference time (ms): 20.558799999999998
# Labels: [1]
# Inference time (ms): 20.5738
# Labels: [1]
# Inference time (ms): 20.718500000000002
# Labels: []
# Inference time (ms): 20.5873
# Labels: [1]
# Inference time (ms): 21.7503
# Labels: []
# Inference time (ms): 20.2151
# Labels: [1]
# Inference time (ms): 20.380599999999998
# Labels: []
# Inference time (ms): 20.8081
# Labels: [1]
# Inference time (ms): 20.3686
# Labels: []
# Inference time (ms): 22.7132
# Labels: []
# Inference time (ms): 20.7756
# Labels: []
# Inference time (ms): 20.6316
# Labels: []
# Inference time (ms): 21.259400000000003
# Labels: []
# Inference time (ms): 20.7494
# Labels: []
# Inference time (ms): 25.751
# Labels: []
# Inference time (ms): 20.5292
# Labels: []
# Inference time (ms): 20.5062
# Labels: []
# Inference time (ms): 20.5696
# Labels: [1]
# Inference time (ms): 20.4518
# Labels: []
# Inference time (ms): 22.1875
# Labels: [1]
# Inference time (ms): 20.2714
# Labels: [1 1]
# Inference time (ms): 20.842699999999997
# Labels: []
# Inference time (ms): 20.5473
# Labels: []
# Inference time (ms): 20.8281
# Labels: [1]
# Inference time (ms): 21.1567
# Labels: [1]
# Inference time (ms): 20.7143
# Labels: [1]
# Inference time (ms): 20.8437
# Labels: []
# Inference time (ms): 23.9668
# Labels: []
# Inference time (ms): 20.5778
# Labels: [1]
# Inference time (ms): 21.7475
# Labels: [1]
# Inference time (ms): 20.6876
# Labels: [1]
# Inference time (ms): 20.697400000000002
# Labels: [1]
# Inference time (ms): 20.4269
# Labels: [1]
# Inference time (ms): 20.851000000000003
# Labels: []
# Inference time (ms): 21.794999999999998
# Labels: []
# Inference time (ms): 20.3981
# Labels: [1]
# Inference time (ms): 20.6874
# Labels: [1]
# Inference time (ms): 19.9923
# Labels: [1]
# Inference time (ms): 21.075400000000002
# Labels: [1]
# Inference time (ms): 21.9102
# Labels: [1]
# Inference time (ms): 20.7065
# Labels: [1 1]
# Inference time (ms): 20.7665
# Labels: [1 1]
# Inference time (ms): 20.6203
# Labels: [1]
# Inference time (ms): 20.971400000000003
# Labels: [1 1]
# Inference time (ms): 20.7812
# Labels: [1]
# Inference time (ms): 20.2591
# Labels: []
# Inference time (ms): 20.692999999999998
# Labels: [1]
# Inference time (ms): 20.997700000000002
# Labels: [1 1]
# Inference time (ms): 20.462899999999998
# Labels: [1]
# Inference time (ms): 23.007900000000003
# Labels: [1 1]
# Inference time (ms): 20.3548
# Labels: []
# Inference time (ms): 20.5964
# Labels: [1]
# Inference time (ms): 20.94
# Labels: [1 1 1 1]
# Inference time (ms): 20.542
# Labels: []
# Inference time (ms): 21.621000000000002
# Labels: []
# Inference time (ms): 21.211399999999998
# Labels: []
# Inference time (ms): 20.9661
# Labels: []
# Inference time (ms): 20.2849
# Labels: [1]
# Inference time (ms): 20.5841
# Labels: [1]
# Inference time (ms): 21.0963
# Labels: [1]
# Inference time (ms): 20.4783
# Labels: [1]
# Inference time (ms): 20.880200000000002
# Labels: []
# Inference time (ms): 20.4198
# Labels: []
# Inference time (ms): 20.296499999999998
# Labels: []
# Inference time (ms): 20.7497
# Labels: [1 1 1]
# Inference time (ms): 21.5799
# Labels: [1 1 1]
# Inference time (ms): 20.6122
# Labels: [1]
# Inference time (ms): 20.4014
# Labels: [1 1]
# Inference time (ms): 20.6189
# Labels: [1 1]
# Inference time (ms): 20.7905
# Labels: [1]
# Inference time (ms): 21.2045
# Labels: [1]
# Inference time (ms): 20.8186
# Labels: [1 1]
# Inference time (ms): 20.5418
# Labels: [1 1]
# Inference time (ms): 21.0854
# Labels: [1 1 1 1]
# Inference time (ms): 20.9362
# Labels: [1 1]
# Inference time (ms): 21.081599999999998
# Labels: [1 1 1]
# Inference time (ms): 20.4205
# Labels: [1 1 1]
# Inference time (ms): 20.671100000000003
# Labels: [1 1 1 1]
# Inference time (ms): 20.497899999999998
# Labels: [1 1 1 1]
# Inference time (ms): 21.5535
# Labels: [1 1 1 1]
# Inference time (ms): 20.4407
# Labels: [1 1 1 1]
# Inference time (ms): 20.9966
# Labels: [1 1 1]
# Inference time (ms): 20.663
# Labels: [1 1 1 1]
# Inference time (ms): 20.7964
# Labels: [1 1]
# Inference time (ms): 20.8171
# Labels: [1 1]
# Inference time (ms): 20.52
# Labels: [1 1]
# Inference time (ms): 21.1317
# Labels: [1 1 1]
# Inference time (ms): 20.796200000000002
# Labels: [1 1 1 1]
# Inference time (ms): 21.0217
# Labels: [1 1 1]
# Inference time (ms): 23.2452
# Labels: [1 1 1]
# Inference time (ms): 20.5494
# Labels: [1 1 1]
# Inference time (ms): 20.3121
# Labels: [1 1 1 1]
# Inference time (ms): 20.849
# Labels: [1 1 1 1]
# Inference time (ms): 20.610599999999998
# Labels: [1 1 1 1]
# Inference time (ms): 21.2288
# Labels: [1 1 1 1]
# Inference time (ms): 20.3319
# Labels: [1 1 1]
# Inference time (ms): 20.703699999999998
# Labels: [1 1 1 1]
# Inference time (ms): 21.0535
# Labels: [1 1 1]
# Inference time (ms): 21.6545
# Labels: [1 1]
# Inference time (ms): 20.9911
# Labels: [1 1 1]
# Inference time (ms): 20.2891
# Labels: [1 1]
# Inference time (ms): 20.747600000000002
# Labels: [1 1 1 1]
# Inference time (ms): 20.9172
# Labels: [1 1 1]
# Inference time (ms): 20.6946
# Labels: [1 1 1]
# Inference time (ms): 21.133599999999998
# Labels: [1 1 1]
# Inference time (ms): 20.386499999999998
# Labels: [1 1 1 1]
# Inference time (ms): 20.6527
# Labels: [1 1 1 1]
# Inference time (ms): 20.6207
# Labels: [1 1 1]
# Inference time (ms): 20.482400000000002
# Labels: [1 1 1]
# Inference time (ms): 25.862199999999998
# Labels: [1 1 1 1]
# Inference time (ms): 20.915599999999998
# Labels: [1 1 1 1]
# Inference time (ms): 20.8417
# Labels: [1 1]
# Inference time (ms): 20.3276
# Labels: [1 1]
# Inference time (ms): 20.5615
# Labels: [1 1 1]
# Inference time (ms): 20.9998
# Labels: [1 1]
# Inference time (ms): 20.495800000000003
# Labels: [1]
# Inference time (ms): 20.953300000000002
# Labels: [1 1]
# Inference time (ms): 20.4895
# Labels: [1 1]
# Inference time (ms): 20.6687
# Labels: [1 1 1 1]
# Inference time (ms): 24.8809
# Labels: [1 1]
# Inference time (ms): 20.5861
# Labels: [1 1]
# Inference time (ms): 20.3551
# Labels: [1 1]
# Inference time (ms): 20.7562
# Labels: [1 1]
# Inference time (ms): 20.6689
# Labels: [1 1 1 1]
# Inference time (ms): 21.239500000000003
# Labels: [1]
# Inference time (ms): 20.1863
# Labels: [1]
# Inference time (ms): 21.1698
# Labels: [1 1]
# Inference time (ms): 20.28
# Labels: [1]
# Inference time (ms): 20.4243
# Labels: [1 1]
# Inference time (ms): 20.9201
# Labels: [1 1]
# Inference time (ms): 20.770400000000002
# Labels: []
# Inference time (ms): 20.2833
# Labels: [1 1]
# Inference time (ms): 20.6021
# Labels: [1 1 1]
# Inference time (ms): 20.7741
# Labels: [1 1 1 1]
# Inference time (ms): 20.965999999999998
# Labels: [1 1]
# Inference time (ms): 20.5608
# Labels: [1 1]
# Inference time (ms): 20.643
# Labels: [1 1]
# Inference time (ms): 20.8619
# Labels: [1 1 1]
# Inference time (ms): 20.4376
# Labels: [1]
# Inference time (ms): 21.279
# Labels: [1 1]
# Inference time (ms): 20.7169
# Labels: [1 1]
# Inference time (ms): 20.6147
# Labels: [1 1 1]
# Inference time (ms): 20.6989
# Labels: [1 1]
# Inference time (ms): 21.1789
# Labels: []
# Inference time (ms): 21.1918
# Labels: []
# Inference time (ms): 20.5897
# Labels: [1]
# Inference time (ms): 20.242199999999997
# Labels: [1]
# Inference time (ms): 21.2163
# Labels: [1]
# Inference time (ms): 20.8371
# Labels: [1 1]
# Inference time (ms): 22.699
# Labels: [1]
# Inference time (ms): 20.6502
# Labels: [1]
# Inference time (ms): 20.6608
# Labels: [1 1]
# Inference time (ms): 20.663600000000002
# Labels: [1 1]
# Inference time (ms): 20.8695
# Labels: [1 1]
# Inference time (ms): 22.0308
# Labels: [1 1]
# Inference time (ms): 20.4299
# Labels: [1]
# Inference time (ms): 21.023500000000002
# Labels: [1 1]
# Inference time (ms): 20.296000000000003
# Labels: [1]
# Inference time (ms): 20.801
# Labels: [1]
# Inference time (ms): 20.9276
# Labels: [1]
# Inference time (ms): 20.9494
# Labels: [1]
# Inference time (ms): 20.6145
# Labels: [1]
# Inference time (ms): 20.776699999999998
# Labels: [1]
# Inference time (ms): 20.7478
# Labels: [1]
# Inference time (ms): 20.8521
# Labels: [1]
# Inference time (ms): 20.788
# Labels: [1]
# Inference time (ms): 20.5883
# Labels: [1 1]
# Inference time (ms): 20.7407
# Labels: [1]
# Inference time (ms): 21.5851
# Labels: [1]
# Inference time (ms): 21.3113
# Labels: [1]
# Inference time (ms): 20.5314
# Labels: [1]
# Inference time (ms): 20.8062
# Labels: [1]
# Inference time (ms): 20.688100000000002
# Labels: [1]
# Inference time (ms): 20.6275
# Labels: [1]
# Inference time (ms): 22.2998
# Labels: [1]
# Inference time (ms): 20.6676
# Labels: [1]
# Inference time (ms): 20.1283
# Labels: [1]
# Inference time (ms): 20.7595
# Labels: [1]
# Inference time (ms): 20.9086
# Labels: [1]
# Inference time (ms): 22.9619
# Labels: [1]
# Inference time (ms): 20.634
# Labels: [1]
# Inference time (ms): 20.194
# Labels: [1]
# Inference time (ms): 25.3344
# Labels: [1]
# Inference time (ms): 21.3186
# Labels: [1 1]
# Inference time (ms): 21.4587
# Labels: [1 1]
# Inference time (ms): 20.589799999999997
# Labels: [1 1 1]
# Inference time (ms): 20.779700000000002
# Labels: [1]
# Inference time (ms): 20.5501
# Labels: [1 1]
# Inference time (ms): 20.9955
# Labels: [1]
# Inference time (ms): 22.2289
# Labels: [1]
# Inference time (ms): 21.007499999999997
# Labels: [1]
# Inference time (ms): 20.2846
# Labels: [1]
# Inference time (ms): 20.7544
# Labels: [1]
# Inference time (ms): 20.403000000000002
# Labels: [1]
# Inference time (ms): 21.336299999999998
# Labels: [1]
# Inference time (ms): 20.5925
# Labels: [1]
# Inference time (ms): 20.778100000000002
# Labels: []
# Inference time (ms): 21.012800000000002
# Labels: [1]
# Inference time (ms): 25.015800000000002
# Labels: [1]
# Inference time (ms): 25.118000000000002
# Labels: [1]
# Inference time (ms): 20.4424
# Labels: [1]
# Inference time (ms): 20.4574
# Labels: [1]
# Inference time (ms): 20.9624
# Labels: [1]
# Inference time (ms): 20.7339
# Labels: [1]
# Inference time (ms): 21.188599999999997
# Labels: [1]
# Inference time (ms): 21.151
# Labels: [1]
# Inference time (ms): 20.5995
# Labels: [1]
# Inference time (ms): 20.7864
# Labels: [1]
# Inference time (ms): 20.365399999999998
# Labels: [1]
# Inference time (ms): 20.953300000000002
# Labels: [1]
# Inference time (ms): 20.720499999999998
# Labels: [1]
# Inference time (ms): 20.8425
# Labels: [1]
# Inference time (ms): 20.5329
# Labels: [1]
# Inference time (ms): 20.685100000000002
# Labels: [1]
# Inference time (ms): 20.9361
# Labels: [1]
# Inference time (ms): 21.2818
# Labels: [1]
# Inference time (ms): 20.8928
# Labels: [1]
# Inference time (ms): 20.473000000000003
# Labels: [1]
# Inference time (ms): 20.2717
# Labels: [1]
# Inference time (ms): 21.389499999999998
# Labels: [1]
# Inference time (ms): 20.9242
# Labels: [1]
# Inference time (ms): 20.429
# Labels: [1]
# Inference time (ms): 20.422
# Labels: [1]
# Inference time (ms): 20.307100000000002
# Labels: [1]
# Inference time (ms): 20.945999999999998
# Labels: [1]
# Inference time (ms): 20.6283
# Labels: [1]
# Inference time (ms): 21.4348
# Labels: [1]
# Inference time (ms): 20.270500000000002
# Labels: []
# Inference time (ms): 21.2326
# Labels: []
# Inference time (ms): 21.0144
# Labels: []
# Inference time (ms): 20.3367
# Labels: []
# Inference time (ms): 20.337600000000002
# Labels: [1]
# Inference time (ms): 20.483999999999998
# Labels: [1]
# Inference time (ms): 20.6568
# Labels: [1]
# Inference time (ms): 20.957900000000002
# Labels: [1]
# Inference time (ms): 20.011999999999997
# Labels: [1]
# Inference time (ms): 21.0453
# Labels: [1]
# Inference time (ms): 20.8915
# Labels: [1]
# Inference time (ms): 20.653399999999998
# Labels: [1]
# Inference time (ms): 20.913
# Labels: [1]
# Inference time (ms): 20.6081
# Labels: [1]
# Inference time (ms): 21.1798
# Labels: [1]
# Inference time (ms): 20.848
# Labels: [1]
# Inference time (ms): 20.6742
# Labels: [1]
# Inference time (ms): 20.7837
# Labels: [1]
# Inference time (ms): 20.755599999999998
# Labels: [1]
# Inference time (ms): 21.3074
# Labels: [1]
# Inference time (ms): 20.54
# Labels: [1]
# Inference time (ms): 21.0869
# Labels: [1]
# Inference time (ms): 21.0034
# Labels: [1]
# Inference time (ms): 20.6688
# Labels: [1]
# Inference time (ms): 20.763299999999997
# Labels: [1]
# Inference time (ms): 20.8666
# Labels: [1]
# Inference time (ms): 20.651699999999998
# Labels: [1]
# Inference time (ms): 21.0037
# Labels: [1]
# Inference time (ms): 21.410700000000002
# Labels: [1]
# Inference time (ms): 20.4774
# Labels: [1]
# Inference time (ms): 20.643
# Labels: [1]
# Inference time (ms): 20.4594
# Labels: [1]
# Inference time (ms): 24.232
# Labels: [1]
# Inference time (ms): 20.4848
# Labels: [1]
# Inference time (ms): 20.7241
# Labels: [1]
# Inference time (ms): 20.583199999999998
# Labels: [1]
# Inference time (ms): 20.871399999999998
# Labels: [1]
# Inference time (ms): 21.2478
# Labels: [1 1]
# Inference time (ms): 21.1937
# Labels: [1 1]
# Inference time (ms): 20.6976
# Labels: [1]
# Inference time (ms): 20.6071
# Labels: [1]
# Inference time (ms): 20.310000000000002
# Labels: [1]
# Inference time (ms): 24.9472
# Labels: [1]
# Inference time (ms): 21.8825
# Labels: [1]
# Inference time (ms): 20.736
# Labels: [1]
# Inference time (ms): 21.1123
# Labels: [1]
# Inference time (ms): 21.1786
# Labels: [1]
# Inference time (ms): 22.5306
# Labels: [1]
# Inference time (ms): 22.5454
# Labels: [1]
# Inference time (ms): 20.552
# Labels: [1]
# Inference time (ms): 22.3075
# Labels: [1]
# Inference time (ms): 20.9291
# Labels: [1]
# Inference time (ms): 21.061799999999998
# Labels: [1]
# Inference time (ms): 20.7588
# Labels: [1]
# Inference time (ms): 20.0266
# Labels: [1]
# Inference time (ms): 21.4615
# Labels: [1]
# Inference time (ms): 20.697400000000002
# Labels: [1]
# Inference time (ms): 20.9614
# Labels: [1]
# Inference time (ms): 20.0795
# Labels: [1]
# Inference time (ms): 24.79
# Labels: [1]
# Inference time (ms): 20.927500000000002
# Labels: [1]
# Inference time (ms): 20.7287
# Labels: [1 1]
# Inference time (ms): 21.3674
# Labels: [1]
# Inference time (ms): 21.8234
# Labels: [1]
# Inference time (ms): 20.363699999999998
# Labels: [1]
# Inference time (ms): 21.0155
# Labels: [1]
# Inference time (ms): 20.8931
# Labels: [1]
# Inference time (ms): 20.9085
# Labels: [1]
# Inference time (ms): 20.2558
# Labels: [1]
# Inference time (ms): 20.503
# Labels: [1]
# Inference time (ms): 21.5014
# Labels: [1]
# Inference time (ms): 20.2917
# Labels: [1]
# Inference time (ms): 20.8231
# Labels: [1]
# Inference time (ms): 20.354899999999997
# Labels: [1]
# Inference time (ms): 20.951500000000003
# Labels: [1]
# Inference time (ms): 21.0321
# Labels: [1]
# Inference time (ms): 21.616699999999998
# Labels: [1]
# Inference time (ms): 20.9739
# Labels: [1]
# Inference time (ms): 20.2302
# Labels: [1]
# Inference time (ms): 20.4643
# Labels: [1]
# Inference time (ms): 25.0568
# Labels: [1]
# Inference time (ms): 21.117
# Labels: [1]
# Inference time (ms): 20.9019
# Labels: [1]
# Inference time (ms): 20.5936
# Labels: [1]
# Inference time (ms): 20.2068
# Labels: [1]
# Inference time (ms): 20.778499999999998
# Labels: [1]
# Inference time (ms): 21.5675
# Labels: [1]
# Inference time (ms): 20.7491
# Labels: [1]
# Inference time (ms): 20.4136
# Labels: [1 1]
# Inference time (ms): 20.5213
# Labels: [1]
# Inference time (ms): 20.124
# Labels: [1]
# Inference time (ms): 25.7608
# Labels: [1]
# Inference time (ms): 20.7199
# Labels: [1]
# Inference time (ms): 21.1051
# Labels: [1]
# Inference time (ms): 20.7327
# Labels: [1]
# Inference time (ms): 20.688499999999998
# Labels: [1]
# Inference time (ms): 26.0412
# Labels: [1]
# Inference time (ms): 20.6993
# Labels: [1]
# Inference time (ms): 20.7125
# Labels: [1]
# Inference time (ms): 20.980700000000002
# Labels: [1 1]
# Inference time (ms): 20.7593
# Labels: [1 1]
# Inference time (ms): 20.8443
# Labels: [1]
# Inference time (ms): 20.6954
# Labels: [1 1]
# Inference time (ms): 20.194
# Labels: [1]
# Inference time (ms): 21.0857
# Labels: [1 1]
# Inference time (ms): 20.3539
# Labels: [1]
# Inference time (ms): 20.6817
# Labels: [1]
# Inference time (ms): 20.3183
# Labels: [1 1]
# Inference time (ms): 21.2987
# Labels: [1 1]
# Inference time (ms): 20.6473
# Labels: [1 1]
# Inference time (ms): 20.5737
# Labels: [1]
# Inference time (ms): 20.7532
# Labels: [1]
# Inference time (ms): 20.6841
# Labels: [1 1]
# Inference time (ms): 25.1117
# Labels: [1]
# Inference time (ms): 21.0197
# Labels: [1]
# Inference time (ms): 21.0307
# Labels: [1 1]
# Inference time (ms): 21.5319
# Labels: [1]
# Inference time (ms): 20.6328
# Labels: [1]
# Inference time (ms): 20.509
# Labels: [1]
# Inference time (ms): 20.2309
# Labels: [1]
# Inference time (ms): 20.5936
# Labels: []
# Inference time (ms): 21.1724
# Labels: []
# Inference time (ms): 20.4413
# Labels: []
# Inference time (ms): 20.5564
# Labels: []
# Inference time (ms): 20.9195
# Labels: []
# Inference time (ms): 20.6492
# Labels: []
# Inference time (ms): 21.0219
# Labels: []
# Inference time (ms): 21.8461
# Labels: []
# Inference time (ms): 20.7438
# Labels: []
# Inference time (ms): 20.3995
# Labels: []
# Inference time (ms): 20.5593
# Labels: []
# Inference time (ms): 20.618000000000002
# Labels: []
# Inference time (ms): 20.4821
# Labels: [1]
# Inference time (ms): 20.340400000000002
# Labels: []
# Inference time (ms): 21.0887
# Labels: [1]
# Inference time (ms): 20.8022
# Labels: [1]
# Inference time (ms): 20.593500000000002
# Labels: []
# Inference time (ms): 20.3745
# Labels: []
# Inference time (ms): 20.7931
# Labels: []
# Inference time (ms): 20.480999999999998
# Labels: []
# Inference time (ms): 20.352
# Labels: []
# Inference time (ms): 21.726599999999998
# Labels: []
# Inference time (ms): 20.7479
# Labels: []
# Inference time (ms): 20.2941
# Labels: []
# Inference time (ms): 20.4025
# Labels: []
# Inference time (ms): 20.3297
# Labels: []
# Inference time (ms): 20.8308
# Labels: [1]
# Inference time (ms): 21.036800000000003
# Labels: [1]
# Inference time (ms): 20.936799999999998
# Labels: [1]
# Inference time (ms): 20.1346
# Labels: [1]
# Inference time (ms): 20.7572
# Labels: [1]
# Inference time (ms): 21.7838
# Labels: [1]
# Inference time (ms): 20.366100000000003
# Labels: [1]
# Inference time (ms): 20.563499999999998
# Labels: [1]
# Inference time (ms): 20.6615
# Labels: [1]
# Inference time (ms): 20.315900000000003
# Labels: [1]
# Inference time (ms): 20.8372
# Labels: [1]
# Inference time (ms): 20.4796
# Labels: [1]
# Inference time (ms): 20.612499999999997
# Labels: [1]
# Inference time (ms): 20.9019
# Labels: [1]
# Inference time (ms): 20.7998
# Labels: [1]
# Inference time (ms): 21.1291
# Labels: [1]
# Inference time (ms): 20.5585
# Labels: [1]
# Inference time (ms): 20.6555
# Labels: [1]
# Inference time (ms): 21.2122
# Labels: [1]
# Inference time (ms): 20.575400000000002
# Labels: [1]
# Inference time (ms): 21.1226
# Labels: [1]
# Inference time (ms): 20.5618
# Labels: [1]
# Inference time (ms): 20.538
# Labels: [1]
# Inference time (ms): 20.9528
# Labels: [1]
# Inference time (ms): 20.2361
# Labels: [1]
# Inference time (ms): 21.4529
# Labels: [1]
# Inference time (ms): 20.3148
# Labels: [1]
# Inference time (ms): 20.680400000000002
# Labels: [1]
# Inference time (ms): 20.4761
# Labels: [1]
# Inference time (ms): 20.9295
# Labels: [1]
# Inference time (ms): 20.5096
# Labels: [1 1]
# Inference time (ms): 21.035
# Labels: [1 1]
# Inference time (ms): 20.4376
# Labels: [1]
# Inference time (ms): 20.3037
# Labels: [1]
# Inference time (ms): 21.0101
# Labels: [1]
# Inference time (ms): 21.1005
# Labels: [1]
# Inference time (ms): 20.5581
# Labels: [1]
# Inference time (ms): 20.530099999999997
# Labels: [1]
# Inference time (ms): 20.9349
# Labels: [1]
# Inference time (ms): 20.6354
# Labels: [1]
# Inference time (ms): 21.7972
# Labels: [1]
# Inference time (ms): 20.5944
# Labels: [1]
# Inference time (ms): 20.7087
# Labels: [1]
# Inference time (ms): 21.3351
# Labels: [1]
# Inference time (ms): 20.561200000000003
# Labels: [1]
# Inference time (ms): 20.8906
# Labels: [1]
# Inference time (ms): 20.986500000000003
# Labels: [1]
# Inference time (ms): 20.448600000000003
# Labels: [1]
# Inference time (ms): 20.1843
# Labels: [1]
# Inference time (ms): 20.8928
# Labels: [1]
# Inference time (ms): 25.031399999999998
# Labels: [1]
# Inference time (ms): 20.801
# Labels: [1]
# Inference time (ms): 20.180500000000002
# Labels: [1]
# Inference time (ms): 20.540699999999998
# Labels: [1]
# Inference time (ms): 20.5966
# Labels: [1]
# Inference time (ms): 21.4345
# Labels: [1]
# Inference time (ms): 20.052899999999998
# Labels: [1]
# Inference time (ms): 25.0756
# Labels: [1]
# Inference time (ms): 20.4436
# Labels: [1]
# Inference time (ms): 20.5304
# Labels: [1]
# Inference time (ms): 21.0059
# Labels: [1]
# Inference time (ms): 20.4556
# Labels: [1]
# Inference time (ms): 21.0687
# Labels: [1]
# Inference time (ms): 20.7719
# Labels: [1 1]
# Inference time (ms): 20.4487
# Labels: [1]
# Inference time (ms): 21.087999999999997
# Labels: [1]
# Inference time (ms): 20.418200000000002
# Labels: [1]
# Inference time (ms): 20.8589
# Labels: [1]
# Inference time (ms): 20.6244
# Labels: [1 1]
# Inference time (ms): 20.5516
# Labels: [1]
# Inference time (ms): 23.6914
# Labels: [1 1 1]
# Inference time (ms): 20.5143
# Labels: [1]
# Inference time (ms): 20.6463
# Labels: [1 1]
# Inference time (ms): 20.6207
# Labels: [1]
# Inference time (ms): 20.8761
# Labels: [1 1]
# Inference time (ms): 20.749299999999998
# Labels: [1]
# Inference time (ms): 20.4908
# Labels: [1]
# Inference time (ms): 20.1982
# Labels: [1]
# Inference time (ms): 21.0095
# Labels: [1]
# Inference time (ms): 20.7361
# Labels: [1]
# Inference time (ms): 21.1149
# Labels: [1]
# Inference time (ms): 20.679199999999998
# Labels: [1]
# Inference time (ms): 20.4974
# Labels: [1]
# Inference time (ms): 21.0438
# Labels: [1]
# Inference time (ms): 20.4611
# Labels: [1]
# Inference time (ms): 21.1027
# Labels: [1]
# Inference time (ms): 20.401699999999998
# Labels: [1]
# Inference time (ms): 20.6185
# Labels: [1]
# Inference time (ms): 20.591
# Labels: [1]
# Inference time (ms): 21.215
# Labels: [1]
# Inference time (ms): 21.108999999999998
# Labels: [1]
# Inference time (ms): 20.473399999999998
# Labels: [1]
# Inference time (ms): 20.2745
# Labels: [1]
# Inference time (ms): 20.6254
# Labels: [1]
# Inference time (ms): 20.6029
# Labels: [1]
# Inference time (ms): 21.1906
# Labels: [1]
# Inference time (ms): 20.712
# Labels: [1]
# Inference time (ms): 20.0714
# Labels: [1]
# Inference time (ms): 21.0137
# Labels: [1]
# Inference time (ms): 20.5801
# Labels: [1]
# Inference time (ms): 21.1493
# Labels: [1]
# Inference time (ms): 20.3064
# Labels: [1]
# Inference time (ms): 21.1
# Labels: [1]
# Inference time (ms): 20.500999999999998
# Labels: [1]
# Inference time (ms): 20.9065
# Labels: [1]
# Inference time (ms): 20.7879
# Labels: [1]
# Inference time (ms): 20.7619
# Labels: [1]
# Inference time (ms): 20.236400000000003
# Labels: [1]
# Inference time (ms): 20.5987
# Labels: [1]
# Inference time (ms): 20.933
# Labels: [1]
# Inference time (ms): 26.283
# Labels: [1]
# Inference time (ms): 20.5561
# Labels: [1]
# Inference time (ms): 20.527
# Labels: [1]
# Inference time (ms): 20.3788
# Labels: [1]
# Inference time (ms): 20.565199999999997
# Labels: [1]
# Inference time (ms): 20.4173
# Labels: [1]
# Inference time (ms): 20.7053
# Labels: [1]
# Inference time (ms): 20.8192
# Labels: [1]
# Inference time (ms): 20.3109
# Labels: [1]
# Inference time (ms): 25.3397
# Labels: [1]
# Inference time (ms): 20.7486
# Labels: [1]
# Inference time (ms): 20.9
# Labels: [1]
# Inference time (ms): 20.3522
# Labels: [1]
# Inference time (ms): 20.6694
# Labels: [1]
# Inference time (ms): 20.835099999999997
# Labels: [1]
# Inference time (ms): 21.1832
# Labels: [1]
# Inference time (ms): 20.6859
# Labels: [1]
# Inference time (ms): 20.8036
# Labels: [1]
# Inference time (ms): 20.442800000000002
# Labels: [1]
# Inference time (ms): 20.7292
# Labels: [1]
# Inference time (ms): 20.5771
# Labels: []
# Inference time (ms): 21.52
# Labels: []
# Inference time (ms): 20.942800000000002
# Labels: []
# Inference time (ms): 20.6945
# Labels: [1]
# Inference time (ms): 21.4479
# Labels: [1]
# Inference time (ms): 22.8396
# Labels: [1]
# Inference time (ms): 21.3421
# Labels: [1]
# Inference time (ms): 20.805
# Labels: [1]
# Inference time (ms): 20.7515
# Labels: [1]
# Inference time (ms): 20.4097
# Labels: [1]
# Inference time (ms): 21.1922
# Labels: [1]
# Inference time (ms): 20.7272
# Labels: [1]
# Inference time (ms): 25.6417
# Labels: []
# Inference time (ms): 20.6177
# Labels: []
# Inference time (ms): 21.1656
# Labels: []
# Inference time (ms): 20.8393
# Labels: []
# Inference time (ms): 21.0316
# Labels: []
# Inference time (ms): 20.5488
# Labels: [1]
# Inference time (ms): 20.3086
# Labels: [1]
# Inference time (ms): 20.561300000000003
# Labels: [1]
# Inference time (ms): 21.263399999999997
# Labels: [1]
# Inference time (ms): 20.8067
# Labels: [1 1]
# Inference time (ms): 20.994100000000003
# Labels: [1]
# Inference time (ms): 20.988
# Labels: [1 1]
# Inference time (ms): 20.4859
# Labels: [1 1]
# Inference time (ms): 20.614
# Labels: [1 1]
# Inference time (ms): 20.565
# Labels: [1]
# Inference time (ms): 20.7942
# Labels: [1]
# Inference time (ms): 20.2963
# Labels: [1]
# Inference time (ms): 20.8365
# Labels: [1]
# Inference time (ms): 20.6784
# Labels: [1]
# Inference time (ms): 21.0988
# Labels: [1]
# Inference time (ms): 20.9026
# Labels: []
# Inference time (ms): 20.602800000000002
# Labels: []
# Inference time (ms): 20.4619
# Labels: [1]
# Inference time (ms): 21.4806
# Labels: [1]
# Inference time (ms): 21.0215
# Labels: [1]
# Inference time (ms): 20.5242
# Labels: [1]
# Inference time (ms): 20.4064
# Labels: [1]
# Inference time (ms): 20.5025
# Labels: []
# Inference time (ms): 21.5685
# Labels: []
# Inference time (ms): 20.526
# Labels: []
# Inference time (ms): 20.6823
# Labels: [1]
# Inference time (ms): 20.4797
# Labels: []
# Inference time (ms): 20.8828
# Labels: []
# Inference time (ms): 20.7559
# Labels: [1]
# Inference time (ms): 20.4534
# Labels: [1]
# Inference time (ms): 20.7684
# Labels: [1]
# Inference time (ms): 20.9745
# Labels: [1]
# Inference time (ms): 20.9375
# Labels: [1]
# Inference time (ms): 20.9788
# Labels: [1]
# Inference time (ms): 27.9461
# Labels: [1]
# Inference time (ms): 21.184
# Labels: []
# Inference time (ms): 21.1386
# Labels: [1]
# Inference time (ms): 21.2182
# Labels: [1]
# Inference time (ms): 20.4451
# Labels: []
# Inference time (ms): 20.7021
# Labels: [1]
# Inference time (ms): 20.3293
# Labels: [1 1]
# Inference time (ms): 21.2099
# Labels: [1 1]
# Inference time (ms): 20.960800000000003
# Labels: [1]
# Inference time (ms): 21.058400000000002
# Labels: [1]
# Inference time (ms): 20.4863
# Labels: [1]
# Inference time (ms): 21.1498
# Labels: [1]
# Inference time (ms): 20.6012
# Labels: [1]
# Inference time (ms): 20.6918
# Labels: [1]
# Inference time (ms): 20.367199999999997
# Labels: [1]
# Inference time (ms): 20.3015
# Labels: [1]
# Inference time (ms): 21.2495
# Labels: [1]
# Inference time (ms): 21.54
# Labels: [1]
# Inference time (ms): 21.109099999999998
# Labels: [1]
# Inference time (ms): 20.7021
# Labels: [1]
# Inference time (ms): 20.495
# Labels: [1]
# Inference time (ms): 21.1875
# Labels: [1]
# Inference time (ms): 20.845599999999997
# Labels: [1]
# Inference time (ms): 21.1619
# Labels: []
# Inference time (ms): 20.7614
# Labels: []
# Inference time (ms): 19.8013
# Labels: []
# Inference time (ms): 20.5625
# Labels: []
# Inference time (ms): 20.8244
# Labels: [1]
# Inference time (ms): 21.0728
# Labels: []
# Inference time (ms): 20.187199999999997
# Labels: [1]
# Inference time (ms): 20.7934
# Labels: [1 1]
# Inference time (ms): 20.9429
# Labels: [1 1]
# Inference time (ms): 20.7016
# Labels: [1]
# Inference time (ms): 23.2155
# Labels: [1]
# Inference time (ms): 21.3201
# Labels: []
# Inference time (ms): 20.2748
# Labels: []
# Inference time (ms): 21.0002
# Labels: []
# Inference time (ms): 20.814
# Labels: []
# Inference time (ms): 20.9982
# Labels: []
# Inference time (ms): 20.540599999999998
# Labels: []
# Inference time (ms): 20.156899999999997
# Labels: []
# Inference time (ms): 20.6997
# Labels: []
# Inference time (ms): 20.2819
# Labels: []
# Inference time (ms): 24.6832
# Labels: []
# Inference time (ms): 20.7909
# Labels: []
# Inference time (ms): 20.581
# Labels: []
# Inference time (ms): 21.4327
# Labels: []
# Inference time (ms): 20.703
# Labels: []
# Inference time (ms): 21.1472
# Labels: []
# Inference time (ms): 20.3483
# Labels: []
# Inference time (ms): 20.9058
# Labels: []
# Inference time (ms): 20.383200000000002
# Labels: []
# Inference time (ms): 20.2253
# Labels: []
# Inference time (ms): 25.763
# Labels: []
# Inference time (ms): 21.456300000000002
# Labels: []
# Inference time (ms): 20.8898
# Labels: []
# Inference time (ms): 21.1656
# Labels: []
# Inference time (ms): 21.0218
# Labels: []
# Inference time (ms): 21.0796
# Labels: []
# Inference time (ms): 20.6288
# Labels: []
# Inference time (ms): 20.426099999999998
# Labels: [1]
# Inference time (ms): 20.3458
# Labels: [1]
# Inference time (ms): 20.4269
# Labels: []
# Inference time (ms): 21.657
# Labels: []
# Inference time (ms): 20.941499999999998
# Labels: []
# Inference time (ms): 20.9502
# Labels: []
# Inference time (ms): 20.136000000000003
# Labels: []
# Inference time (ms): 20.965500000000002
# Labels: []
# Inference time (ms): 21.3091
# Labels: []
# Inference time (ms): 20.283099999999997
# Labels: []
# Inference time (ms): 21.4268
# Labels: []
# Inference time (ms): 20.4986
# Labels: []
# Inference time (ms): 20.3009
# Labels: []
# Inference time (ms): 21.413800000000002
# Labels: []
# Inference time (ms): 20.4404
# Labels: []
# Inference time (ms): 20.300700000000003
# Labels: []
# Inference time (ms): 26.1247
# Labels: []
# Inference time (ms): 20.9839
# Labels: []
# Inference time (ms): 21.9346
# Labels: []
# Inference time (ms): 20.5526
# Labels: []
# Inference time (ms): 25.5092
# Labels: [1]
# Inference time (ms): 20.3855
# Labels: [1]
# Inference time (ms): 28.2746
# Labels: []
# Inference time (ms): 21.4549
# Labels: [1]
# Inference time (ms): 24.819399999999998
# Labels: [1]
# Inference time (ms): 20.8285
# Labels: []
# Inference time (ms): 20.864400000000003
# Labels: [1]
# Inference time (ms): 20.941100000000002
# Labels: []
# Inference time (ms): 20.7495
# Labels: [1]
# Inference time (ms): 20.4917
# Labels: []
# Inference time (ms): 24.930600000000002
# Labels: []
# Inference time (ms): 21.591099999999997
# Labels: []
# Inference time (ms): 20.8639
# Labels: []
# Inference time (ms): 24.466
# Labels: []
# Inference time (ms): 20.4218
# Labels: [1 1]
# Inference time (ms): 20.9265
# Labels: [1]
# Inference time (ms): 20.613599999999998
# Labels: []
# Inference time (ms): 20.805600000000002
# Labels: []
# Inference time (ms): 21.291600000000003
# Labels: []
# Inference time (ms): 21.086199999999998
# Labels: []
# Inference time (ms): 20.5655
# Labels: []
# Inference time (ms): 20.2308
# Labels: []
# Inference time (ms): 20.4188
# Labels: []
# Inference time (ms): 20.7946
# Labels: []
# Inference time (ms): 20.4145
# Labels: []
# Inference time (ms): 21.0562
# Labels: []
# Inference time (ms): 20.3996
# Labels: []
# Inference time (ms): 20.6048
# Labels: []
# Inference time (ms): 22.0938
# Labels: []
# Inference time (ms): 20.7735
# Labels: []
# Inference time (ms): 20.2886
# Labels: []
# Inference time (ms): 21.0672
# Labels: []
# Inference time (ms): 20.143
# Labels: []
# Inference time (ms): 21.5271
# Labels: []
# Inference time (ms): 20.508499999999998
# Labels: []
# Inference time (ms): 21.1358
# Labels: []
# Inference time (ms): 20.6613
# Labels: []
# Inference time (ms): 23.7073
# Labels: []
# Inference time (ms): 21.2416
# Labels: []
# Inference time (ms): 20.360599999999998
# Labels: []
# Inference time (ms): 20.5145
# Labels: []
# Inference time (ms): 20.3372
# Labels: []
# Inference time (ms): 21.2446
# Labels: []
# Inference time (ms): 21.0424
# Labels: []
# Inference time (ms): 20.6464
# Labels: [1]
# Inference time (ms): 21.015900000000002
# Labels: [1]
# Inference time (ms): 20.8868
# Labels: []
# Inference time (ms): 20.801099999999998
# Labels: []
# Inference time (ms): 20.8212
# Labels: []
# Inference time (ms): 20.853
# Labels: [1]
# Inference time (ms): 20.2942
# Labels: [1]
# Inference time (ms): 20.7731
# Labels: []
# Inference time (ms): 20.617
# Labels: []
# Inference time (ms): 21.7498
# Labels: []
# Inference time (ms): 20.5444
# Labels: []
# Inference time (ms): 20.7107
# Labels: []
# Inference time (ms): 21.0231
# Labels: []
# Inference time (ms): 20.8393
# Labels: []
# Inference time (ms): 23.2385
# Labels: []
# Inference time (ms): 20.91
# Labels: []
# Inference time (ms): 20.600299999999997
# Labels: []
# Inference time (ms): 20.429699999999997
# Labels: []
# Inference time (ms): 20.633599999999998
# Labels: []
# Inference time (ms): 20.8896
# Labels: []
# Inference time (ms): 21.118100000000002
# Labels: []
# Inference time (ms): 20.640800000000002
# Labels: []
# Inference time (ms): 20.8111
# Labels: []
# Inference time (ms): 20.1449
# Labels: []
# Inference time (ms): 22.058
# Labels: []
# Inference time (ms): 20.7322
# Labels: []
# Inference time (ms): 20.9252
# Labels: []
# Inference time (ms): 20.832900000000002
# Labels: []
# Inference time (ms): 20.3039
# Labels: []
# Inference time (ms): 21.4326
# Labels: []
# Inference time (ms): 20.7199
# Labels: []
# Inference time (ms): 20.4237
# Labels: []
# Inference time (ms): 20.0591
# Labels: []
# Inference time (ms): 21.066499999999998
# Labels: []
# Inference time (ms): 21.6697
# Labels: []
# Inference time (ms): 20.5425
# Labels: []
# Inference time (ms): 20.260299999999997
# Labels: []
# Inference time (ms): 20.548099999999998
# Labels: []
# Inference time (ms): 20.4095
# Labels: []
# Inference time (ms): 21.0619
# Labels: []
# Inference time (ms): 21.2056
# Labels: []
# Inference time (ms): 20.5258
# Labels: []
# Inference time (ms): 20.647599999999997
# Labels: []
# Inference time (ms): 20.560599999999997
# Labels: []
# Inference time (ms): 21.0172
# Labels: []
# Inference time (ms): 20.1544
# Labels: []
# Inference time (ms): 20.6777
# Labels: []
# Inference time (ms): 20.433400000000002
# Labels: []
# Inference time (ms): 20.3173
# Labels: []
# Inference time (ms): 21.654300000000003
# Labels: []
# Inference time (ms): 20.4339
# Labels: [1]
# Inference time (ms): 20.3721
# Labels: []
# Inference time (ms): 20.4416
# Labels: [1]
# Inference time (ms): 20.9881
# Labels: []
# Inference time (ms): 20.5054
# Labels: [1]
# Inference time (ms): 20.2017
# Labels: [1 1]
# Inference time (ms): 20.4523
# Labels: [1 1]
# Inference time (ms): 21.1245
# Labels: [1]
# Inference time (ms): 20.7828
# Labels: [1 1]
# Inference time (ms): 25.9752
# Labels: [1 1]
# Inference time (ms): 20.555899999999998
# Labels: [1 1]
# Inference time (ms): 20.4175
# Labels: [1 1]
# Inference time (ms): 20.6584
# Labels: [1 1]
# Inference time (ms): 22.031499999999998
# Labels: [1 1]
# Inference time (ms): 21.2649
# Labels: [1 1]
# Inference time (ms): 20.345200000000002
# Labels: [1 1]
# Inference time (ms): 20.4802
# Labels: [1 1]
# Inference time (ms): 20.4145
# Labels: [1 1]
# Inference time (ms): 20.584600000000002
# Labels: [1 1]
# Inference time (ms): 21.0199
# Labels: [1 1]
# Inference time (ms): 20.7247
# Labels: [1 1]
# Inference time (ms): 20.3609
# Labels: [1]
# Inference time (ms): 20.5614
# Labels: [1]
# Inference time (ms): 20.3217
# Labels: []
# Inference time (ms): 20.8495
# Labels: []
# Inference time (ms): 20.281
# Labels: [1]
# Inference time (ms): 20.6462
# Labels: [1]
# Inference time (ms): 21.4054
# Labels: []
# Inference time (ms): 20.302
# Labels: [1]
# Inference time (ms): 21.4748
# Labels: [1]
# Inference time (ms): 20.293599999999998
# Labels: [1]
# Inference time (ms): 20.621000000000002
# Labels: [1]
# Inference time (ms): 20.4784
# Labels: []
# Inference time (ms): 20.5592
# Labels: []
# Inference time (ms): 23.784
# Labels: [1]
# Inference time (ms): 20.5286
# Labels: []
# Inference time (ms): 20.3128
# Labels: []
# Inference time (ms): 20.5212
# Labels: []
# Inference time (ms): 20.505599999999998
# Labels: [1]
# Inference time (ms): 22.4561
# Labels: []
# Inference time (ms): 20.5842
# Labels: [1]
# Inference time (ms): 20.6578
# Labels: [1]
# Inference time (ms): 20.7597
# Labels: []
# Inference time (ms): 20.513900000000003
# Labels: [1 1]
# Inference time (ms): 21.413800000000002
# Labels: [1]
# Inference time (ms): 25.1418
# Labels: [1 1]
# Inference time (ms): 21.1237
# Labels: [1]
# Inference time (ms): 20.368299999999998
# Labels: [1]
# Inference time (ms): 20.6781
# Labels: [1]
# Inference time (ms): 20.935
# Labels: [1]
# Inference time (ms): 20.5815
# Labels: [1]
# Inference time (ms): 20.6713
# Labels: [1]
# Inference time (ms): 20.7043
# Labels: [1]
# Inference time (ms): 20.2408
# Labels: [1]
# Inference time (ms): 20.6427
# Labels: [1]
# Inference time (ms): 20.9291
# Labels: [1]
# Inference time (ms): 20.512900000000002
# Labels: [1]
# Inference time (ms): 20.772100000000002
# Labels: [1]
# Inference time (ms): 20.56
# Labels: [1]
# Inference time (ms): 21.3818
# Labels: [1]
# Inference time (ms): 20.529100000000003
# Labels: [1]
# Inference time (ms): 20.7073
# Labels: [1]
# Inference time (ms): 20.2688
# Labels: [1]
# Inference time (ms): 20.1995
# Labels: [1]
# Inference time (ms): 20.8678
# Labels: [1]
# Inference time (ms): 20.9729
# Labels: [1]
# Inference time (ms): 20.4138
# Labels: [1]
# Inference time (ms): 20.7182
# Labels: [1]
# Inference time (ms): 20.8725
# Labels: [1]
# Inference time (ms): 20.9353
# Labels: [1]
# Inference time (ms): 21.265
# Labels: [1]
# Inference time (ms): 20.2828
# Labels: [1]
# Inference time (ms): 20.5116
# Labels: [1]
# Inference time (ms): 19.9948
# Labels: [1]
# Inference time (ms): 21.5306
# Labels: [1]
# Inference time (ms): 20.2303
# Labels: [1]
# Inference time (ms): 20.7761
# Labels: [1]
# Inference time (ms): 20.4756
# Labels: [1]
# Inference time (ms): 20.9596
# Labels: [1]
# Inference time (ms): 20.7372
# Labels: [1]
# Inference time (ms): 21.168699999999998
# Labels: [1]
# Inference time (ms): 21.0023
# Labels: [1]
# Inference time (ms): 21.0498
# Labels: [1]
# Inference time (ms): 20.488300000000002
# Labels: [1]
# Inference time (ms): 21.018700000000003
# Labels: [1]
# Inference time (ms): 21.160600000000002
# Labels: [1]
# Inference time (ms): 20.092200000000002
# Labels: [1]
# Inference time (ms): 20.7919
# Labels: [1]
# Inference time (ms): 20.5296
# Labels: [1]
# Inference time (ms): 20.830399999999997
# Labels: [1]
# Inference time (ms): 20.3444
# Labels: [1]
# Inference time (ms): 20.4812
# Labels: [1]
# Inference time (ms): 20.4049
# Labels: [1]
# Inference time (ms): 20.4053
# Labels: [1]
# Inference time (ms): 20.4784
# Labels: [1]
# Inference time (ms): 20.4866
# Labels: [1]
# Inference time (ms): 20.5979
# Labels: [1]
# Inference time (ms): 20.2142
# Labels: [1]
# Inference time (ms): 20.9575
# Labels: [1]
# Inference time (ms): 21.296499999999998
# Labels: [1]
# Inference time (ms): 20.7063
# Labels: [1]
# Inference time (ms): 20.0654
# Labels: [1]
# Inference time (ms): 20.61
# Labels: [1]
# Inference time (ms): 20.616200000000003
# Labels: [1]
# Inference time (ms): 21.011599999999998
# Labels: [1]
# Inference time (ms): 20.3659
# Labels: [1]
# Inference time (ms): 20.5676
# Labels: [1]
# Inference time (ms): 20.5486
# Labels: [1]
# Inference time (ms): 20.5133
# Labels: [1]
# Inference time (ms): 21.0979
# Labels: [1]
# Inference time (ms): 20.8553
# Labels: [1]
# Inference time (ms): 20.255300000000002
# Labels: [1]
# Inference time (ms): 20.918300000000002
# Labels: [1]
# Inference time (ms): 20.9954
# Labels: [1]
# Inference time (ms): 21.2238
# Labels: [1]
# Inference time (ms): 20.6496
# Labels: [1]
# Inference time (ms): 20.7909
# Labels: [1]
# Inference time (ms): 20.5358
# Labels: [1]
# Inference time (ms): 20.395599999999998
# Labels: [1]
# Inference time (ms): 22.436500000000002
# Labels: [1]
# Inference time (ms): 20.438100000000002
# Labels: [1]
# Inference time (ms): 21.0827
# Labels: [1]
# Inference time (ms): 20.392899999999997
# Labels: [1]
# Inference time (ms): 20.5676
# Labels: [1]
# Inference time (ms): 20.8998
# Labels: [1]
# Inference time (ms): 20.8417
# Labels: [1]
# Inference time (ms): 20.968400000000003
# Labels: [1]
# Inference time (ms): 20.7548
# Labels: [1]
# Inference time (ms): 20.7164
# Labels: [1]
# Inference time (ms): 21.3996
# Labels: [1]
# Inference time (ms): 21.0049
# Labels: [1]
# Inference time (ms): 21.0545
# Labels: [1]
# Inference time (ms): 20.987599999999997
# Labels: [1]
# Inference time (ms): 20.498800000000003
# Labels: [1]
# Inference time (ms): 21.325
# Labels: [1]
# Inference time (ms): 20.6067
# Labels: [1]
# Inference time (ms): 20.733999999999998
# Labels: [1]
# Inference time (ms): 20.282899999999998
# Labels: [1]
# Inference time (ms): 20.6392
# Labels: [1]
# Inference time (ms): 25.221500000000002
# Labels: [1]
# Inference time (ms): 20.7923
# Labels: [1 1]
# Inference time (ms): 20.747700000000002
# Labels: [1 1]
# Inference time (ms): 21.669
# Labels: [1]
# ...
# Labels: [1 1]
# Inference time (ms): 20.371899999999997
# Labels: [1 1 1]
# Inference time (ms): 20.2218
# Labels: [1 1]
# Inference time (ms): 20.8507
# Labels: [1 1 1]
# Inference time (ms): 20.3876
# Labels: [1 1]
# Inference time (ms): 20.3293
# Labels: [1]
# Inference time (ms): 20.4885
# Labels: [1]
# Inference time (ms): 20.037
# Labels: [1]
# Inference time (ms): 21.107899999999997
# Labels: [1]
# Inference time (ms): 20.572799999999997
# Labels: [1]
# Inference time (ms): 20.3301
# Labels: [1]
# Inference time (ms): 20.395
# Labels: [1]
# Inference time (ms): 20.163400000000003
# Labels: [1]
# Inference time (ms): 21.121299999999998
# Labels: [1]
# Inference time (ms): 20.485500000000002
# Labels: []
# Inference time (ms): 20.6582
# Labels: [1]
# Inference time (ms): 20.3511
# Labels: [1]
# Inference time (ms): 20.485500000000002
# Labels: [1]
# Inference time (ms): 20.945999999999998
# Labels: [1 1]
# Inference time (ms): 20.391099999999998
# Labels: [1 1]
# Inference time (ms): 20.340600000000002
# Labels: [1]
# Inference time (ms): 20.8672
# Labels: [1 1 1]
# Inference time (ms): 20.4488
# Labels: [1 1]
# Inference time (ms): 21.2162
# Labels: [1 1]
# Inference time (ms): 20.2198
# Labels: [1 1]
# Inference time (ms): 20.0759
# Labels: [1 1 1]
# Inference time (ms): 20.5964
# Labels: [1 1]
# Inference time (ms): 20.4331
# Labels: [1]
# Inference time (ms): 21.430899999999998
# Labels: [1]
# Inference time (ms): 20.4584
# Labels: [1]
# Inference time (ms): 20.648
# Labels: [1]
# Inference time (ms): 20.9079
# Labels: [1]
# Inference time (ms): 20.7105
# Labels: [1]
# Inference time (ms): 21.1404
# Labels: [1 1]
# Inference time (ms): 20.307599999999997
# Labels: [1 1]
# Inference time (ms): 20.9806
# Labels: [1 1]
# Inference time (ms): 20.429699999999997
# Labels: [1 1 1]
# Inference time (ms): 20.5848
# Labels: [1 1 1]
# Inference time (ms): 21.1749
# Labels: [1]
# Inference time (ms): 20.4382
# Labels: [1 1]
# Inference time (ms): 20.679
# Labels: [1 1 1]
# Inference time (ms): 20.5838
# Labels: [1]
# Inference time (ms): 20.2719
# Labels: [1]
# Inference time (ms): 21.1464
# Labels: [1]
# Inference time (ms): 20.8583
# Labels: []
# Inference time (ms): 20.417399999999997
# Labels: [1]
# Inference time (ms): 20.2798
# Labels: [1 1]
# Inference time (ms): 20.4094
# Labels: []
# Inference time (ms): 20.7286
# Labels: [1]
# Inference time (ms): 19.7852
# Labels: []
# Inference time (ms): 20.9882
# Labels: [1 1]
# Inference time (ms): 20.3119
# Labels: [1 1]
# Inference time (ms): 20.2861
# Labels: [1]
# Inference time (ms): 24.1812
# Labels: [1 1 1]
# Inference time (ms): 28.1856
# Labels: [1 1 1]
# Inference time (ms): 20.2272
# Labels: [1]
# Inference time (ms): 20.485599999999998
# Labels: [1 1 1 1]
# Inference time (ms): 21.0481
# Labels: [1 1]
# Inference time (ms): 20.275000000000002
# Labels: [1]
# Inference time (ms): 20.478199999999998
# Labels: [1 1 1]
# Inference time (ms): 20.1308
# Labels: [1]
# Inference time (ms): 20.489
# Labels: [1 1]
# Inference time (ms): 22.3482
# Labels: [1]
# Inference time (ms): 20.323999999999998
# Labels: [1 1]
# Inference time (ms): 20.7168
# Labels: [1]
# Inference time (ms): 20.5608
# Labels: [1 1]
# Inference time (ms): 20.2741
# Labels: [1]
# Inference time (ms): 20.8136
# Labels: [1]
# Inference time (ms): 20.2334
# Labels: [1]
# Inference time (ms): 20.421000000000003
# Labels: [1]
# Inference time (ms): 20.677999999999997
# Labels: [1]
# Inference time (ms): 20.3175
# Labels: [1]
# Inference time (ms): 25.0177
# Labels: [1 1 1]
# Inference time (ms): 20.5505
# Labels: [1 1]
# Inference time (ms): 20.3968
# Labels: [1 1]
# Inference time (ms): 20.298099999999998
# Labels: [1 1 1]
# Inference time (ms): 25.3665
# Labels: [1]
# Inference time (ms): 20.9774
# Labels: [1]
# Inference time (ms): 20.4859
# Labels: [1 1]
# Inference time (ms): 20.3568
# Labels: [1 1]
# Inference time (ms): 20.7397
# Labels: [1 1]
# Inference time (ms): 20.3947
# Labels: [1]
# Inference time (ms): 21.003999999999998
# Labels: [1]
# Inference time (ms): 20.6111
# Labels: [1 1]
# Inference time (ms): 19.9113
# Labels: [1]
# Inference time (ms): 20.351000000000003
# Labels: [1 1]
# Inference time (ms): 20.4242
# Labels: [1 1]
# Inference time (ms): 20.3616
# Labels: [1]
# Inference time (ms): 20.387099999999997
# Labels: [1]
# Inference time (ms): 20.3111
# Labels: [1]
# Inference time (ms): 20.4513
# Labels: [1]
# Inference time (ms): 21.2285
# Labels: [1]
# Inference time (ms): 25.3961
# Labels: [1]
# Inference time (ms): 20.3238
# Labels: [1]
# Inference time (ms): 24.3863
# Labels: [1]
# Inference time (ms): 20.625
# Labels: [1]
# Inference time (ms): 20.322799999999997
# Labels: [1]
# Inference time (ms): 20.4674
# Labels: [1]
# Inference time (ms): 20.1245
# Labels: [1]
# Inference time (ms): 21.1188
# Labels: [1]
# Inference time (ms): 20.6597
# Labels: [1]
# Inference time (ms): 20.5734
# Labels: [1]
# Inference time (ms): 21.661900000000003
# Labels: [1]
# Inference time (ms): 20.4584
# Labels: [1 1]
# Inference time (ms): 20.9763
# Labels: [1 1]
# Inference time (ms): 20.1123
# Labels: [1]
# Inference time (ms): 21.022
# Labels: [1 1]
# Inference time (ms): 25.196900000000003
# Labels: [1 1]
# Inference time (ms): 20.5809
# Labels: [1 1 1 1]
# Inference time (ms): 20.6789
# Labels: [1 1]
# Inference time (ms): 21.4827
# Labels: [1 1 1]
# Inference time (ms): 20.4147
# Labels: [1 1 1]
# Inference time (ms): 20.9969
# Labels: [1]
# Inference time (ms): 21.0375
# Labels: [1]
# Inference time (ms): 20.4248
# Labels: [1]
# Inference time (ms): 20.3172
# Labels: [1]
# Inference time (ms): 20.2665
# Labels: [1]
# Inference time (ms): 56.2038
# Labels: [1]
# Inference time (ms): 20.567
# Labels: [1]
# Inference time (ms): 20.5041
# Labels: [1]
# Inference time (ms): 20.5016
# Labels: [1]
# Inference time (ms): 20.2814
# Labels: [1]
# Inference time (ms): 20.436
# Labels: [1 1]
# Inference time (ms): 20.7139
# Labels: [1 1]
# Inference time (ms): 20.5868
# Labels: [1]
# Inference time (ms): 20.567800000000002
# Labels: [1 1]
# Inference time (ms): 20.4393
# Labels: [1]
# Inference time (ms): 21.003999999999998
# Labels: [1 1]
# Inference time (ms): 20.6906
# Labels: [1 1 1]
# Inference time (ms): 20.5153
# Labels: [1]
# Inference time (ms): 20.2244
# Labels: [1]
# Inference time (ms): 20.2846
# Labels: [1]
# Inference time (ms): 21.6702
# Labels: [1]
# Inference time (ms): 20.505599999999998
# Labels: [1]
# Inference time (ms): 22.3971
# Labels: [1]
# Inference time (ms): 20.3905
# Labels: [1]
# Inference time (ms): 21.4117
# Labels: [1]
# Inference time (ms): 21.1918
# Labels: [1]
# Inference time (ms): 20.5118
# Labels: [1]
# Inference time (ms): 20.5263
# Labels: [1 1]
# Inference time (ms): 20.5838
# Labels: [1 1]
# Inference time (ms): 20.392500000000002
# Labels: [1 1]
# Inference time (ms): 20.992
# Labels: [1 1]
# Inference time (ms): 20.0472
# Labels: [1 1]
# Inference time (ms): 20.3791
# Labels: [1 1 1]
# Inference time (ms): 20.6065
# Labels: [1]
# Inference time (ms): 20.4392
# Labels: [1 1]
# Inference time (ms): 20.8975
# Labels: [1 1 1 1]
# Inference time (ms): 20.342200000000002
# Labels: [1 1]
# Inference time (ms): 20.4361
# Labels: [1 1]
# Inference time (ms): 20.3023
# Labels: [1]
# Inference time (ms): 20.200699999999998
# Labels: [1]
# Inference time (ms): 21.1305
# Labels: [1]
# Inference time (ms): 20.1889
# Labels: [1]
# Inference time (ms): 20.5031
# Labels: [1]
# Inference time (ms): 20.7887
# Labels: [1]
# Inference time (ms): 20.2104
# Labels: [1 1]
# Inference time (ms): 20.9559
# Labels: [1]
# Inference time (ms): 20.6591
# Labels: [1]
# Inference time (ms): 20.2586
# Labels: [1]
# Inference time (ms): 20.3494
# Labels: [1]
# Inference time (ms): 20.472299999999997
# Labels: [1]
# Inference time (ms): 21.0446
# Labels: [1]
# Inference time (ms): 20.4547
# Labels: [1]
# Inference time (ms): 20.2482
# Labels: [1]
# Inference time (ms): 20.3015
# Labels: [1 1]
# Inference time (ms): 25.218799999999998
# Labels: [1]
# Inference time (ms): 26.991999999999997
# Labels: [1 1]
# Inference time (ms): 20.3097
# Labels: [1]
# Inference time (ms): 20.345
# Labels: [1 1]
# Inference time (ms): 20.4234
# Labels: [1 1]
# Inference time (ms): 21.2003
# Labels: [1 1]
# Inference time (ms): 25.252
# Labels: [1 1]
# Inference time (ms): 20.396
# Labels: [1 1]
# Inference time (ms): 20.5214
# Labels: [1 1 1]
# Inference time (ms): 20.5473
# Labels: [1 1]
# Inference time (ms): 20.7171
# Labels: [1 1 1 1]
# Inference time (ms): 20.927500000000002
# Labels: [1 1 1 1]
# Inference time (ms): 20.375600000000002
# Labels: [1 1 1]
# Inference time (ms): 20.2567
# Labels: [1 1 1]
# Inference time (ms): 20.2593
# Labels: [1 1 1 1]
# Inference time (ms): 20.0974
# Labels: [1 1 1 1]
# Inference time (ms): 27.0876
# Labels: [1 1 1]
# Inference time (ms): 21.019
# Labels: [1 1 1 1]
# Inference time (ms): 20.5795
# Labels: [1 1 1 1]
# Inference time (ms): 20.2342
# Labels: [1 1]
# Inference time (ms): 20.9713
# Labels: [1 1 1]
# Inference time (ms): 20.4695
# Labels: [1 1 1]
# Inference time (ms): 20.3905
# Labels: [1 1]
# Inference time (ms): 20.4432
# Labels: [1 1]
# Inference time (ms): 20.0787
# Labels: [1]
# Inference time (ms): 20.9297
# Labels: [1]
# Inference time (ms): 20.7465
# Labels: [1]
# Inference time (ms): 20.5192
# Labels: [1 1 1 1]
# Inference time (ms): 20.5153
# Labels: [1 1]
# Inference time (ms): 25.538999999999998
# Labels: [1 1]
# Inference time (ms): 20.9375
# Labels: [1]
# Inference time (ms): 20.5413
# Labels: [1]
# Inference time (ms): 20.2699
# Labels: [1 1]
# Inference time (ms): 20.5645
# Labels: [1]
# Inference time (ms): 20.603900000000003
# Labels: [1 1]
# Inference time (ms): 25.6527
# Labels: [1 1]
# Inference time (ms): 21.0374
# Labels: [1 1]
# Inference time (ms): 20.6598
# Labels: [1 1 1]
# Inference time (ms): 20.2612
# Labels: [1 1 1]
# Inference time (ms): 20.3166
# Labels: [1 1]
# Inference time (ms): 20.633499999999998
# Labels: [1 1]
# Inference time (ms): 20.200400000000002
# Labels: [1]
# Inference time (ms): 20.3952
# Labels: [1 1 1]
# Inference time (ms): 25.5854
# Labels: [1 1]
# Inference time (ms): 20.5106
# Labels: [1 1 1 1]
# Inference time (ms): 20.445999999999998
# Labels: [1 1 1]
# Inference time (ms): 20.778299999999998
# Labels: [1 1]
# Inference time (ms): 21.1462
# Labels: [1 1 1]
# Inference time (ms): 20.3078
# Labels: [1]
# Inference time (ms): 20.4638
# Labels: [1 1]
# Inference time (ms): 22.146900000000002
# Labels: [1 1]
# Inference time (ms): 26.1052
# Labels: [1 1]
# Inference time (ms): 24.327399999999997
# Labels: [1]
# Inference time (ms): 20.5258
# Labels: [1]
# Inference time (ms): 20.273200000000003
# Labels: [1 1]
# Inference time (ms): 21.1492
# Labels: [1]
# Inference time (ms): 20.383200000000002
# Labels: [1]
# Inference time (ms): 20.586299999999998
# Labels: []
# Inference time (ms): 20.3423
# Labels: [1]
# Inference time (ms): 20.5469
# Labels: [1 1]
# Inference time (ms): 20.2313
# Labels: [1 1]
# Inference time (ms): 20.0094
# Labels: [1 1]
# Inference time (ms): 20.3594
# Labels: []
# Inference time (ms): 20.9018
# Labels: [1]
# Inference time (ms): 20.6618
# Labels: []
# Inference time (ms): 22.0086
# Labels: []
# Inference time (ms): 20.2618
# Labels: []
# Inference time (ms): 25.5905
# Labels: []
# Inference time (ms): 20.5733
# Labels: []
# Inference time (ms): 21.2304
# Labels: [1]
# Inference time (ms): 21.0903
# Labels: []
# Inference time (ms): 20.715899999999998
# Labels: []
# Inference time (ms): 20.4985
# Labels: []
# Inference time (ms): 20.567800000000002
# Labels: []
# Inference time (ms): 20.360500000000002
# Labels: []
# Inference time (ms): 25.581300000000002
# Labels: [1]
# Inference time (ms): 20.6406
# Labels: []
# Inference time (ms): 21.0076
# Labels: [1]
# Inference time (ms): 20.2564
# Labels: []
# Inference time (ms): 20.607899999999997
# Labels: []
# Inference time (ms): 20.7095
# Labels: []
# Inference time (ms): 26.9585
# Labels: []
# Inference time (ms): 20.3952
# Labels: []
# Inference time (ms): 20.527
# Labels: []
# Inference time (ms): 21.249299999999998
# Labels: []
# Inference time (ms): 20.4745
# Labels: []
# Inference time (ms): 20.3432
# Labels: [1]
# Inference time (ms): 20.4448
# Labels: []
# Inference time (ms): 20.2087
# Labels: [1]
# Inference time (ms): 21.8595
# Labels: [1]
# Inference time (ms): 20.8848
# Labels: []
# Inference time (ms): 20.5835
# Labels: []
# Inference time (ms): 20.314
# Labels: []
# Inference time (ms): 20.585900000000002
# Labels: []
# Inference time (ms): 21.0148
# Labels: []
# Inference time (ms): 20.534899999999997
# Labels: []
# Inference time (ms): 20.5654
# Labels: []
# Inference time (ms): 20.447799999999997
# Labels: []
# Inference time (ms): 20.386499999999998
# Labels: []
# Inference time (ms): 21.0977
# Labels: []
# Inference time (ms): 20.5341
# Labels: []
# Inference time (ms): 20.2027
# Labels: []
# Inference time (ms): 20.2667
# Labels: []
# Inference time (ms): 20.415499999999998
# Labels: []
# Inference time (ms): 21.8607
# Labels: []
# Inference time (ms): 20.3215
# Labels: [1]
# Inference time (ms): 20.5499
# Labels: []
# Inference time (ms): 20.2727
# Labels: []
# Inference time (ms): 20.319899999999997
# Labels: []
# Inference time (ms): 20.6634
# Labels: []
# Inference time (ms): 20.520799999999998
# Labels: [1]
# Inference time (ms): 20.5054
# Labels: [1]
# Inference time (ms): 20.7897
# Labels: []
# Inference time (ms): 20.439
# Labels: []
# Inference time (ms): 22.822200000000002
# Labels: []
# Inference time (ms): 20.5586
# Labels: []
# Inference time (ms): 20.2392
# Labels: []
# Inference time (ms): 20.3236
# Labels: []
# Inference time (ms): 20.4455
# Labels: []
# Inference time (ms): 21.4951
# Labels: []
# Inference time (ms): 20.601000000000003
# Labels: [1]
# Inference time (ms): 20.197699999999998
# Labels: []
# Inference time (ms): 20.5522
# Labels: []
# Inference time (ms): 20.2258
# Labels: []
# Inference time (ms): 20.838700000000003
# Labels: [1]
# Inference time (ms): 25.8723
# Labels: [1]
# Inference time (ms): 20.280800000000003
# Labels: []
# Inference time (ms): 20.8947
# Labels: []
# Inference time (ms): 25.4502
# Labels: []
# Inference time (ms): 20.5452
# Labels: []
# Inference time (ms): 20.1613
# Labels: [1]
# Inference time (ms): 20.4271
# Labels: [1]
# Inference time (ms): 20.563100000000002
# Labels: []
# Inference time (ms): 20.3905
# Labels: []
# Inference time (ms): 20.831
# Labels: []
# Inference time (ms): 20.580000000000002
# Labels: []
# Inference time (ms): 20.3986
# Labels: []
# Inference time (ms): 20.3731
# Labels: []
# Inference time (ms): 20.6095
# Labels: []
# Inference time (ms): 22.073099999999997
# Labels: [1]
# Inference time (ms): 19.9994
# Labels: [1]
# Inference time (ms): 20.770799999999998
# Labels: [1]
# Inference time (ms): 20.7313
# Labels: []
# Inference time (ms): 20.5017
# Labels: []
# Inference time (ms): 22.616799999999998
# Labels: []
# Inference time (ms): 27.826
# Labels: []
# Inference time (ms): 20.2771
# Labels: [1]
# Inference time (ms): 20.2524
# Labels: [1]
# Inference time (ms): 21.511599999999998
# Labels: [1]
# Inference time (ms): 20.307599999999997
# Labels: []
# Inference time (ms): 20.3043
# Labels: []
# Inference time (ms): 20.4403
# Labels: []
# Inference time (ms): 20.1189
# Labels: []
# Inference time (ms): 21.2072
# Labels: []
# Inference time (ms): 20.4468
# Labels: []
# Inference time (ms): 21.0207
# Labels: []
# Inference time (ms): 20.6908
# Labels: []
# Inference time (ms): 20.4343
# Labels: []
# Inference time (ms): 20.8986
# Labels: []
# Inference time (ms): 20.5672
# Labels: []
# Inference time (ms): 20.2557
# Labels: []
# Inference time (ms): 20.509200000000003
# Labels: []
# Inference time (ms): 25.8988
# Labels: []
# Inference time (ms): 21.548000000000002
# Labels: []
# Inference time (ms): 25.5295
# Labels: []
# Inference time (ms): 20.3359
# Labels: []
# Inference time (ms): 20.3639
# Labels: []
# Inference time (ms): 20.054
# Labels: []
# Inference time (ms): 20.775399999999998
# Labels: []
# Inference time (ms): 20.3078
# Labels: []
# Inference time (ms): 20.6147
# Labels: []
# Inference time (ms): 20.372700000000002
# Labels: []
# Inference time (ms): 20.660899999999998
# Labels: []
# Inference time (ms): 21.168599999999998
# Labels: []
# Inference time (ms): 20.0811
# Labels: []
# Inference time (ms): 20.3823
# Labels: []
# Inference time (ms): 20.3707
# Labels: []
# Inference time (ms): 20.944399999999998
# Labels: []
# Inference time (ms): 20.8347
# Labels: []
# Inference time (ms): 20.254
# Labels: []
# Inference time (ms): 20.4575
# Labels: []
# Inference time (ms): 20.1298
# Labels: []
# Inference time (ms): 20.673099999999998
# Labels: []
# Inference time (ms): 22.1932
# Labels: []
# Inference time (ms): 20.7245
# Labels: []
# Inference time (ms): 20.285600000000002
# Labels: []
# Inference time (ms): 20.517799999999998
# Labels: []
# Inference time (ms): 20.1631
# Labels: []
# Inference time (ms): 20.9862
# Labels: []
# Inference time (ms): 28.8303
# Labels: []
# Inference time (ms): 20.4293
# Labels: []
# Inference time (ms): 20.060499999999998
# Labels: []
# Inference time (ms): 21.0302
# Labels: []
# Inference time (ms): 20.5136
# Labels: []
# Inference time (ms): 20.4114
# Labels: []
# Inference time (ms): 25.243399999999998
# Labels: []
# Inference time (ms): 20.5608

# %% [markdown]
# # Calculate PARAMs and MACs

# %%
import torch
import torch.nn as nn
from ptflops import get_model_complexity_info

class SSDWrapper(nn.Module):
    def __init__(self, detection_model):
        super().__init__()
        self.model = detection_model

    def forward(self, x):
        # x will be a single Tensor of shape (batch_size=1, 3, H, W)
        # We need to transform it into a list of images for SSDLite.
        return self.model([x[0]])  # pass as a list with one image
import torch
from ptflops import get_model_complexity_info

# 1. Wrap the SSDLite model
wrapped_model = SSDWrapper(model).to(device)
wrapped_model.eval()

# 2. Define the input shape for which you want to measure FLOPs
input_res = (3, 320, 320)  # (channels, height, width)

# 3. Calculate MACs and Params using ptflops
with torch.cuda.device(0):
    macs, params = get_model_complexity_info(
        wrapped_model,
        input_res,
        as_strings=True,           # If True, returns strings like '0.88 GFLOPs'
        print_per_layer_stat=False # If True, prints layer-by-layer stats
    )

print(f"MACs: {macs}")
print(f"Params: {params}")
# Out:
# MACs: 518.9 MMac
# Params: 3.71 M

# %% [markdown]
# # Convert to C++ to ONNX

# %%
import torch
import torchvision
from torchvision.models.detection import ssdlite320_mobilenet_v3_large
from torchvision.models.detection.ssdlite import SSDLite320_MobileNet_V3_Large_Weights

# 1) Create model
model = ssdlite320_mobilenet_v3_large(
    weights=None,
    num_classes=2,  # e.g. background + rat
    weights_backbone=torchvision.models.MobileNet_V3_Large_Weights.IMAGENET1K_V1
)

# 2) Load your trained weights
model_path = r"C:\Machine Learning\Rat Tracking using TensorFlow\Model.pth"
state_dict = torch.load(model_path, map_location="cpu")
model.load_state_dict(state_dict)
model.eval()

# 3) Force the model to keep the final detection step in the graph
#    so that the ONNX includes bounding boxes, scores, labels.
#    We'll override the model's transform.postprocess to do nothing
#    but we do want to keep `postprocess_detections`.
#    By default, the official code calls it inside `forward()` only if `not training`.
def keep_postprocess_detections(self, head_outputs, anchors, image_sizes):
    # The default ssd.py code for postprocess_detections does the anchor decode, clamp, etc.
    # We'll call the original method:
    from torchvision.models.detection.ssd import SSD
    return SSD.postprocess_detections(self, head_outputs, anchors, image_sizes)

# Attach this override
model.postprocess_detections = keep_postprocess_detections.__get__(model)

# Optionally override transform.postprocess to do *nothing* (so we keep raw image size).
# model.transform.postprocess = lambda detections, image_sizes, orig_image_sizes: detections

# 4) Create a dummy input
dummy_input = torch.randn(1, 3, 320, 320)

# 5) Export to ONNX
torch.onnx.export(
    model,
    dummy_input,
    "model.onnx",
    input_names=["input"],
    # We want 3 outputs: "boxes", "scores", "labels"
    # but TorchVision returns them in a single list of dict for each image.
    # By default, it might create sequence outputs. Let's see.
    output_names=["boxes", "scores", "labels"],
    opset_version=12,
    # dynamic_axes={
    #     "input": {0: "batch_size", 2: "height", 3: "width"},
    #     "boxes": {1: "num_boxes"},
    #     "scores": {1: "num_boxes"},
    #     "labels": {1: "num_boxes"},
    # }
)
print("Exported SSDLite model with final bounding boxes to model.onnx.")
# Out:
# Exported SSDLite model with final bounding boxes to model.onnx.

# %%
import torch
import torchvision
from torchvision.models.detection import ssdlite320_mobilenet_v3_large, SSDLite320_MobileNet_V3_Large_Weights

# Recreate the model architecture
model = ssdlite320_mobilenet_v3_large(
    weights=None,
    num_classes=2,  # background and rat
    weights_backbone=torchvision.models.MobileNet_V3_Large_Weights.IMAGENET1K_V1
)

# Load your trained weights
state_dict = torch.load("Model.pth", map_location="cpu")
model.load_state_dict(state_dict)

# Set the model to evaluation mode
model.eval()

# (Optional) If you want to run the conversion on CPU
device = torch.device("cpu")
model.to(device)

# Create a dummy input matching your expected input size (e.g., 1x3x320x320)
dummy_input = torch.randn(1, 3, 320, 320, device=device)

# Export the model to ONNX
torch.onnx.export(
    model, 
    dummy_input, 
    "model.onnx", 
    export_params=True,              # store the trained parameter weights inside the model file
    opset_version=11,                # choose an appropriate opset version
    do_constant_folding=False,        # optimize constant expressions
    input_names=["input"],           # name your input tensor(s)
    output_names=["boxes", "scores", "labels"],        # name your output tensor(s)
    dynamic_axes={
        "input": {0: "batch_size"},   # enable variable batch size
        "output": {0: "batch_size"}
    }
)
print("Model successfully exported to model.onnx")
# Out:
# Model successfully exported to model.onnx

# %%
import cv2
import numpy as np
import time
import onnxruntime as ort

# --------------------------
# 1) Preprocessing
# --------------------------
def preprocess(frame, target_size=(320, 320)):
    """
    Convert BGR frame to normalized RGB tensor of shape (1, 3, H, W).
    """
    # Convert from BGR to RGB
    img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    
    # Resize to (320 x 320)
    img = cv2.resize(img, target_size)
    
    # Convert to float and normalize to [0,1]
    img = img.astype(np.float32) / 255.0
    
    # Normalize using the same mean and std used in training
    mean = np.array([0.485, 0.456, 0.406], dtype=np.float32)
    std = np.array([0.229, 0.224, 0.225], dtype=np.float32)
    img = (img - mean) / std
    
    # Change from HxWxC to CxHxW, then add batch dimension => (1, 3, 320, 320)
    img = np.transpose(img, (2, 0, 1))
    img = np.expand_dims(img, axis=0)
    
    return img

# --------------------------
# 2) ONNX Inference
# --------------------------
def predict(frame, session, threshold=0.2, input_size=(320, 320)):
    """
    Run inference on a single frame using an ONNX session.
    Returns the original frame plus boxes, scores, labels, and inference time.
    """
    # Store original dimensions for later box scaling
    orig_h, orig_w = frame.shape[:2]
    
    # Preprocess
    input_tensor = preprocess(frame, target_size=input_size)
    
    # Get input name for the session
    input_name = session.get_inputs()[0].name
    
    # Run inference and measure time
    start = time.time()
    outputs = session.run(None, {input_name: input_tensor})
    inf_time = (time.time() - start) * 1000.0  # ms
    
    # Model outputs (assuming "boxes", "scores", "labels" in that order)
    boxes = outputs[0]   # Shape: (N, 4)
    scores = outputs[1]  # Shape: (N,)
    labels = outputs[2]  # Shape: (N,)
    
    # Filter predictions by threshold
    valid_idx = scores > threshold
    boxes = boxes[valid_idx]
    scores = scores[valid_idx]
    labels = labels[valid_idx]
    
    # --------------------------
    # 3) If we have at least one detection, keep only the best one
    # --------------------------
    if len(scores) > 0:
        best_idx = np.argmax(scores)
        boxes = boxes[best_idx:best_idx+1]
        scores = scores[best_idx:best_idx+1]
        labels = labels[best_idx:best_idx+1]
    else:
        # No detections above threshold, so we return empty arrays
        boxes = np.array([])
        scores = np.array([])
        labels = np.array([])
    
    # --------------------------
    # 4) Scale Boxes Back
    # --------------------------
    # The boxes are in (320x320) coordinates. Scale them to (orig_w x orig_h).
    scale_x = orig_w / float(input_size[0])
    scale_y = orig_h / float(input_size[1])
    
    if boxes.size > 0:
        boxes[:, [0, 2]] *= scale_x
        boxes[:, [1, 3]] *= scale_y
    
    return frame, boxes, scores, labels, inf_time

# --------------------------
# 4) Main Loop
# --------------------------
def main():
    # Create an ONNX Runtime session (CPU Execution Provider here)
    session = ort.InferenceSession("model.onnx", providers=["CPUExecutionProvider"])
    
    video_path = r"C:\Machine Learning\Rat Tracking using TensorFlow\Video\BaselineDark.mp4"
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"Error opening video file: {video_path}")
        return
    
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        
        # Run inference
        orig_img, boxes, scores, labels, inf_time = predict(frame, session, threshold=0.2)
        
        # Draw bounding box (if any)
        for box, score, label in zip(boxes, scores, labels):
            x1, y1, x2, y2 = box.astype(int)
            cv2.rectangle(orig_img, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(orig_img, f"Rat: {score:.2f}", (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
            
            # Draw centroid
            cx = (x1 + x2) // 2
            cy = (y1 + y2) // 2
            cv2.circle(orig_img, (cx, cy), 3, (0, 0, 255), -1)
        
        # Display inference time
        cv2.putText(orig_img, f"Inference: {inf_time:.1f} ms", (10, 30),
                    cv2.FONT_HERSHEY_SIMPLEX, 1.0, (0, 255, 255), 2)
        
        cv2.imshow("Predictions", orig_img)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    
    cap.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    main()

# %% [markdown]
# # Convert to c++/TouchSript

# %%
# import torch
# import torchvision
# from torchvision.models.detection import ssdlite320_mobilenet_v3_large

# # 1. Load the model architecture without pretrained weights
# model = ssdlite320_mobilenet_v3_large(
#     weights=None,
#     num_classes=2,  # e.g., background + rat
#     weights_backbone=torchvision.models.MobileNet_V3_Large_Weights.IMAGENET1K_V1
# )

# # 2. Load your trained weights
# model_path = r"C:\Machine Learning\Rat Tracking using TensorFlow\Model.pth"
# state_dict = torch.load(model_path, map_location="cpu")
# model.load_state_dict(state_dict)
# model.eval()

# # 3. Convert the model to TorchScript using scripting
# scripted_model = torch.jit.script(model)

# # 4. Save the scripted model for C++ usage
# scripted_model.save("model.pt")
