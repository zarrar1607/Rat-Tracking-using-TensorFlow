# %% [markdown]
# # Preparing Dataset

# %% [markdown]
# ## Normal Dataset

# %%
import os
import torch
import random
import numpy as np
from PIL import Image
from torch.utils.data import Dataset

import torchvision.transforms as T

class MyRatDataset(Dataset):
    """
    A dataset that reads images and YOLO-format annotations from a folder.
    Expected structure:
        root/
          images/
            img1.jpg
            img2.jpg
            ...
          labels/
            img1.txt
            img2.txt
            ...
    Each label file should contain lines (YOLO format):
        class_id  x_center_norm  y_center_norm  width_norm  height_norm
    In this version, we also create negative samples on the fly.
    With a certain probability, we "remove" the rat(s) by filling the bounding box regions with random noise.
    The resulting image is treated as a negative sample (with no bounding boxes).
    """
    def __init__(self, root, transforms=None, negative_sample_ratio=0.3):
        """
        Args:
            root (str): Path to the subset folder (e.g., 'new_dataset/train').
                        Must contain 'images/' and 'labels/' subfolders.
            transforms (callable, optional): Transformations to apply to the PIL image.
            negative_sample_ratio (float): The probability (0 to 1) of generating a negative sample from a positive image.
        """
        self.root = root
        self.transforms = transforms
        self.negative_sample_ratio = negative_sample_ratio
        
        self.img_dir = os.path.join(root, "images")
        self.lbl_dir = os.path.join(root, "labels")
        
        # Collect image file names
        self.imgs = [f for f in os.listdir(self.img_dir)
                     if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
        self.imgs.sort()  # for consistent ordering

    def __len__(self):
        return len(self.imgs)

    def __getitem__(self, idx):
        # Load image
        img_name = self.imgs[idx]
        img_path = os.path.join(self.img_dir, img_name)
        img = Image.open(img_path).convert("RGB")
        w, h = img.size

        # Load annotations from the corresponding label file
        label_name = os.path.splitext(img_name)[0] + ".txt"
        label_path = os.path.join(self.lbl_dir, label_name)
        
        boxes = []
        labels = []
        if os.path.exists(label_path):
            with open(label_path, 'r') as f:
                for line in f:
                    parts = line.strip().split()
                    if len(parts) != 5:
                        continue
                    # YOLO format: class_id, x_center, y_center, width, height (all normalized)
                    class_id = int(parts[0]) + 1
                    x_center_norm = float(parts[1])
                    y_center_norm = float(parts[2])
                    width_norm    = float(parts[3])
                    height_norm   = float(parts[4])
                    
                    # Convert normalized coords to absolute pixel coordinates
                    x_center = x_center_norm * w
                    y_center = y_center_norm * h
                    box_width = width_norm * w
                    box_height = height_norm * h
                    x_min = x_center - box_width / 2
                    y_min = y_center - box_height / 2
                    x_max = x_center + box_width / 2
                    y_max = y_center + box_height / 2
                    boxes.append([x_min, y_min, x_max, y_max])
                    labels.append(class_id)
        
        # If no annotations, treat image as a negative sample naturally
        if len(boxes) == 0:
            boxes = torch.empty((0, 4), dtype=torch.float32)
            labels = torch.empty((0,), dtype=torch.int64)
        else:
            boxes = torch.as_tensor(boxes, dtype=torch.float32)
            labels = torch.as_tensor(labels, dtype=torch.int64)
        
        # Decide whether to generate a negative sample from this image
        # (only if there are boxes, because otherwise it's already negative)
        if boxes.shape[0] > 0 and random.random() < self.negative_sample_ratio:
            # Generate negative sample by filling each bounding box with random noise
            img = self.generate_negative_sample(img, boxes)
            # Set target to have no boxes or labels
            boxes = torch.empty((0, 4), dtype=torch.float32)
            labels = torch.empty((0,), dtype=torch.int64)
        
        image_id = torch.tensor([idx])
        if boxes.size(0) > 0:
            area = (boxes[:,2] - boxes[:,0]) * (boxes[:,3] - boxes[:,1])
        else:
            area = torch.empty((0,), dtype=torch.float32)
        iscrowd = torch.zeros((labels.shape[0],), dtype=torch.int64)
        
        target = {
            "boxes": boxes,
            "labels": labels,
            "image_id": image_id,
            "area": area,
            "iscrowd": iscrowd
        }
        
        if self.transforms:
            img = self.transforms(img)
        
        return img, target

    def generate_negative_sample(self, img, boxes):
        """
        Generate a negative sample by filling the regions of each bounding box in the image with random noise.
        Args:
            img (PIL.Image): The original image.
            boxes (Tensor): Tensor of shape [N, 4] with bounding box coordinates in absolute pixel values.
        Returns:
            PIL.Image: The image with the rat regions replaced with noise.
        """
        # Convert PIL image to NumPy array
        img_np = np.array(img)
        # Iterate through each box and fill the region with random noise
        for box in boxes:
            x_min, y_min, x_max, y_max = box.int().tolist()
            # Clip coordinates to image boundaries
            x_min = max(0, x_min)
            y_min = max(0, y_min)
            x_max = min(img_np.shape[1], x_max)
            y_max = min(img_np.shape[0], y_max)
            if x_max > x_min and y_max > y_min:
                noise = np.random.randint(0, 256, (y_max - y_min, x_max - x_min, 3), dtype=np.uint8)
                img_np[y_min:y_max, x_min:x_max, :] = noise
        # Convert back to PIL image
        return Image.fromarray(img_np)

# Example usage
if __name__ == "__main__":
    import torchvision.transforms as T
    
    # Define transforms: converting image to tensor and normalizing
    transforms = T.Compose([
        T.ToTensor(),
        T.Normalize(mean=[0.485, 0.456, 0.406],
                    std=[0.229, 0.224, 0.225])
    ])
    
    # Create dataset instance. Adjust root path as needed.
    dataset_root = "new_dataset\\train"  # Folder with subfolders: images/ and labels/
    dataset = MyRatDataset(root=dataset_root, transforms=transforms, negative_sample_ratio=0.3)
    
    # Optionally, inspect a sample
    img, target = dataset[0]
    print("Sample target:", target)
    
    # Create DataLoader
    from torch.utils.data import DataLoader
    dataloader = DataLoader(dataset, batch_size=4, shuffle=True, collate_fn=lambda batch: tuple(zip(*batch)))
    
    # Iterate over one batch
    for images, targets in dataloader:
        print(f"Batch has {len(images)} images")
        for t in targets:
            print("Boxes:", t["boxes"], "Labels:", t["labels"])
        break
# Out:
# Sample target: {'boxes': tensor([[ 19.0000, 133.2500, 168.0000, 396.7500]]), 'labels': tensor([1]), 'image_id': tensor([0]), 'area': tensor([39261.5000]), 'iscrowd': tensor([0])}
# Batch has 4 images
# Boxes: tensor([[307.0000, 157.2500, 500.0000, 319.7500]]) Labels: tensor([1])
# Boxes: tensor([[318., 317., 530., 526.]]) Labels: tensor([1])
# Boxes: tensor([[357.0000, 146.7500, 565.0000, 317.2500]]) Labels: tensor([1])
# Boxes: tensor([[269.0000, 134.9998, 442.0003, 385.9999]]) Labels: tensor([1])

# %% [markdown]
# ## Mosaic

# %%
import os
import torch
import random
import numpy as np
from PIL import Image
from torch.utils.data import Dataset
import torchvision.transforms as T
import cv2

class MyRatDatasetWithMosaic(Dataset):
    """
    A dataset that reads images and YOLO-format annotations from a folder and applies mosaic augmentation
    with a given probability. Additionally, it can convert the mosaic sample to a negative sample 
    (i.e. with bounding boxes removed) with a specified probability.
    
    Expected folder structure:
        root/
          images/
            img1.jpg
            img2.jpg
            ...
          labels/
            img1.txt
            img2.txt
            ...
    
    Each label file should contain lines (YOLO format):
        class_id  x_center_norm  y_center_norm  width_norm  height_norm

    The mosaic augmentation combines 4 images (2x2 grid) and adjusts bounding boxes accordingly.
    """
    def __init__(self, root, transforms=None, mosaic_prob=0.5, mosaic_negative_prob=0.5):
        """
        Args:
            root (str): Path to the subset folder (e.g., 'new_dataset/train').
                        Must contain 'images/' and 'labels/' subfolders.
            transforms (callable, optional): Transformations to apply to the PIL image.
            mosaic_prob (float): Probability to apply mosaic augmentation instead of normal sampling.
            mosaic_negative_prob (float): When mosaic augmentation is applied, probability to convert it to a negative sample.
        """
        self.root = root
        self.transforms = transforms
        self.mosaic_prob = mosaic_prob
        self.mosaic_negative_prob = mosaic_negative_prob
        
        self.img_dir = os.path.join(root, "images")
        self.lbl_dir = os.path.join(root, "labels")
        
        # Collect image file names
        self.imgs = [f for f in os.listdir(self.img_dir)
                     if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
        self.imgs.sort()  # for consistent ordering

    def __len__(self):
        return len(self.imgs)

    def __getitem__(self, idx):
        if random.random() < self.mosaic_prob:
            return self.mosaic_augmentation(idx)
        else:
            return self.load_single(idx)

    def load_single(self, idx):
        """Load a single image and its labels."""
        img_name = self.imgs[idx]
        img_path = os.path.join(self.img_dir, img_name)
        img = Image.open(img_path).convert("RGB")
        w, h = img.size
        boxes, labels = self.load_labels(img_name, w, h)
        target = {
            "boxes": torch.as_tensor(boxes, dtype=torch.float32) if boxes else torch.empty((0, 4), dtype=torch.float32),
            "labels": torch.as_tensor(labels, dtype=torch.int64) if labels else torch.empty((0,), dtype=torch.int64),
            "image_id": torch.tensor([idx]),
            "area": torch.as_tensor([(box[2]-box[0])*(box[3]-box[1]) for box in boxes], dtype=torch.float32) if boxes else torch.empty((0,), dtype=torch.float32),
            "iscrowd": torch.zeros((len(labels),), dtype=torch.int64) if labels else torch.empty((0,), dtype=torch.int64)
        }
        if self.transforms:
            img = self.transforms(img)
        return img, target

    def load_labels(self, img_name, w, h):
        """Load labels for a given image."""
        label_name = os.path.splitext(img_name)[0] + ".txt"
        label_path = os.path.join(self.lbl_dir, label_name)
        boxes = []
        labels = []
        if os.path.exists(label_path):
            with open(label_path, 'r') as f:
                for line in f:
                    parts = line.strip().split()
                    if len(parts) != 5:
                        continue
                    # In our convention, rat's label is 1 (we add 1 to the original if it was 0)
                    class_id = int(parts[0]) + 1
                    x_center_norm = float(parts[1])
                    y_center_norm = float(parts[2])
                    width_norm    = float(parts[3])
                    height_norm   = float(parts[4])
                    
                    x_center = x_center_norm * w
                    y_center = y_center_norm * h
                    box_width = width_norm * w
                    box_height = height_norm * h
                    x_min = x_center - box_width / 2
                    y_min = y_center - box_height / 2
                    x_max = x_center + box_width / 2
                    y_max = y_center + box_height / 2
                    boxes.append([x_min, y_min, x_max, y_max])
                    labels.append(class_id)
        return boxes, labels

    def mosaic_augmentation(self, idx, input_size=640):
        """
        Creates a mosaic image from 4 images (the current index plus 3 random indices)
        and combines their bounding boxes. Optionally, converts the mosaic sample into a negative sample.
        
        Args:
            idx (int): Index of the primary image.
            input_size (int): The size to which each image is resized before mosaic.
            
        Returns:
            img (Tensor): Mosaic image (after applying transforms).
            target (dict): Combined target with adjusted bounding boxes.
        """
        # Select 3 additional indices randomly (allow repetition if necessary)
        indices = [idx] + random.sample(range(len(self)), 3)
        
        # Create a blank mosaic image (2x2 grid) and placeholders for boxes and labels.
        mosaic_img = Image.new("RGB", (input_size * 2, input_size * 2), (128, 128, 128))
        mosaic_boxes = []
        mosaic_labels = []
        
        # Random center for mosaic (within a range to allow images to be partially outside the mosaic canvas)
        xc = int(random.uniform(input_size//2, input_size*3/2))
        yc = int(random.uniform(input_size//2, input_size*3/2))
        
        for i, index in enumerate(indices):
            # Load raw image (without transforms)
            img_name = self.imgs[index]
            img_path = os.path.join(self.img_dir, img_name)
            img = Image.open(img_path).convert("RGB")
            w, h = img.size
            boxes, labels = self.load_labels(img_name, w, h)
            
            # Resize image to input_size x input_size
            img = img.resize((input_size, input_size))
            # Adjust boxes to the resized image (scaling factors)
            if boxes:
                scale_x = input_size / w
                scale_y = input_size / h
                boxes = [[box[0]*scale_x, box[1]*scale_y, box[2]*scale_x, box[3]*scale_y] for box in boxes]
            
            # Determine placement position on the mosaic canvas
            if i == 0:  # top-left
                x1a, y1a, x2a, y2a = xc - input_size, yc - input_size, xc, yc
            elif i == 1:  # top-right
                x1a, y1a, x2a, y2a = xc, yc - input_size, xc + input_size, yc
            elif i == 2:  # bottom-left
                x1a, y1a, x2a, y2a = xc - input_size, yc, xc, yc + input_size
            elif i == 3:  # bottom-right
                x1a, y1a, x2a, y2a = xc, yc, xc + input_size, yc + input_size
            
            # Paste the resized image onto the mosaic canvas
            mosaic_img.paste(img, (x1a, y1a, x2a, y2a))
            
            # If there are boxes, adjust them to mosaic coordinates
            if boxes:
                for box in boxes:
                    new_box = [box[0] + x1a, box[1] + y1a, box[2] + x1a, box[3] + y1a]
                    mosaic_boxes.append(new_box)
                mosaic_labels.extend(labels)
        
        # Build target dictionary from mosaic annotations
        target = {
            "boxes": torch.as_tensor(mosaic_boxes, dtype=torch.float32) if mosaic_boxes else torch.empty((0, 4), dtype=torch.float32),
            "labels": torch.as_tensor(mosaic_labels, dtype=torch.int64) if mosaic_labels else torch.empty((0,), dtype=torch.int64),
            "image_id": torch.tensor([idx]),
            "area": torch.as_tensor([(box[2]-box[0])*(box[3]-box[1]) for box in mosaic_boxes], dtype=torch.float32) if mosaic_boxes else torch.empty((0,), dtype=torch.float32),
            "iscrowd": torch.zeros((len(mosaic_labels),), dtype=torch.int64) if mosaic_labels else torch.empty((0,), dtype=torch.int64)
        }
        
        # Optionally convert mosaic sample to a negative sample by filling boxes with noise.
        # Here, we apply this transformation with a probability mosaic_negative_prob.
        if random.random() < self.mosaic_negative_prob and mosaic_boxes:
            boxes_tensor = torch.as_tensor(mosaic_boxes, dtype=torch.float32)
            mosaic_img = self.fill_boxes_with_noise(mosaic_img, boxes_tensor)
            # Set targets to be empty (no boxes, no labels)
            target["boxes"] = torch.empty((0, 4), dtype=torch.float32)
            target["labels"] = torch.empty((0,), dtype=torch.int64)
            target["area"] = torch.empty((0,), dtype=torch.float32)
            target["iscrowd"] = torch.empty((0,), dtype=torch.int64)
        
        if self.transforms:
            mosaic_img = self.transforms(mosaic_img)
        
        return mosaic_img, target

    def fill_boxes_with_noise(self, img, boxes):
        """
        Fill each bounding box region in 'img' with random noise.
        Args:
            img (PIL.Image): The original image.
            boxes (Tensor): Tensor of shape [N, 4] with bounding box coordinates in absolute pixel values.
        Returns:
            PIL.Image: The image with bounding box regions replaced with random noise.
        """
        img_np = np.array(img)
        for box in boxes:
            x_min, y_min, x_max, y_max = box.int().tolist()
            x_min = max(0, x_min)
            y_min = max(0, y_min)
            x_max = min(img_np.shape[1], x_max)
            y_max = min(img_np.shape[0], y_max)
            if x_max > x_min and y_max > y_min:
                noise = np.random.randint(0, 256, (y_max - y_min, x_max - x_min, 3), dtype=np.uint8)
                img_np[y_min:y_max, x_min:x_max, :] = noise
        return Image.fromarray(img_np)

# Example usage
if __name__ == "__main__":
    import torchvision.transforms as T
    transforms = T.Compose([
        T.ToTensor(),
        T.Normalize(mean=[0.485, 0.456, 0.406],
                    std=[0.229, 0.224, 0.225])
    ])
    
    dataset_root = "new_dataset\\train"
    # Use the mosaic-enabled dataset and set mosaic_prob to 1.0 for testing,
    # and mosaic_negative_prob to, say, 0.5 to mix negative mosaic samples.
    dataset = MyRatDatasetWithMosaic(root=dataset_root, transforms=transforms, mosaic_prob=0.7, mosaic_negative_prob=0.5)
    
    from torch.utils.data import DataLoader
    dataloader = DataLoader(dataset, batch_size=2, shuffle=True, collate_fn=lambda batch: tuple(zip(*batch)))
    
    # Helper function to convert tensor to displayable image
    def tensor_to_image(tensor, mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]):
        tensor = tensor.clone().detach().cpu().numpy()
        tensor = tensor * np.array(std)[:, None, None] + np.array(mean)[:, None, None]
        tensor = np.transpose(tensor, (1, 2, 0))
        tensor = np.clip(tensor * 255, 0, 255).astype(np.uint8)
        img_bgr = cv2.cvtColor(tensor, cv2.COLOR_RGB2BGR)
        return img_bgr

    # Iterate over one batch and display images with OpenCV
    for images, targets in dataloader:
        print(f"Batch has {len(images)} images")
        for i, (img_tensor, t) in enumerate(zip(images, targets)):
            img_disp = tensor_to_image(img_tensor)
            print("Boxes:", t["boxes"], "Labels:", t["labels"])
            cv2.imshow(f"Sample {i}", img_disp)
        cv2.waitKey(0)
        cv2.destroyAllWindows()
        break
# Out:
# Batch has 2 images
# Boxes: tensor([], size=(0, 4)) Labels: tensor([], dtype=torch.int64)
# Boxes: tensor([[-250.0000,  300.5000,  -42.0000,  468.5000],
#         [ 703.0000,  317.6669,  745.9997,  373.6669],
#         [-262.0000, 1034.7500,  -89.0000, 1200.2500],
#         [ 725.6365,  805.6666,  838.3635, 1044.3335]]) Labels: tensor([1, 1, 1, 1])

# %% [markdown]
# # SDDLITE QAT

# %%
import os
import torch
import torchvision
from torch.utils.data import DataLoader
import torchvision.transforms as T
from torchvision.models.detection.ssdlite import SSDLite320_MobileNet_V3_Large_Weights
from torch.utils.tensorboard import SummaryWriter
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import torch.quantization

# Assume your custom dataset class MyRatDatasetWithMosaic is defined elsewhere.
# It should return images and targets (with keys: "boxes", "labels", etc.).
# For this example, we assume 'dataset_root' is defined (e.g., "new_dataset/train").

dataset_root = "new_dataset\\train"  # adjust as needed

# --- Define transforms ---
transforms = T.Compose([
    T.ToTensor(),
    T.Normalize(mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225])
])

# --- Create training and validation datasets and dataloaders ---
train_dataset = MyRatDatasetWithMosaic(root=dataset_root, transforms=transforms, mosaic_prob=0.8, mosaic_negative_prob=0.8)
val_dataset   = MyRatDatasetWithMosaic(root=dataset_root, transforms=transforms, mosaic_prob=0.5, mosaic_negative_prob=0.5)

train_loader = DataLoader(
    train_dataset,
    batch_size=4,
    shuffle=True,
    collate_fn=lambda batch: tuple(zip(*batch))
)

val_loader = DataLoader(
    val_dataset,
    batch_size=4,
    shuffle=False,
    collate_fn=lambda batch: tuple(zip(*batch))
)

# --- Load and modify the SSDLite detection model ---
# Initialize with weights=None so we can override num_classes,
# and load backbone weights from MobileNet_V3_Large_Weights.
model = torchvision.models.detection.ssdlite320_mobilenet_v3_large(
    weights=None,
    num_classes=2,  # 2 classes: background and rat
    weights_backbone=torchvision.models.MobileNet_V3_Large_Weights.IMAGENET1K_V1,
    box_score_thresh=0.5,   # keep detections > 0.5 confidence
    box_nms_thresh=0.3      # more aggressive NMS
)

# --- Prepare Quantization-Aware Training (QAT) ---
# Set the QAT configuration; for CPU, the 'fbgemm' backend is recommended.
model.qconfig = torch.quantization.get_default_qat_qconfig('fbgemm')
# Optionally, fuse modules here if supported (not shown for brevity)
torch.quantization.prepare_qat(model, inplace=True)
print("Model prepared for QAT.")

# --- Define optimizer and scheduler ---
optimizer = torch.optim.SGD(
    [p for p in model.parameters() if p.requires_grad],
    lr=0.005, momentum=0.9, weight_decay=0.0005
)
scheduler = StepLR(optimizer, step_size=3, gamma=0.1)

# Set up TensorBoard logging
writer = SummaryWriter(log_dir="runs/ssdlite_rat_detection_qat")

# We'll maintain only two checkpoint files: best.pth and last.pth.
best_val_loss = float('inf')
loss_gap_threshold = 0.001  # threshold for significant improvement

# Save and validate every epoch (adjust intervals as needed)
validate_interval = 1

# Helper function to force BatchNorm layers to eval mode (for val loss)
def set_bn_eval(m):
    if isinstance(m, torch.nn.BatchNorm2d):
        m.eval()

# --- Training loop with validation ---
num_epochs = 20
train_losses = []
validation_losses = []


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)


for epoch in range(num_epochs):
    model.train()
    epoch_train_loss = 0.0
    for images, targets in train_loader:
        images = [img.to(device) for img in images]
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
        
        loss_dict = model(images, targets)
        losses = sum(loss for loss in loss_dict.values())
        optimizer.zero_grad()
        losses.backward()
        optimizer.step()
        
        epoch_train_loss += losses.item()
    epoch_train_loss /= len(train_loader)
    train_losses.append(epoch_train_loss)
    writer.add_scalar("Loss/Train", epoch_train_loss, epoch+1)
    
    scheduler.step()
    
    # --- Validation Loop ---
    model.train()          # required for loss computation with targets
    model.apply(set_bn_eval)  # Force BN layers to use running stats
    epoch_val_loss = 0.0
    with torch.no_grad():
        for images, targets in val_loader:
            images = [img.to(device) for img in images]
            targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
            loss_dict = model(images, targets)
            losses = sum(loss for loss in loss_dict.values())
            epoch_val_loss += losses.item()
    epoch_val_loss /= len(val_loader)
    validation_losses.append(epoch_val_loss)
    writer.add_scalar("Loss/Val", epoch_val_loss, epoch+1)
    
    print(f"Epoch {epoch+1}/{num_epochs} - Train Loss: {epoch_train_loss:.4f}, Val Loss: {epoch_val_loss:.4f}")
    
    # Save 'last.pth' for the current epoch (but not at every epoch if desired)
    torch.save(model.state_dict(), "runs/quantized_last.pth")
    print("Saved last.pth")
    
    # Update best model if there is significant improvement
    if epoch_val_loss < best_val_loss - loss_gap_threshold:
        best_val_loss = epoch_val_loss
        torch.save(model.state_dict(), "runs/quantized_best.pth")
        print("New best model saved to best.pth")
    else:
        print("No significant improvement; best model remains unchanged.")

writer.close()

# Plot the training and validation loss curves
epochs = range(1, num_epochs + 1)
plt.plot(epochs, train_losses, label="Train Loss")
plt.plot(epochs, validation_losses, label="Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training and Validation Loss (QAT)")
plt.legend()
plt.show()
# Out:
# c:\Users\mzarrar\AppData\Local\miniconda3\envs\tf\lib\site-packages\torch\ao\quantization\observer.py:229: UserWarning: Please use quant_min and quant_max to specify the range for observers.                     reduce_range will be deprecated in a future release of PyTorch.
#   warnings.warn(
# Model prepared for QAT.
# Epoch 1/20 - Train Loss: 5.4735, Val Loss: 5.4457
# Saved last.pth
# New best model saved to best.pth
# Epoch 2/20 - Train Loss: 4.0270, Val Loss: 4.0249
# Saved last.pth
# New best model saved to best.pth
# Epoch 3/20 - Train Loss: 3.4775, Val Loss: 3.5656
# Saved last.pth
# New best model saved to best.pth
# Epoch 4/20 - Train Loss: 3.1982, Val Loss: 3.1801
# Saved last.pth
# New best model saved to best.pth
# Epoch 5/20 - Train Loss: 3.3446, Val Loss: 3.1180
# Saved last.pth
# New best model saved to best.pth
# Epoch 6/20 - Train Loss: 3.0540, Val Loss: 3.1221
# Saved last.pth
# No significant improvement; best model remains unchanged.
# Epoch 7/20 - Train Loss: 3.1615, Val Loss: 3.0917
# Saved last.pth
# New best model saved to best.pth
# Epoch 8/20 - Train Loss: 2.9168, Val Loss: 2.9809
# Saved last.pth
# New best model saved to best.pth
# Epoch 9/20 - Train Loss: 2.8755, Val Loss: 3.0973
# Saved last.pth
# No significant improvement; best model remains unchanged.
# Epoch 10/20 - Train Loss: 2.8322, Val Loss: 3.0177
# Saved last.pth
# No significant improvement; best model remains unchanged.
# Epoch 11/20 - Train Loss: 2.8698, Val Loss: 2.9002
# Saved last.pth
# New best model saved to best.pth
# Epoch 12/20 - Train Loss: 2.9413, Val Loss: 3.0563
# Saved last.pth
# No significant improvement; best model remains unchanged.
# Epoch 13/20 - Train Loss: 2.8700, Val Loss: 2.9287
# Saved last.pth
# No significant improvement; best model remains unchanged.
# Epoch 14/20 - Train Loss: 2.8576, Val Loss: 3.0422
# Saved last.pth
# No significant improvement; best model remains unchanged.
# Epoch 15/20 - Train Loss: 3.1129, Val Loss: 3.0703
# Saved last.pth
# No significant improvement; best model remains unchanged.
# Epoch 16/20 - Train Loss: 2.7574, Val Loss: 2.9783
# Saved last.pth
# No significant improvement; best model remains unchanged.
# Epoch 17/20 - Train Loss: 2.9363, Val Loss: 3.0002
# Saved last.pth
# No significant improvement; best model remains unchanged.
# Epoch 18/20 - Train Loss: 2.9287, Val Loss: 3.0110
# Saved last.pth
# No significant improvement; best model remains unchanged.
# Epoch 19/20 - Train Loss: 2.8127, Val Loss: 3.0150
# Saved last.pth
# No significant improvement; best model remains unchanged.
# Epoch 20/20 - Train Loss: 2.8938, Val Loss: 3.0785
# Saved last.pth
# No significant improvement; best model remains unchanged.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 153
#     150 plt.show()
#     152 # After training, convert the QAT model to a quantized model.
# --> 153 torch.quantization.convert(model, inplace=True)
#     154 torch.save(model.state_dict(), "quantized_ssdlite_rat_detection.pth")
#     155 print("Quantized model saved to quantized_ssdlite_rat_detection.pth")
#
# File c:\Users\mzarrar\AppData\Local\miniconda3\envs\tf\lib\site-packages\torch\ao\quantization\quantize.py:657, in convert(module, mapping, inplace, remove_qconfig, is_reference, convert_custom_config_dict, use_precomputed_fake_quant)
#     655 if not inplace:
#     656     module = copy.deepcopy(module)
# --> 657 _convert(
#     658     module,
#     659     mapping,
#     660     inplace=True,
#     661     is_reference=is_reference,
#     662     convert_custom_config_dict=convert_custom_config_dict,
#     663     use_precomputed_fake_quant=use_precomputed_fake_quant,
#     664 )
#     665 if remove_qconfig:
#     666     _remove_qconfig(module)
#
# File c:\Users\mzarrar\AppData\Local\miniconda3\envs\tf\lib\site-packages\torch\ao\quantization\quantize.py:714, in _convert(module, mapping, inplace, is_reference, convert_custom_config_dict, use_precomputed_fake_quant)
#     707 for name, mod in module.named_children():
#     708     # both fused modules and observed custom modules are
#     709     # swapped as one unit
#     710     if (
#     711         not isinstance(mod, _FusedModule)
#     712         and type_before_parametrizations(mod) not in custom_module_class_mapping
#     713     ):
# --> 714         _convert(
#     715             mod,
#     716             mapping,
#     717             True,  # inplace
#     718             is_reference,
#     719             convert_custom_config_dict,
#     720             use_precomputed_fake_quant=use_precomputed_fake_quant,
#     721         )
#     722     reassign[name] = swap_module(
#     723         mod, mapping, custom_module_class_mapping, use_precomputed_fake_quant
#     724     )
#     726 for key, value in reassign.items():
#
# File c:\Users\mzarrar\AppData\Local\miniconda3\envs\tf\lib\site-packages\torch\ao\quantization\quantize.py:714, in _convert(module, mapping, inplace, is_reference, convert_custom_config_dict, use_precomputed_fake_quant)
#     707 for name, mod in module.named_children():
#     708     # both fused modules and observed custom modules are
#     709     # swapped as one unit
#     710     if (
#     711         not isinstance(mod, _FusedModule)
#     712         and type_before_parametrizations(mod) not in custom_module_class_mapping
#     713     ):
# --> 714         _convert(
#     715             mod,
#     716             mapping,
#     717             True,  # inplace
#     718             is_reference,
#     719             convert_custom_config_dict,
#     720             use_precomputed_fake_quant=use_precomputed_fake_quant,
#     721         )
#     722     reassign[name] = swap_module(
#     723         mod, mapping, custom_module_class_mapping, use_precomputed_fake_quant
#     724     )
#     726 for key, value in reassign.items():
#
#     [... skipping similar frames: _convert at line 714 (1 times)]
#
# File c:\Users\mzarrar\AppData\Local\miniconda3\envs\tf\lib\site-packages\torch\ao\quantization\quantize.py:714, in _convert(module, mapping, inplace, is_reference, convert_custom_config_dict, use_precomputed_fake_quant)
#     707 for name, mod in module.named_children():
#     708     # both fused modules and observed custom modules are
#     709     # swapped as one unit
#     710     if (
#     711         not isinstance(mod, _FusedModule)
#     712         and type_before_parametrizations(mod) not in custom_module_class_mapping
#     713     ):
# --> 714         _convert(
#     715             mod,
#     716             mapping,
#     717             True,  # inplace
#     718             is_reference,
#     719             convert_custom_config_dict,
#     720             use_precomputed_fake_quant=use_precomputed_fake_quant,
#     721         )
#     722     reassign[name] = swap_module(
#     723         mod, mapping, custom_module_class_mapping, use_precomputed_fake_quant
#     724     )
#     726 for key, value in reassign.items():
#
# File c:\Users\mzarrar\AppData\Local\miniconda3\envs\tf\lib\site-packages\torch\ao\quantization\quantize.py:722, in _convert(module, mapping, inplace, is_reference, convert_custom_config_dict, use_precomputed_fake_quant)
#     710     if (
#     711         not isinstance(mod, _FusedModule)
#     712         and type_before_parametrizations(mod) not in custom_module_class_mapping
#     713     ):
#     714         _convert(
#     715             mod,
#     716             mapping,
#    (...)
#     720             use_precomputed_fake_quant=use_precomputed_fake_quant,
#     721         )
# --> 722     reassign[name] = swap_module(
#     723         mod, mapping, custom_module_class_mapping, use_precomputed_fake_quant
#     724     )
#     726 for key, value in reassign.items():
#     727     module._modules[key] = value
#
# File c:\Users\mzarrar\AppData\Local\miniconda3\envs\tf\lib\site-packages\torch\ao\quantization\quantize.py:764, in swap_module(mod, mapping, custom_module_class_mapping, use_precomputed_fake_quant)
#     762 sig = inspect.signature(qmod.from_float)
#     763 if "use_precomputed_fake_quant" in sig.parameters:
# --> 764     new_mod = qmod.from_float(
#     765         mod, use_precomputed_fake_quant=use_precomputed_fake_quant
#     766     )
#     767 else:
#     768     new_mod = qmod.from_float(mod)
#
# File c:\Users\mzarrar\AppData\Local\miniconda3\envs\tf\lib\site-packages\torch\ao\nn\quantized\modules\conv.py:606, in Conv2d.from_float(cls, mod, use_precomputed_fake_quant)
#     598 @classmethod
#     599 def from_float(cls, mod, use_precomputed_fake_quant=False):
#     600     r"""Creates a quantized module from a float module or qparams_dict.
#     601
#     602     Args:
#     603         mod (Module): a float module, either produced by torch.ao.quantization
#     604           utilities or provided by the user
#     605     """
# --> 606     return _ConvNd.from_float(
#     607         cls, mod, use_precomputed_fake_quant=use_precomputed_fake_quant
#     608     )
#
# File c:\Users\mzarrar\AppData\Local\miniconda3\envs\tf\lib\site-packages\torch\ao\nn\quantized\modules\conv.py:322, in _ConvNd.from_float(cls, mod, use_precomputed_fake_quant)
#     320         mod = mod[0]
#     321     weight_post_process = mod.qconfig.weight()
# --> 322 return cls.get_qconv(mod, activation_post_process, weight_post_process)
#
# File c:\Users\mzarrar\AppData\Local\miniconda3\envs\tf\lib\site-packages\torch\ao\nn\quantized\modules\conv.py:266, in _ConvNd.get_qconv(cls, mod, activation_post_process, weight_post_process)
#     254 # the __init__ call used is the one from derived classes and not the one from _ConvNd
#     255 qconv = cls(
#     256     mod.in_channels,
#     257     mod.out_channels,
#    (...)
#     264     mod.padding_mode,
#     265 )
# --> 266 qconv.set_weight_bias(qweight, mod.bias)
#     267 if (
#     268     activation_post_process is None
#     269     or activation_post_process.dtype == torch.float
#     270 ):
#     271     return qconv  # dynamic quantization doesn't need scale/zero_point
#
# File c:\Users\mzarrar\AppData\Local\miniconda3\envs\tf\lib\site-packages\torch\ao\nn\quantized\modules\conv.py:567, in Conv2d.set_weight_bias(self, w, b)
#     565 def set_weight_bias(self, w: torch.Tensor, b: Optional[torch.Tensor]) -> None:
#     566     if self.padding_mode == "zeros":
# --> 567         self._packed_params = torch.ops.quantized.conv2d_prepack(
#     568             w, b, self.stride, self.padding, self.dilation, self.groups
#     569         )
#     570     else:
#     571         self._packed_params = torch.ops.quantized.conv2d_prepack(
#     572             w, b, self.stride, _pair(0), self.dilation, self.groups
#     573         )
#
# File c:\Users\mzarrar\AppData\Local\miniconda3\envs\tf\lib\site-packages\torch\_ops.py:1123, in OpOverloadPacket.__call__(self, *args, **kwargs)
#    1121 if self._has_torchbind_op_overload and _must_dispatch_in_python(args, kwargs):
#    1122     return _call_overload_packet_from_python(self, args, kwargs)
# -> 1123 return self._op(*args, **(kwargs or {}))
#
# RuntimeError: Unsupported qscheme: per_channel_affine

# %%
import torch.quantization as quant
from torch.quantization import FakeQuantize, MinMaxObserver, MovingAverageMinMaxObserver

custom_qconfig = quant.QConfig(
    activation=FakeQuantize.with_args(observer=MovingAverageMinMaxObserver, quant_min=0, quant_max=255),
    weight=FakeQuantize.with_args(observer=MinMaxObserver, quant_min=-128, quant_max=127)
)



model.qconfig = custom_qconfig
torch.quantization.prepare_qat(model, inplace=True)
print("Model prepared for QAT with custom qconfig.")

# ... (Train your model as usual)

# After training, convert the QAT model to a quantized model.
torch.quantization.convert(model, inplace=True)
torch.save(model.state_dict(), "quantized_ssdlite_rat_detection.pth")
print("Quantized model saved to quantized_ssdlite_rat_detection.pth")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[6], line 12
#       4 custom_qconfig = quant.QConfig(
#       5     activation=FakeQuantize.with_args(observer=MovingAverageMinMaxObserver, quant_min=0, quant_max=255),
#       6     weight=FakeQuantize.with_args(observer=MinMaxObserver, quant_min=-128, quant_max=127)
#       7 )
#      11 model.qconfig = custom_qconfig
# ---> 12 torch.quantization.prepare_qat(model, inplace=True)
#      13 print("Model prepared for QAT with custom qconfig.")
#      15 # ... (Train your model as usual)
#      16
#      17 # After training, convert the QAT model to a quantized model.
#
# File c:\Users\mzarrar\AppData\Local\miniconda3\envs\tf\lib\site-packages\torch\ao\quantization\quantize.py:589, in prepare_qat(model, mapping, inplace)
#     586 if not inplace:
#     587     model = copy.deepcopy(model)
# --> 589 propagate_qconfig_(model, qconfig_dict=None)
#     590 convert(model, mapping=mapping, inplace=True, remove_qconfig=False)
#     591 prepare(model, observer_non_leaf_module_list=set(mapping.values()), inplace=True)
#
# File c:\Users\mzarrar\AppData\Local\miniconda3\envs\tf\lib\site-packages\torch\ao\quantization\quantize.py:140, in propagate_qconfig_(module, qconfig_dict, prepare_custom_config_dict)
#     138 if prepare_custom_config_dict is None:
#     139     prepare_custom_config_dict = {}
# --> 140 _propagate_qconfig_helper(
#     141     module, qconfig_dict, prepare_custom_config_dict=prepare_custom_config_dict
#     142 )
#
# File c:\Users\mzarrar\AppData\Local\miniconda3\envs\tf\lib\site-packages\torch\ao\quantization\quantize.py:104, in _propagate_qconfig_helper(module, qconfig_dict, qconfig_parent, prefix, prepare_custom_config_dict)
#     100 module_qconfig = getattr(module, "qconfig", module_qconfig)
#     102 torch.ao.quantization.qconfig._assert_valid_qconfig(module_qconfig, module)
# --> 104 qconfig_with_device_check = _add_module_to_qconfig_obs_ctr(module_qconfig, module)
#     105 module.qconfig = qconfig_with_device_check
#     107 for name, child in module.named_children():
#
# File c:\Users\mzarrar\AppData\Local\miniconda3\envs\tf\lib\site-packages\torch\ao\quantization\qconfig.py:610, in _add_module_to_qconfig_obs_ctr(qconfig, module)
#     607         return original_constructor
#     609 activation = configure_constructor_to_put_obs_on_module_device(qconfig.activation)
# --> 610 weight = configure_constructor_to_put_obs_on_module_device(qconfig.weight)
#     612 return QConfig(activation, weight)
#
# File c:\Users\mzarrar\AppData\Local\miniconda3\envs\tf\lib\site-packages\torch\ao\quantization\qconfig.py:600, in _add_module_to_qconfig_obs_ctr.<locals>.configure_constructor_to_put_obs_on_module_device(original_constructor)
#     597 try:
#     598     # check if constructor can accept factory_kwargs
#     599     check = original_constructor.with_args(factory_kwargs=None)
# --> 600     check()
#     601     return original_constructor.with_callable_args(
#     602         factory_kwargs=get_factory_kwargs_based_on_module_device
#     603     )
#     604 except AttributeError:  # qconfig doesn't have activation or weight
#
# File c:\Users\mzarrar\AppData\Local\miniconda3\envs\tf\lib\site-packages\torch\ao\quantization\observer.py:71, in _PartialWrapper.__call__(self, *args, **keywords)
#      69     if arg_name not in keywords:
#      70         keywords = {**keywords, arg_name: self.callable_args[arg_name]()}
# ---> 71 return self.p(*args, **keywords)
#
# File c:\Users\mzarrar\AppData\Local\miniconda3\envs\tf\lib\site-packages\torch\ao\quantization\observer.py:71, in _PartialWrapper.__call__(self, *args, **keywords)
#      69     if arg_name not in keywords:
#      70         keywords = {**keywords, arg_name: self.callable_args[arg_name]()}
# ---> 71 return self.p(*args, **keywords)
#
# File c:\Users\mzarrar\AppData\Local\miniconda3\envs\tf\lib\site-packages\torch\ao\quantization\fake_quantize.py:190, in FakeQuantize.__init__(self, observer, quant_min, quant_max, is_dynamic, **observer_kwargs)
#     184 if hasattr(observer, "p"):
#     185     # In case observer is _PartialWrapper, dtype can be stored in
#     186     # observer.p.keywords["dtype"]
#     187     dtype = getattr(getattr(observer, "p", {}), "keywords", {}).get(
#     188         "dtype", dtype
#     189     )
# --> 190 assert torch.iinfo(dtype).min <= quant_min, "quant_min out of bound"
#     191 assert quant_max <= torch.iinfo(dtype).max, "quant_max out of bound"
#     192 observer_kwargs.update({"quant_min": quant_min, "quant_max": quant_max})
#
# AssertionError: quant_min out of bound

# %%
def predict(image_path, model, device, threshold=0.7):
        # Load image using PIL
        img = Image.open(image_path).convert("RGB")
        orig_img = np.array(img)  # For visualization
        # Apply transforms
        img_tensor = transforms(img).to(device)
        img_tensor = img_tensor.unsqueeze(0)
        
        model.eval()
        with torch.no_grad():
            outputs = model(img_tensor)
        output = outputs[0]
        boxes = output['boxes'].cpu().numpy()
        scores = output['scores'].cpu().numpy()
        labels = output['labels'].cpu().numpy()
        
        # Filter out detections below threshold
        keep = scores >= threshold
        boxes = boxes[keep]
        scores = scores[keep]
        labels = labels[keep]
        return orig_img, boxes, scores, labels

# %% [markdown]
# # SSD Image Predict

# %%
import cv2
import torch
import torchvision
import torchvision.transforms as T
import numpy as np
from PIL import Image

# Force using CPU or GPU as desired
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Use the official backbone weights for MobileNetV3 Large
backbone_weights = torchvision.models.MobileNet_V3_Large_Weights.IMAGENET1K_V1

# For SSDLite, we set weights=None (to avoid loading detection head weights) and override num_classes=2.
model = torchvision.models.detection.ssdlite320_mobilenet_v3_large(
    weights=None,         # Do not load COCO detection weights.
    num_classes=2,        # 2 classes: background and rat.
    weights_backbone=backbone_weights  # Load pretrained backbone.
)
model.to(device)

# Load your fine-tuned weights for SSDLite (ensure these were trained for num_classes=2)
model_path = r"C:\Machine Learning\Rat Tracking using TensorFlow\FastRcNN\runs\best.pth"
model.load_state_dict(torch.load(model_path, map_location=device))
model.eval()

# For inference transforms, you can use the ones provided by the official weights.
# Here we use the default transforms from the backbone weights; you can also compose your own.
transform = T.Compose([
    T.ToTensor(),
    # If you need to normalize further, you could add normalization.
    # For SSDLite, images are expected to be scaled to [0, 1].
])

def predict(image_input, model, device, threshold=0.7):
    """
    Predict detections on a given image.
    
    Args:
        image_input (str or np.ndarray): If a string, treated as a file path; if an ndarray, assumed to be a BGR image.
        model: The detection model.
        device: The computation device.
        threshold (float): Confidence threshold.
    
    Returns:
        orig_img (np.ndarray): Original image in BGR format.
        boxes (np.ndarray): Bounding boxes.
        scores (np.ndarray): Confidence scores.
        labels (np.ndarray): Detected labels.
    """
    # Convert input to PIL image and get original for display
    if isinstance(image_input, np.ndarray):
        # image_input is a BGR frame
        pil_img = Image.fromarray(cv2.cvtColor(image_input, cv2.COLOR_BGR2RGB))
        orig_img = image_input.copy()
    elif isinstance(image_input, str):
        pil_img = Image.open(image_input).convert("RGB")
        # Convert to BGR for display
        orig_img = cv2.cvtColor(np.array(pil_img), cv2.COLOR_RGB2BGR)
    else:
        raise ValueError("Unsupported image_input type; must be str or np.ndarray.")
    
    # Apply transforms (convert PIL image to tensor)
    img_tensor = transform(pil_img).to(device)
    img_tensor = img_tensor.unsqueeze(0)  # add batch dimension
    
    with torch.no_grad():
        outputs = model(img_tensor)
    output = outputs[0]
    boxes = output['boxes'].cpu().numpy()
    scores = output['scores'].cpu().numpy()
    labels = output['labels'].cpu().numpy()
    
    # Filter detections below the threshold
    keep = scores >= threshold
    boxes = boxes[keep]
    scores = scores[keep]
    labels = labels[keep]
    
    return orig_img, boxes, scores, labels

# --- Inference on a test image ---
test_image_path = r"C:\Machine Learning\Rat Tracking using TensorFlow\FastRcNN\new_dataset\test\images\Baseline_frame_000253.jpg"
orig_img, boxes, scores, labels = predict(test_image_path, model, device, threshold=0.7)

# Draw bounding boxes on the test image using OpenCV
for box, score, label in zip(boxes, scores, labels):
    x1, y1, x2, y2 = box.astype(int)
    cv2.rectangle(orig_img, (x1, y1), (x2, y2), (0, 255, 0), 2)
    cv2.putText(orig_img, f"Rat: {score:.2f}", (x1, y1 - 10),
                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

cv2.imshow("Predictions", orig_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # SSDLite VIdeo Predict

# %%
import cv2
import torch
import torchvision
import torchvision.transforms as T
import numpy as np
from PIL import Image
import torchvision.ops as ops  # for NMS

# Define the transform (same as used during training/inference)
transform = T.Compose([
    T.ToTensor(),
    # SSDLite models usually expect pixel values scaled to [0, 1]. 
    # Additional normalization can be added if needed.
])

# Force using CPU for inference
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load the SSDLite model with MobileNetV3 Large backbone.
# Here, we initialize with no detection weights (weights=None) so we can set num_classes=2.
# We load pretrained backbone weights from MobileNet_V3_Large_Weights.
model = torchvision.models.detection.ssdlite320_mobilenet_v3_large(
    weights=None,
    num_classes=2,  # 2 classes: background (0) and rat (1)
    weights_backbone=torchvision.models.MobileNet_V3_Large_Weights.IMAGENET1K_V1
)
model.to(device)

# Load your fine-tuned SSDLite weights for rat detection.
model_path = r"C:\Machine Learning\Rat Tracking using TensorFlow\FastRcNN\runs\best.pth"
model.load_state_dict(torch.load(model_path, map_location=device))
model.eval()

def predict(image_input, model, device, threshold=0.7, iou_threshold=0.3):
    """
    Predict detections on a given image input.
    
    Args:
        image_input (str or np.ndarray): If string, treated as a file path;
                                           if np.ndarray, treated as an OpenCV BGR image.
        model: The SSDLite detection model.
        device: Computation device.
        threshold (float): Confidence threshold for filtering detections.
        iou_threshold (float): IoU threshold for non-max suppression.
    
    Returns:
        orig_img (np.ndarray): The original image in BGR format.
        boxes (np.ndarray): Array of final bounding boxes.
        scores (np.ndarray): Detection confidence scores.
        labels (np.ndarray): Detected labels.
        inference_time_ms (float): Inference time in milliseconds.
    """
    # Convert input to PIL image and get original image for display
    if isinstance(image_input, np.ndarray):
        # image_input is a frame in BGR format
        pil_img = Image.fromarray(cv2.cvtColor(image_input, cv2.COLOR_BGR2RGB))
        orig_img = image_input.copy()  # keep a copy in BGR for display
    elif isinstance(image_input, str):
        pil_img = Image.open(image_input).convert("RGB")
        orig_img = cv2.cvtColor(np.array(pil_img), cv2.COLOR_RGB2BGR)
    else:
        raise ValueError("Unsupported image_input type. Must be str or np.ndarray.")
    
    # Apply transforms to the PIL image
    img_tensor = transform(pil_img).to(device)
    img_tensor = img_tensor.unsqueeze(0)  # add batch dimension

    # Measure inference time using OpenCV ticks
    start = cv2.getTickCount()
    with torch.no_grad():
        outputs = model(img_tensor)
    end = cv2.getTickCount()
    inference_time_ms = (end - start) / cv2.getTickFrequency() * 1000.0

    output = outputs[0]
    boxes = output['boxes'].cpu().numpy()
    scores = output['scores'].cpu().numpy()
    labels = output['labels'].cpu().numpy()

    # Filter out detections below threshold
    keep = scores >= threshold
    boxes = boxes[keep]
    scores = scores[keep]
    labels = labels[keep]

    # Apply Non-Maximum Suppression (per class)
    if boxes.shape[0] > 0:
        final_boxes = []
        final_scores = []
        final_labels = []
        unique_labels = np.unique(labels)
        for cls in unique_labels:
            inds = np.where(labels == cls)[0]
            boxes_cls = torch.tensor(boxes[inds])
            scores_cls = torch.tensor(scores[inds])
            keep_inds = ops.nms(boxes_cls, scores_cls, iou_threshold)
            final_boxes.append(boxes_cls[keep_inds])
            final_scores.append(scores_cls[keep_inds])
            final_labels.append(torch.tensor([cls] * len(keep_inds)))
        if final_boxes:
            boxes = torch.cat(final_boxes).numpy()
            scores = torch.cat(final_scores).numpy()
            labels = torch.cat(final_labels).numpy()
    else:
        boxes = np.empty((0, 4))
        scores = np.empty((0,))
        labels = np.empty((0,))

    return orig_img, boxes, scores, labels, inference_time_ms

def main():
    # video_path = r"C:\Machine Learning\Rat Tracking using TensorFlow\Video\BaselineDark.mp4"
    # video_path = r"C:\Machine Learning\Rat Tracking using TensorFlow\Video\Baseline.mp4"
    video_path = r"C:\Machine Learning\Rat Tracking using TensorFlow\Video\TestFile_video.mp4"
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"Error opening video file: {video_path}")
        return

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Run prediction on the current frame (which is a numpy array in BGR format)
        orig_img, boxes, scores, labels, inf_time = predict(frame, model, device, threshold=0.4, iou_threshold=0.0)
        print("Labels:", labels)
        print("Inference time (ms):", inf_time)

        # Draw bounding boxes and labels on the original image
        for box, score, label in zip(boxes, scores, labels):
            x1, y1, x2, y2 = box.astype(int)
            cv2.rectangle(orig_img, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(orig_img, f"Rat: {score:.2f}", (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
        
        # Draw inference time on the frame
        cv2.putText(orig_img, f"Inference: {inf_time:.1f} ms", (10, 30),
                    cv2.FONT_HERSHEY_SIMPLEX, 1.0, (0, 255, 255), 2)
        
        cv2.imshow("Predictions", orig_img)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    main()
# Out:
# Labels: [1]
# Inference time (ms): 25.4311
# Labels: [1]
# Inference time (ms): 38.226499999999994
# Labels: [1]
# Inference time (ms): 63.9435
# Labels: [1]
# Inference time (ms): 41.542
# Labels: [1]
# Inference time (ms): 29.4905
# Labels: [1]
# Inference time (ms): 28.6748
# Labels: [1]
# Inference time (ms): 30.0933
# Labels: [1]
# Inference time (ms): 29.0109
# Labels: [1]
# Inference time (ms): 25.433600000000002
# Labels: [1]
# Inference time (ms): 19.9436
# Labels: [1]
# Inference time (ms): 20.465899999999998
# Labels: [1]
# Inference time (ms): 20.1942
# Labels: [1]
# Inference time (ms): 19.9753
# Labels: [1]
# Inference time (ms): 21.0155
# Labels: [1]
# Inference time (ms): 20.9315
# Labels: [1]
# Inference time (ms): 20.939
# Labels: [1]
# Inference time (ms): 19.9213
# Labels: [1]
# Inference time (ms): 20.527299999999997
# Labels: [1]
# Inference time (ms): 19.7588
# Labels: [1]
# Inference time (ms): 19.9356
# Labels: [1]
# Inference time (ms): 19.976399999999998
# Labels: [1]
# Inference time (ms): 20.4007
# Labels: [1]
# Inference time (ms): 20.0286
# Labels: [1]
# Inference time (ms): 20.391
# Labels: [1]
# Inference time (ms): 21.8924
# Labels: [1]
# Inference time (ms): 21.5231
# Labels: [1]
# Inference time (ms): 21.1558
# Labels: [1]
# Inference time (ms): 21.3969
# Labels: [1]
# Inference time (ms): 20.8015
# Labels: [1]
# Inference time (ms): 22.1577
# Labels: [1]
# Inference time (ms): 20.5566
# Labels: [1]
# Inference time (ms): 20.3838
# Labels: [1]
# Inference time (ms): 20.090799999999998
# Labels: [1]
# Inference time (ms): 22.2425
# Labels: [1]
# Inference time (ms): 22.0858
# Labels: [1]
# Inference time (ms): 20.1769
# Labels: [1]
# Inference time (ms): 20.9594
# Labels: []
# Inference time (ms): 20.3816
# Labels: [1]
# Inference time (ms): 20.660899999999998
# Labels: [1]
# Inference time (ms): 20.4327
# Labels: [1]
# Inference time (ms): 20.4619
# Labels: [1]
# Inference time (ms): 20.4243
# Labels: [1]
# Inference time (ms): 19.9101
# Labels: [1]
# Inference time (ms): 19.335
# Labels: [1]
# Inference time (ms): 20.1597
# Labels: [1]
# Inference time (ms): 20.0314
# Labels: [1]
# Inference time (ms): 19.5446
# Labels: [1]
# Inference time (ms): 19.4716
# Labels: [1]
# Inference time (ms): 19.5396
# Labels: [1]
# Inference time (ms): 20.4737
# Labels: [1]
# Inference time (ms): 20.1248
# Labels: [1]
# Inference time (ms): 20.047800000000002
# Labels: [1]
# Inference time (ms): 20.0248
# Labels: [1]
# Inference time (ms): 20.7072
# Labels: [1]
# Inference time (ms): 20.1665
# Labels: [1]
# Inference time (ms): 19.5606
# Labels: [1]
# Inference time (ms): 19.7518
# Labels: [1]
# Inference time (ms): 21.0494
# Labels: [1]
# Inference time (ms): 20.540599999999998
# Labels: []
# Inference time (ms): 20.5046
# Labels: [1]
# Inference time (ms): 19.9687
# Labels: [1]
# Inference time (ms): 20.3762
# Labels: [1]
# Inference time (ms): 20.398300000000003
# Labels: [1]
# Inference time (ms): 21.673499999999997
# Labels: [1]
# Inference time (ms): 21.5773
# Labels: [1]
# Inference time (ms): 22.3286
# Labels: [1]
# Inference time (ms): 20.7504
# Labels: [1]
# Inference time (ms): 20.532700000000002
# Labels: [1]
# Inference time (ms): 20.1986
# Labels: [1]
# Inference time (ms): 20.5794
# Labels: [1]
# Inference time (ms): 20.416400000000003
# Labels: [1]
# Inference time (ms): 19.811100000000003
# Labels: [1]
# Inference time (ms): 20.0456
# Labels: [1]
# Inference time (ms): 21.5974
# Labels: [1]
# Inference time (ms): 22.4241
# Labels: [1]
# Inference time (ms): 20.8003
# Labels: [1]
# Inference time (ms): 20.7847
# Labels: [1]
# Inference time (ms): 20.3872
# Labels: [1]
# Inference time (ms): 21.752
# Labels: [1]
# Inference time (ms): 19.726899999999997
# Labels: [1]
# Inference time (ms): 19.8614
# Labels: [1]
# Inference time (ms): 20.4695
# Labels: []
# Inference time (ms): 20.9412
# Labels: []
# Inference time (ms): 21.711000000000002
# Labels: []
# Inference time (ms): 21.9789
# Labels: [1]
# Inference time (ms): 20.863400000000002
# Labels: [1]
# Inference time (ms): 19.8361
# Labels: []
# Inference time (ms): 19.612299999999998
# Labels: [1]
# Inference time (ms): 19.4384
# Labels: [1]
# Inference time (ms): 19.3262
# Labels: [1]
# Inference time (ms): 19.492099999999997
# Labels: [1]
# Inference time (ms): 19.437800000000003
# Labels: [1]
# Inference time (ms): 19.4998
# Labels: [1]
# Inference time (ms): 19.5245
# Labels: []
# Inference time (ms): 20.1433
# Labels: []
# Inference time (ms): 20.0506
# Labels: [1]
# Inference time (ms): 19.5652
# Labels: [1]
# Inference time (ms): 19.5301
# Labels: [1]
# Inference time (ms): 19.6355
# Labels: []
# Inference time (ms): 21.0322
# Labels: []
# Inference time (ms): 19.4189
# Labels: []
# Inference time (ms): 19.347099999999998
# Labels: []
# Inference time (ms): 19.165100000000002
# Labels: [1]
# Inference time (ms): 20.0563
# Labels: [1]
# Inference time (ms): 20.2723
# Labels: []
# Inference time (ms): 20.223100000000002
# Labels: [1]
# Inference time (ms): 19.9147
# Labels: [1]
# Inference time (ms): 19.413300000000003
# Labels: [1]
# Inference time (ms): 19.8233
# Labels: [1]
# Inference time (ms): 19.4707
# Labels: [1]
# Inference time (ms): 19.3967
# Labels: [1]
# Inference time (ms): 19.3803
# Labels: [1]
# Inference time (ms): 20.8521
# Labels: [1]
# Inference time (ms): 19.4642
# Labels: [1]
# Inference time (ms): 19.6618
# Labels: [1]
# Inference time (ms): 20.1356
# Labels: [1]
# Inference time (ms): 20.5598
# Labels: [1]
# Inference time (ms): 19.5412
# Labels: [1]
# Inference time (ms): 19.5793
# Labels: [1]
# Inference time (ms): 19.595100000000002
# Labels: [1]
# Inference time (ms): 21.024
# Labels: [1]
# Inference time (ms): 19.5067
# Labels: [1]
# Inference time (ms): 19.3329
# Labels: [1]
# Inference time (ms): 19.4339
# Labels: [1]
# Inference time (ms): 19.9968
# Labels: [1]
# Inference time (ms): 20.0764
# Labels: [1]
# Inference time (ms): 19.6556
# Labels: [1]
# Inference time (ms): 20.0893
# Labels: [1]
# Inference time (ms): 19.5263
# Labels: [1]
# Inference time (ms): 19.229799999999997
# Labels: [1]
# Inference time (ms): 19.814600000000002
# Labels: [1]
# Inference time (ms): 19.841
# Labels: [1]
# Inference time (ms): 19.9604
# Labels: [1]
# Inference time (ms): 20.3349
# Labels: [1]
# Inference time (ms): 20.0415
# Labels: [1]
# Inference time (ms): 19.5794
# Labels: [1]
# Inference time (ms): 19.5714
# Labels: [1]
# Inference time (ms): 19.4616
# Labels: [1]
# Inference time (ms): 19.6011
# Labels: [1]
# Inference time (ms): 19.452199999999998
# Labels: [1]
# Inference time (ms): 19.393400000000003
# Labels: [1]
# Inference time (ms): 19.4726
# Labels: [1]
# Inference time (ms): 19.892400000000002
# Labels: [1]
# Inference time (ms): 19.684
# Labels: [1]
# Inference time (ms): 20.1437
# Labels: [1]
# Inference time (ms): 19.6042
# Labels: [1]
# Inference time (ms): 19.6118
# Labels: [1]
# Inference time (ms): 19.2983
# Labels: [1]
# Inference time (ms): 20.2332
# Labels: [1]
# Inference time (ms): 19.6476
# Labels: [1]
# Inference time (ms): 19.325599999999998
# Labels: [1]
# Inference time (ms): 19.7075
# Labels: [1]
# Inference time (ms): 20.2568
# Labels: [1]
# Inference time (ms): 19.3735
# Labels: [1]
# Inference time (ms): 19.535400000000003
# Labels: [1]
# Inference time (ms): 20.234599999999997
# Labels: [1]
# Inference time (ms): 19.5154
# Labels: [1]
# Inference time (ms): 19.4233
# Labels: [1]
# Inference time (ms): 19.6006
# Labels: [1]
# Inference time (ms): 19.3473
# Labels: [1]
# Inference time (ms): 19.2333
# Labels: []
# Inference time (ms): 19.5076
# Labels: [1]
# Inference time (ms): 20.7021
# Labels: [1]
# Inference time (ms): 20.4042
# Labels: [1]
# Inference time (ms): 19.4847
# Labels: [1]
# Inference time (ms): 19.5183
# Labels: [1]
# Inference time (ms): 19.4969
# Labels: [1]
# Inference time (ms): 19.3362
# Labels: [1]
# Inference time (ms): 20.9992
# Labels: [1]
# Inference time (ms): 19.6353
# Labels: [1]
# Inference time (ms): 19.595399999999998
# Labels: [1]
# Inference time (ms): 19.7223
# Labels: [1]
# Inference time (ms): 19.9711
# Labels: [1]
# Inference time (ms): 19.5151
# Labels: [1]
# Inference time (ms): 19.6989
# Labels: [1]
# Inference time (ms): 19.249499999999998
# Labels: [1]
# Inference time (ms): 19.414299999999997
# Labels: [1]
# Inference time (ms): 19.8119
# Labels: [1]
# Inference time (ms): 19.3394
# Labels: [1]
# Inference time (ms): 19.3488
# Labels: [1]
# Inference time (ms): 19.842
# Labels: [1]
# Inference time (ms): 20.4724
# Labels: [1]
# Inference time (ms): 19.552
# Labels: [1]
# Inference time (ms): 19.9964
# Labels: [1]
# Inference time (ms): 19.6319
# Labels: [1]
# Inference time (ms): 19.479400000000002
# Labels: [1]
# Inference time (ms): 19.4619
# Labels: [1]
# Inference time (ms): 19.457700000000003
# Labels: [1]
# Inference time (ms): 19.104400000000002
# Labels: [1]
# Inference time (ms): 19.2575
# Labels: [1]
# Inference time (ms): 19.3398
# Labels: [1]
# Inference time (ms): 19.6682
# Labels: [1]
# Inference time (ms): 20.0625
# Labels: [1]
# Inference time (ms): 19.3326
# Labels: [1]
# Inference time (ms): 19.517500000000002
# Labels: [1]
# Inference time (ms): 19.5502
# Labels: [1]
# Inference time (ms): 19.514
# Labels: [1]
# Inference time (ms): 19.7271
# Labels: [1]
# Inference time (ms): 19.396900000000002
# Labels: [1]
# Inference time (ms): 19.2733
# Labels: [1]
# Inference time (ms): 19.792
# Labels: [1]
# Inference time (ms): 19.978099999999998
# Labels: [1]
# Inference time (ms): 19.4597
# Labels: [1]
# Inference time (ms): 20.2728
# Labels: [1]
# Inference time (ms): 20.7624
# Labels: [1]
# Inference time (ms): 19.0321
# Labels: [1]
# Inference time (ms): 19.6629
# Labels: [1]
# Inference time (ms): 20.7104
# Labels: [1]
# Inference time (ms): 22.6478
# Labels: [1]
# Inference time (ms): 19.33
# Labels: [1]
# Inference time (ms): 19.7288
# Labels: [1]
# Inference time (ms): 20.585800000000003
# Labels: [1]
# Inference time (ms): 19.6746
# Labels: [1]
# Inference time (ms): 20.363
# Labels: [1]
# Inference time (ms): 20.457
# Labels: [1]
# Inference time (ms): 19.4111
# Labels: [1]
# Inference time (ms): 19.684
# Labels: [1]
# Inference time (ms): 19.704800000000002
# Labels: [1]
# Inference time (ms): 19.9413
# Labels: [1]
# Inference time (ms): 19.5337
# Labels: [1]
# Inference time (ms): 19.4676
# Labels: [1]
# Inference time (ms): 19.7191
# Labels: [1]
# Inference time (ms): 19.515600000000003
# Labels: [1]
# Inference time (ms): 19.5154
# Labels: [1]
# Inference time (ms): 20.2275
# Labels: [1]
# Inference time (ms): 20.435200000000002
# Labels: [1]
# Inference time (ms): 19.485
# Labels: [1]
# Inference time (ms): 19.5357
# Labels: [1]
# Inference time (ms): 20.889499999999998
# Labels: [1]
# Inference time (ms): 19.3203
# Labels: [1]
# Inference time (ms): 19.4761
# Labels: [1]
# Inference time (ms): 20.283099999999997
# Labels: [1]
# Inference time (ms): 19.602899999999998
# Labels: [1]
# Inference time (ms): 19.7149
# Labels: [1]
# Inference time (ms): 19.8282
# Labels: [1]
# Inference time (ms): 20.5518
# Labels: [1]
# Inference time (ms): 19.5919
# Labels: [1]
# Inference time (ms): 19.4566
# Labels: [1]
# Inference time (ms): 19.9831
# Labels: [1]
# Inference time (ms): 21.8893
# Labels: [1]
# Inference time (ms): 19.8787
# Labels: []
# Inference time (ms): 19.5425
# Labels: [1]
# Inference time (ms): 19.482200000000002
# Labels: [1]
# Inference time (ms): 20.0505
# Labels: [1]
# Inference time (ms): 19.4337
# Labels: []
# Inference time (ms): 20.7667
# Labels: []
# Inference time (ms): 20.0179
# Labels: []
# Inference time (ms): 19.4676
# Labels: [1]
# Inference time (ms): 19.735599999999998
# Labels: [1]
# Inference time (ms): 19.5321
# Labels: [1]
# Inference time (ms): 19.4262
# Labels: [1]
# Inference time (ms): 19.4678
# Labels: []
# Inference time (ms): 19.5757
# Labels: [1]
# Inference time (ms): 19.571
# Labels: [1]
# Inference time (ms): 19.847
# Labels: [1]
# Inference time (ms): 19.767699999999998
# Labels: [1]
# Inference time (ms): 18.892200000000003
# Labels: []
# Inference time (ms): 19.369
# Labels: []
# Inference time (ms): 19.496
# Labels: [1]
# Inference time (ms): 19.5194
# Labels: [1]
# Inference time (ms): 21.1248
# Labels: [1]
# Inference time (ms): 19.5425
# Labels: [1]
# Inference time (ms): 19.487399999999997
# Labels: [1]
# Inference time (ms): 19.476
# Labels: [1]
# Inference time (ms): 20.1394
# Labels: [1]
# Inference time (ms): 19.7671
# Labels: [1]
# Inference time (ms): 18.979599999999998
# Labels: [1]
# Inference time (ms): 19.8844
# Labels: [1]
# Inference time (ms): 18.9855
# Labels: [1]
# Inference time (ms): 21.0171
# Labels: [1]
# Inference time (ms): 19.3773
# Labels: [1]
# Inference time (ms): 19.490299999999998
# Labels: [1]
# Inference time (ms): 19.4135
# Labels: [1]
# Inference time (ms): 19.7085
# Labels: [1]
# Inference time (ms): 19.9389
# Labels: [1]
# Inference time (ms): 20.2491
# Labels: [1]
# Inference time (ms): 19.2193
# Labels: [1]
# Inference time (ms): 19.241
# Labels: [1]
# Inference time (ms): 20.5932
# Labels: [1]
# Inference time (ms): 19.403299999999998
# Labels: [1]
# Inference time (ms): 19.369899999999998
# Labels: [1]
# Inference time (ms): 19.6337
# Labels: [1]
# Inference time (ms): 19.5894
# Labels: [1]
# Inference time (ms): 20.3262
# Labels: [1]
# Inference time (ms): 20.3173
# Labels: [1]
# Inference time (ms): 19.2511
# Labels: [1]
# Inference time (ms): 20.0874
# Labels: [1]
# Inference time (ms): 19.4542
# Labels: [1]
# Inference time (ms): 20.1798
# Labels: [1]
# Inference time (ms): 19.677799999999998
# Labels: [1]
# Inference time (ms): 19.8079
# Labels: [1]
# Inference time (ms): 19.576900000000002
# Labels: [1]
# Inference time (ms): 19.6934
# Labels: [1]
# Inference time (ms): 20.3305
# Labels: [1]
# Inference time (ms): 20.0509
# Labels: [1]
# Inference time (ms): 19.970499999999998
# Labels: [1]
# Inference time (ms): 19.5239
# Labels: [1]
# Inference time (ms): 19.4484
# Labels: [1]
# Inference time (ms): 19.1787
# Labels: [1]
# Inference time (ms): 19.3208
# Labels: [1]
# Inference time (ms): 19.9796
# Labels: [1]
# Inference time (ms): 19.6766
# Labels: [1]
# Inference time (ms): 20.5329
# Labels: [1]
# Inference time (ms): 19.471700000000002
# Labels: [1]
# Inference time (ms): 19.9453
# Labels: [1]
# Inference time (ms): 18.8368
# Labels: [1]
# Inference time (ms): 19.3208
# Labels: [1]
# Inference time (ms): 19.4069
# Labels: [1]
# Inference time (ms): 19.4441
# Labels: [1]
# Inference time (ms): 19.509900000000002
# Labels: [1]
# Inference time (ms): 19.4836
# Labels: [1]
# Inference time (ms): 19.6416
# Labels: [1]
# Inference time (ms): 19.0455
# Labels: [1]
# Inference time (ms): 19.5141
# Labels: [1]
# Inference time (ms): 19.6667
# Labels: [1]
# Inference time (ms): 19.8741
# Labels: [1]
# Inference time (ms): 19.9233
# Labels: [1]
# Inference time (ms): 19.6257
# Labels: [1]
# Inference time (ms): 19.486
# Labels: [1]
# Inference time (ms): 19.755000000000003
# Labels: [1]
# Inference time (ms): 19.3321
# Labels: [1]
# Inference time (ms): 19.5721
# Labels: [1]
# Inference time (ms): 19.8039
# Labels: [1]
# Inference time (ms): 20.640700000000002
# Labels: [1]
# Inference time (ms): 20.038899999999998
# Labels: [1]
# Inference time (ms): 18.7772
# Labels: []
# Inference time (ms): 18.927699999999998
# Labels: [1]
# Inference time (ms): 19.4848
# Labels: [1]
# Inference time (ms): 19.1125
# Labels: [1]
# Inference time (ms): 19.4299
# Labels: [1]
# Inference time (ms): 19.4655
# Labels: [1]
# Inference time (ms): 19.1446
# Labels: [1]
# Inference time (ms): 19.2773
# Labels: [1]
# Inference time (ms): 19.767500000000002
# Labels: [1]
# Inference time (ms): 19.5412
# Labels: [1]
# Inference time (ms): 19.609499999999997
# Labels: [1]
# Inference time (ms): 19.596100000000003
# Labels: [1]
# Inference time (ms): 19.743
# Labels: [1]
# Inference time (ms): 19.5382
# Labels: [1]
# Inference time (ms): 19.5659
# Labels: [1]
# Inference time (ms): 19.2892
# Labels: [1]
# Inference time (ms): 19.3085
# Labels: [1]
# Inference time (ms): 19.384800000000002
# Labels: [1]
# Inference time (ms): 19.447499999999998
# Labels: [1]
# Inference time (ms): 19.509900000000002
# Labels: [1]
# Inference time (ms): 19.6466
# Labels: [1]
# Inference time (ms): 19.6889
# Labels: [1]
# Inference time (ms): 20.100900000000003
# Labels: [1]
# Inference time (ms): 19.3889
# Labels: [1]
# Inference time (ms): 19.4811
# Labels: [1]
# Inference time (ms): 18.959799999999998
# Labels: [1]
# Inference time (ms): 19.4017
# Labels: [1]
# Inference time (ms): 19.3094
# Labels: [1]
# Inference time (ms): 19.6036
# Labels: [1]
# Inference time (ms): 20.1209
# Labels: [1]
# Inference time (ms): 19.2894
# Labels: [1]
# Inference time (ms): 19.404600000000002
# Labels: [1]
# Inference time (ms): 19.3144
# Labels: [1]
# Inference time (ms): 19.9216
# Labels: [1]
# Inference time (ms): 20.0275
# Labels: [1]
# Inference time (ms): 19.5092
# Labels: [1]
# Inference time (ms): 19.261400000000002
# Labels: [1]
# Inference time (ms): 20.1243
# Labels: [1]
# Inference time (ms): 21.8008
# Labels: [1]
# Inference time (ms): 19.0962
# Labels: [1]
# Inference time (ms): 20.2189
# Labels: [1]
# Inference time (ms): 19.704800000000002
# Labels: []
# Inference time (ms): 21.398699999999998
# Labels: []
# Inference time (ms): 19.491999999999997
# Labels: [1]
# Inference time (ms): 19.2761
# Labels: [1]
# Inference time (ms): 19.8843
# Labels: []
# Inference time (ms): 19.3738
# Labels: [1]
# Inference time (ms): 21.3027
# Labels: [1]
# Inference time (ms): 19.2336
# Labels: [1]
# Inference time (ms): 19.572400000000002
# Labels: [1]
# Inference time (ms): 19.505499999999998
# Labels: [1]
# Inference time (ms): 19.3093
# Labels: [1]
# Inference time (ms): 19.4376
# Labels: [1]
# Inference time (ms): 19.518
# Labels: [1]
# Inference time (ms): 19.9521
# Labels: [1]
# Inference time (ms): 19.6904
# Labels: [1]
# Inference time (ms): 19.8237
# Labels: [1]
# Inference time (ms): 19.8702
# Labels: [1]
# Inference time (ms): 19.845000000000002
# Labels: [1]
# Inference time (ms): 19.4331
# Labels: [1]
# Inference time (ms): 18.9834
# Labels: [1]
# Inference time (ms): 20.1328
# Labels: [1]
# Inference time (ms): 19.4771
# Labels: [1]
# Inference time (ms): 19.1676
# Labels: [1]
# Inference time (ms): 19.5225
# Labels: [1]
# Inference time (ms): 19.4362
# Labels: [1]
# Inference time (ms): 22.0962
# Labels: [1]
# Inference time (ms): 19.216
# Labels: [1]
# Inference time (ms): 20.3695
# Labels: [1]
# Inference time (ms): 19.4221
# Labels: [1]
# Inference time (ms): 19.8546
# Labels: [1]
# Inference time (ms): 18.9636
# Labels: [1]
# Inference time (ms): 20.296100000000003
# Labels: [1]
# Inference time (ms): 19.687900000000003
# Labels: [1]
# Inference time (ms): 19.257
# Labels: [1]
# Inference time (ms): 19.712400000000002
# Labels: [1]
# Inference time (ms): 19.9069
# Labels: [1]
# Inference time (ms): 19.567700000000002
# Labels: [1]
# Inference time (ms): 19.5029
# Labels: [1]
# Inference time (ms): 19.086100000000002
# Labels: [1]
# Inference time (ms): 19.627399999999998
# Labels: [1]
# Inference time (ms): 19.4381
# Labels: [1]
# Inference time (ms): 19.6023
# Labels: [1]
# Inference time (ms): 19.742900000000002
# Labels: [1]
# Inference time (ms): 19.4099
# Labels: [1]
# Inference time (ms): 19.017300000000002
# Labels: [1]
# Inference time (ms): 20.201
# Labels: [1]
# Inference time (ms): 19.470299999999998
# Labels: [1]
# Inference time (ms): 19.067400000000003
# Labels: [1]
# Inference time (ms): 20.0733
# Labels: [1]
# Inference time (ms): 19.459400000000002
# Labels: [1]
# Inference time (ms): 19.5959
# Labels: [1]
# Inference time (ms): 19.162200000000002
# Labels: [1]
# Inference time (ms): 19.505399999999998
# Labels: [1]
# Inference time (ms): 19.4774
# Labels: [1]
# Inference time (ms): 19.6255
# Labels: [1]
# Inference time (ms): 19.6009
# Labels: [1]
# Inference time (ms): 19.8724
# Labels: [1]
# Inference time (ms): 19.897399999999998
# Labels: [1]
# Inference time (ms): 19.6414
# Labels: [1]
# Inference time (ms): 21.326500000000003
# Labels: [1]
# Inference time (ms): 20.2068
# Labels: [1]
# Inference time (ms): 20.7575
# Labels: [1]
# Inference time (ms): 20.503400000000003
# Labels: [1]
# Inference time (ms): 19.2907
# Labels: [1]
# Inference time (ms): 19.732699999999998
# Labels: [1]
# Inference time (ms): 20.067800000000002
# Labels: [1]
# Inference time (ms): 20.2987
# Labels: [1]
# Inference time (ms): 20.4928
# Labels: [1]
# Inference time (ms): 19.592499999999998
# Labels: [1]
# Inference time (ms): 20.0001
# Labels: [1]
# Inference time (ms): 19.5842
# Labels: [1]
# Inference time (ms): 19.3234
# Labels: [1]
# Inference time (ms): 19.759700000000002
# Labels: [1]
# Inference time (ms): 19.110200000000003
# Labels: [1]
# Inference time (ms): 19.7647
# Labels: [1]
# Inference time (ms): 19.817700000000002
# Labels: [1]
# Inference time (ms): 20.2668
# Labels: [1]
# Inference time (ms): 19.5741
# Labels: [1]
# Inference time (ms): 19.3787
# Labels: [1]
# Inference time (ms): 19.197
# Labels: [1]
# Inference time (ms): 19.451900000000002
# Labels: [1]
# Inference time (ms): 18.8672
# Labels: [1]
# Inference time (ms): 19.4118
# Labels: [1]
# Inference time (ms): 20.951
# Labels: [1]
# Inference time (ms): 19.7253
# Labels: [1]
# Inference time (ms): 18.9444
# Labels: [1]
# Inference time (ms): 19.4659
# Labels: [1]
# Inference time (ms): 20.2075
# Labels: [1]
# Inference time (ms): 20.0451
# Labels: [1]
# Inference time (ms): 19.4487
# Labels: [1]
# Inference time (ms): 19.6706
# Labels: [1]
# Inference time (ms): 19.7792
# Labels: [1]
# Inference time (ms): 19.2838
# Labels: [1]
# Inference time (ms): 19.202299999999997
# Labels: [1]
# Inference time (ms): 19.257199999999997
# Labels: [1]
# Inference time (ms): 19.32
# Labels: [1]
# Inference time (ms): 19.458799999999997
# Labels: [1]
# Inference time (ms): 19.410899999999998
# Labels: [1]
# Inference time (ms): 20.3584
# Labels: [1]
# Inference time (ms): 19.6109
# Labels: [1]
# Inference time (ms): 19.6058
# Labels: [1]
# Inference time (ms): 19.5386
# Labels: [1]
# Inference time (ms): 19.652099999999997
# Labels: [1]
# Inference time (ms): 19.447699999999998
# Labels: [1]
# Inference time (ms): 19.5917
# Labels: [1]
# Inference time (ms): 19.3676
# Labels: [1]
# Inference time (ms): 19.7587
# Labels: [1]
# Inference time (ms): 20.6897
# Labels: [1]
# Inference time (ms): 19.894
# Labels: [1]
# Inference time (ms): 19.6687
# Labels: [1]
# Inference time (ms): 19.4969
# Labels: [1]
# Inference time (ms): 20.2034
# Labels: [1]
# Inference time (ms): 19.662499999999998
# Labels: [1]
# Inference time (ms): 18.9087
# Labels: [1]
# Inference time (ms): 19.6039
# Labels: []
# Inference time (ms): 19.8232
# Labels: []
# Inference time (ms): 19.2191
# Labels: []
# Inference time (ms): 18.9706
# Labels: []
# Inference time (ms): 19.9037
# Labels: []
# Inference time (ms): 19.3362
# Labels: []
# Inference time (ms): 19.3087
# Labels: [1]
# Inference time (ms): 20.1128
# Labels: [1]
# Inference time (ms): 19.6018
# Labels: [1]
# Inference time (ms): 18.8829
# Labels: [1]
# Inference time (ms): 21.9473
# Labels: [1]
# Inference time (ms): 20.561
# Labels: [1]
# Inference time (ms): 19.7189
# Labels: [1]
# Inference time (ms): 19.1153
# Labels: []
# Inference time (ms): 19.0855
# Labels: [1]
# Inference time (ms): 20.0902
# Labels: [1]
# Inference time (ms): 19.5259
# Labels: [1]
# Inference time (ms): 20.1054
# Labels: [1]
# Inference time (ms): 19.6787
# Labels: [1]
# Inference time (ms): 19.3189
# Labels: [1]
# Inference time (ms): 19.227500000000003
# Labels: [1]
# Inference time (ms): 19.4944
# Labels: [1]
# Inference time (ms): 20.044900000000002
# Labels: [1]
# Inference time (ms): 19.5779
# Labels: [1]
# Inference time (ms): 19.9131
# Labels: [1]
# Inference time (ms): 19.6157
# Labels: [1]
# Inference time (ms): 19.7209
# Labels: [1]
# Inference time (ms): 19.6185
# Labels: [1]
# Inference time (ms): 19.3709
# Labels: [1]
# Inference time (ms): 19.052699999999998
# Labels: [1]
# Inference time (ms): 19.445500000000003
# Labels: [1]
# Inference time (ms): 18.9895
# Labels: [1]
# Inference time (ms): 19.34
# Labels: [1]
# Inference time (ms): 19.949
# Labels: [1]
# Inference time (ms): 19.417299999999997
# Labels: [1]
# Inference time (ms): 19.351899999999997
# Labels: []
# Inference time (ms): 19.446
# Labels: [1]
# Inference time (ms): 19.2915
# Labels: [1]
# Inference time (ms): 19.3887
# Labels: [1]
# Inference time (ms): 20.473200000000002
# Labels: [1]
# Inference time (ms): 19.3915
# Labels: [1]
# Inference time (ms): 19.4634
# Labels: []
# Inference time (ms): 20.793599999999998
# Labels: [1]
# Inference time (ms): 20.351000000000003
# Labels: [1]
# Inference time (ms): 19.378800000000002
# Labels: [1]
# Inference time (ms): 19.4309
# Labels: [1]
# Inference time (ms): 19.845499999999998
# Labels: [1]
# Inference time (ms): 19.7119
# Labels: [1]
# Inference time (ms): 19.602899999999998
# Labels: [1]
# Inference time (ms): 19.712
# Labels: []
# Inference time (ms): 19.6368
# Labels: [1]
# Inference time (ms): 19.195
# Labels: [1]
# Inference time (ms): 21.9804
# Labels: [1]
# Inference time (ms): 20.527900000000002
# Labels: [1]
# Inference time (ms): 20.3234
# Labels: [1]
# Inference time (ms): 19.5415
# Labels: [1]
# Inference time (ms): 19.7191
# Labels: []
# Inference time (ms): 19.6906
# Labels: []
# Inference time (ms): 19.8132
# Labels: []
# Inference time (ms): 19.5957
# Labels: [1]
# Inference time (ms): 20.9801
# Labels: [1]
# Inference time (ms): 19.596100000000003
# Labels: [1]
# Inference time (ms): 19.5702
# Labels: []
# Inference time (ms): 20.147000000000002
# Labels: []
# Inference time (ms): 20.225900000000003
# Labels: [1]
# Inference time (ms): 19.6462
# Labels: [1]
# Inference time (ms): 19.5661
# Labels: [1]
# Inference time (ms): 21.6653
# Labels: [1]
# Inference time (ms): 20.5246
# Labels: [1]
# Inference time (ms): 20.853099999999998
# Labels: [1]
# Inference time (ms): 20.1357
# Labels: [1]
# Inference time (ms): 19.8429
# Labels: [1]
# Inference time (ms): 19.557000000000002
# Labels: []
# Inference time (ms): 20.3724
# Labels: []
# Inference time (ms): 21.9033
# Labels: []
# Inference time (ms): 20.2255
# Labels: []
# Inference time (ms): 19.7992
# Labels: []
# Inference time (ms): 19.842499999999998
# Labels: []
# Inference time (ms): 20.5484
# Labels: []
# Inference time (ms): 19.7897
# Labels: [1]
# Inference time (ms): 21.244200000000003
# Labels: [1]
# Inference time (ms): 19.712699999999998
# Labels: [1]
# Inference time (ms): 19.9619
# Labels: [1]
# Inference time (ms): 20.1617
# Labels: [1]
# Inference time (ms): 20.1668
# Labels: []
# Inference time (ms): 19.660400000000003
# Labels: [1]
# Inference time (ms): 19.837600000000002
# Labels: []
# Inference time (ms): 19.642799999999998
# Labels: []
# Inference time (ms): 19.9395
# Labels: []
# Inference time (ms): 19.529600000000002
# Labels: []
# Inference time (ms): 19.6215
# Labels: []
# Inference time (ms): 19.2971
# Labels: []
# Inference time (ms): 20.0796
# Labels: []
# Inference time (ms): 21.070700000000002
# Labels: []
# Inference time (ms): 20.2601
# Labels: []
# Inference time (ms): 20.6232
# Labels: [1]
# Inference time (ms): 19.5887
# Labels: [1]
# Inference time (ms): 19.6667
# Labels: []
# Inference time (ms): 20.6925
# Labels: [1]
# Inference time (ms): 20.9193
# Labels: [1]
# Inference time (ms): 19.9083
# Labels: [1]
# Inference time (ms): 19.081
# Labels: [1]
# Inference time (ms): 19.5684
# Labels: [1]
# Inference time (ms): 19.5764
# Labels: [1]
# Inference time (ms): 20.0383
# Labels: [1]
# Inference time (ms): 20.8361
# Labels: [1]
# Inference time (ms): 19.686100000000003
# Labels: [1]
# Inference time (ms): 19.8618
# Labels: [1]
# Inference time (ms): 19.5417
# Labels: [1]
# Inference time (ms): 19.8803
# Labels: [1]
# Inference time (ms): 20.531299999999998
# Labels: []
# Inference time (ms): 19.3137
# Labels: []
# Inference time (ms): 19.3608
# Labels: []
# Inference time (ms): 19.2114
# Labels: []
# Inference time (ms): 19.2806
# Labels: []
# Inference time (ms): 19.897100000000002
# Labels: []
# Inference time (ms): 20.4832
# Labels: []
# Inference time (ms): 19.5631
# Labels: []
# Inference time (ms): 19.5644
# Labels: []
# Inference time (ms): 19.7221
# Labels: []
# Inference time (ms): 20.155099999999997
# Labels: [1]
# Inference time (ms): 19.5351
# Labels: [1]
# Inference time (ms): 19.4341
# Labels: [1]
# Inference time (ms): 20.7279
# Labels: [1]
# Inference time (ms): 19.345299999999998
# Labels: [1]
# Inference time (ms): 19.1652
# Labels: [1]
# Inference time (ms): 19.7144
# Labels: [1]
# Inference time (ms): 19.8044
# Labels: [1]
# Inference time (ms): 19.5937
# Labels: []
# Inference time (ms): 19.3786
# Labels: []
# Inference time (ms): 20.2233
# Labels: [1]
# Inference time (ms): 19.544999999999998
# Labels: []
# Inference time (ms): 20.7868
# Labels: [1]
# Inference time (ms): 19.0784
# Labels: [1]
# Inference time (ms): 19.224700000000002
# Labels: [1]
# Inference time (ms): 19.6964
# Labels: [1]
# Inference time (ms): 20.291300000000003
# Labels: [1]
# Inference time (ms): 20.372500000000002
# Labels: [1]
# Inference time (ms): 19.4837
# Labels: [1]
# Inference time (ms): 18.9887
# Labels: [1]
# Inference time (ms): 19.300600000000003
# Labels: [1]
# Inference time (ms): 19.1828
# Labels: [1]
# Inference time (ms): 19.649199999999997
# Labels: [1]
# Inference time (ms): 20.4791
# Labels: [1]
# Inference time (ms): 20.7969
# Labels: [1]
# Inference time (ms): 19.7156
# Labels: [1]
# Inference time (ms): 19.672700000000003
# Labels: [1]
# Inference time (ms): 20.3424
# Labels: [1]
# Inference time (ms): 19.8752
# Labels: [1]
# Inference time (ms): 19.5304
# Labels: [1]
# Inference time (ms): 19.5186
# Labels: [1]
# Inference time (ms): 19.8136
# Labels: [1]
# Inference time (ms): 19.4427
# Labels: [1]
# Inference time (ms): 20.1601
# Labels: [1]
# Inference time (ms): 20.3743
# Labels: [1]
# Inference time (ms): 21.894000000000002
# Labels: [1]
# Inference time (ms): 19.7665
# Labels: [1]
# Inference time (ms): 19.8643
# Labels: [1]
# Inference time (ms): 20.1506
# Labels: []
# Inference time (ms): 20.6755
# Labels: []
# Inference time (ms): 19.5775
# Labels: [1]
# Inference time (ms): 20.085700000000003
# Labels: [1]
# Inference time (ms): 20.890800000000002
# Labels: []
# Inference time (ms): 19.3035
# Labels: []
# Inference time (ms): 19.8933
# Labels: []
# Inference time (ms): 20.3855
# Labels: []
# Inference time (ms): 20.9646
# Labels: [1]
# Inference time (ms): 19.657600000000002
# Labels: [1]
# Inference time (ms): 19.807499999999997
# Labels: [1]
# Inference time (ms): 20.105600000000003
# Labels: [1]
# Inference time (ms): 19.2528
# Labels: []
# Inference time (ms): 19.3297
# Labels: []
# Inference time (ms): 19.4372
# Labels: []
# Inference time (ms): 19.6248
# Labels: []
# Inference time (ms): 19.3946
# Labels: []
# Inference time (ms): 19.5539
# Labels: []
# Inference time (ms): 19.3679
# Labels: [1]
# Inference time (ms): 19.5037
# Labels: [1]
# Inference time (ms): 19.7396
# Labels: [1]
# Inference time (ms): 19.311999999999998
# Labels: [1]
# Inference time (ms): 19.175500000000003
# Labels: [1]
# Inference time (ms): 19.1612
# Labels: [1]
# Inference time (ms): 19.0912
# Labels: [1]
# Inference time (ms): 20.2104
# Labels: [1]
# Inference time (ms): 19.634900000000002
# Labels: []
# Inference time (ms): 19.2845
# Labels: []
# Inference time (ms): 19.8483
# Labels: []
# Inference time (ms): 19.1389
# Labels: []
# Inference time (ms): 18.8505
# Labels: []
# Inference time (ms): 19.227600000000002
# Labels: []
# Inference time (ms): 19.097800000000003
# Labels: []
# Inference time (ms): 19.1865
# Labels: []
# Inference time (ms): 19.874699999999997
# Labels: []
# Inference time (ms): 20.088600000000003
# Labels: []
# Inference time (ms): 19.5929
# Labels: []
# Inference time (ms): 19.2932
# Labels: []
# Inference time (ms): 19.3122
# Labels: [1]
# Inference time (ms): 19.2206
# Labels: []
# Inference time (ms): 18.9282
# Labels: []
# Inference time (ms): 19.0425
# Labels: [1]
# Inference time (ms): 19.6091
# Labels: [1]
# Inference time (ms): 19.8613
# Labels: [1]
# Inference time (ms): 19.1675
# Labels: []
# Inference time (ms): 19.2836
# Labels: [1]
# Inference time (ms): 20.4213
# Labels: [1]
# Inference time (ms): 20.298299999999998
# Labels: [1]
# Inference time (ms): 18.9926
# Labels: [1]
# Inference time (ms): 19.9543
# Labels: [1]
# Inference time (ms): 19.427300000000002
# Labels: [1]
# Inference time (ms): 19.0287
# Labels: [1]
# Inference time (ms): 19.1939
# Labels: [1]
# Inference time (ms): 19.1309
# Labels: [1]
# Inference time (ms): 19.392699999999998
# Labels: [1]
# Inference time (ms): 19.872
# Labels: [1]
# Inference time (ms): 20.133000000000003
# Labels: [1]
# Inference time (ms): 19.6811
# Labels: [1]
# Inference time (ms): 19.5287
# Labels: [1]
# Inference time (ms): 19.026600000000002
# Labels: [1]
# Inference time (ms): 20.5381
# Labels: [1]
# Inference time (ms): 18.839399999999998
# Labels: [1]
# Inference time (ms): 19.062800000000003
# Labels: [1]
# Inference time (ms): 19.654999999999998
# Labels: [1]
# Inference time (ms): 18.9617
# Labels: [1]
# Inference time (ms): 19.5086
# Labels: [1]
# Inference time (ms): 20.2785
# Labels: [1]
# Inference time (ms): 19.5013
# Labels: [1]
# Inference time (ms): 19.3589
# Labels: [1]
# Inference time (ms): 19.374200000000002
# Labels: [1]
# Inference time (ms): 20.729999999999997
# Labels: [1]
# Inference time (ms): 19.2493
# Labels: [1]
# Inference time (ms): 19.0006
# Labels: [1]
# Inference time (ms): 19.0765
# Labels: [1]
# Inference time (ms): 20.1387
# Labels: [1]
# Inference time (ms): 19.3707
# Labels: [1]
# Inference time (ms): 19.4482
# Labels: [1]
# Inference time (ms): 20.3386
# Labels: [1]
# Inference time (ms): 20.0012
# Labels: [1]
# Inference time (ms): 19.3683
# Labels: [1]
# Inference time (ms): 20.446700000000003
# Labels: [1]
# Inference time (ms): 19.3671
# Labels: [1]
# Inference time (ms): 19.433200000000003
# Labels: [1]
# Inference time (ms): 19.5315
# Labels: [1]
# Inference time (ms): 19.3458
# Labels: [1]
# Inference time (ms): 19.3657
# Labels: [1]
# Inference time (ms): 19.5956
# Labels: [1]
# Inference time (ms): 20.0548
# Labels: [1]
# Inference time (ms): 19.0677
# Labels: [1]
# Inference time (ms): 18.854699999999998
# Labels: [1]
# Inference time (ms): 19.1966
# Labels: [1]
# Inference time (ms): 19.7453
# Labels: [1]
# Inference time (ms): 19.3537
# Labels: [1]
# Inference time (ms): 19.592499999999998
# Labels: [1]
# Inference time (ms): 19.3975
# Labels: [1]
# Inference time (ms): 19.91
# Labels: [1]
# Inference time (ms): 19.920299999999997
# Labels: [1]
# Inference time (ms): 20.915300000000002
# Labels: [1]
# Inference time (ms): 20.0344
# Labels: [1]
# Inference time (ms): 19.3014
# Labels: [1]
# Inference time (ms): 19.4962
# Labels: [1]
# Inference time (ms): 19.3645
# Labels: [1]
# Inference time (ms): 19.1212
# Labels: [1]
# Inference time (ms): 19.6343
# Labels: [1]
# Inference time (ms): 19.4994
# Labels: [1]
# Inference time (ms): 19.4706
# Labels: [1]
# Inference time (ms): 19.572699999999998
# Labels: [1]
# Inference time (ms): 20.4465
# Labels: [1]
# Inference time (ms): 20.2673
# Labels: [1]
# Inference time (ms): 19.161399999999997
# Labels: [1]
# Inference time (ms): 19.796999999999997
# Labels: [1]
# Inference time (ms): 18.9477
# Labels: [1]
# Inference time (ms): 20.0018
# Labels: [1]
# Inference time (ms): 19.5335
# Labels: [1]
# Inference time (ms): 20.545399999999997
# Labels: [1]
# Inference time (ms): 19.2738
# Labels: [1]
# Inference time (ms): 19.4923
# Labels: [1]
# Inference time (ms): 19.8018
# Labels: [1]
# Inference time (ms): 20.2241
# Labels: [1]
# Inference time (ms): 20.2986
# Labels: [1]
# Inference time (ms): 19.0259
# Labels: [1]
# Inference time (ms): 19.1985
# Labels: [1]
# Inference time (ms): 19.4787
# Labels: [1]
# Inference time (ms): 19.4193
# Labels: [1]
# Inference time (ms): 19.3904
# Labels: [1]
# Inference time (ms): 19.4309
# Labels: [1]
# Inference time (ms): 20.238599999999998
# Labels: [1]
# Inference time (ms): 19.2493
# Labels: [1]
# Inference time (ms): 19.222900000000003
# Labels: [1]
# Inference time (ms): 19.414399999999997
# Labels: [1]
# Inference time (ms): 19.1048
# Labels: [1]
# Inference time (ms): 19.736900000000002
# Labels: [1]
# Inference time (ms): 19.6004
# Labels: [1]
# Inference time (ms): 19.381700000000002
# Labels: [1]
# Inference time (ms): 19.8785
# Labels: [1]
# Inference time (ms): 18.6251
# Labels: [1]
# Inference time (ms): 19.1066
# Labels: [1]
# Inference time (ms): 19.674799999999998
# Labels: [1]
# Inference time (ms): 20.5839
# Labels: [1]
# Inference time (ms): 19.5222
# Labels: [1]
# Inference time (ms): 19.4865
# Labels: [1]
# Inference time (ms): 19.2346
# Labels: []
# Inference time (ms): 22.5204
# Labels: [1]
# Inference time (ms): 19.124100000000002
# Labels: [1]
# Inference time (ms): 19.6059
# Labels: [1]
# Inference time (ms): 19.1404
# Labels: [1]
# Inference time (ms): 19.2036
# Labels: [1]
# Inference time (ms): 19.7089
# Labels: [1]
# Inference time (ms): 19.362000000000002
# Labels: [1]
# Inference time (ms): 19.4564
# Labels: [1]
# Inference time (ms): 19.6089
# Labels: [1]
# Inference time (ms): 20.0761
# Labels: [1]
# Inference time (ms): 19.8743
# Labels: [1]
# Inference time (ms): 18.9468
# Labels: [1]
# Inference time (ms): 20.084999999999997
# Labels: [1]
# Inference time (ms): 19.6326
# Labels: [1]
# Inference time (ms): 19.7682
# Labels: [1]
# Inference time (ms): 19.5691
# Labels: [1]
# Inference time (ms): 19.549899999999997
# Labels: [1]
# Inference time (ms): 19.804599999999997
# Labels: [1]
# Inference time (ms): 19.589599999999997
# Labels: []
# Inference time (ms): 19.7459
# Labels: []
# Inference time (ms): 19.5071
# Labels: [1]
# Inference time (ms): 18.7455
# Labels: [1]
# Inference time (ms): 18.7791
# Labels: [1]
# Inference time (ms): 19.4135
# Labels: [1]
# Inference time (ms): 19.4977
# Labels: [1]
# Inference time (ms): 19.3737
# Labels: [1]
# Inference time (ms): 19.572599999999998
# Labels: [1]
# Inference time (ms): 20.3827
# Labels: [1]
# Inference time (ms): 22.0732
# Labels: [1]
# Inference time (ms): 19.1448
# Labels: []
# Inference time (ms): 19.5414
# Labels: []
# Inference time (ms): 19.1556
# Labels: [1]
# Inference time (ms): 19.503
# Labels: [1]
# Inference time (ms): 19.8191
# Labels: []
# Inference time (ms): 19.4807
# Labels: [1]
# Inference time (ms): 19.407899999999998
# Labels: [1]
# Inference time (ms): 19.356
# Labels: [1]
# Inference time (ms): 22.006700000000002
# Labels: [1]
# Inference time (ms): 20.0852
# Labels: [1]
# Inference time (ms): 19.0379
# Labels: [1]
# Inference time (ms): 19.823400000000003
# Labels: []
# Inference time (ms): 19.548
# Labels: [1]
# Inference time (ms): 19.4156
# Labels: [1]
# Inference time (ms): 18.8155
# Labels: [1]
# Inference time (ms): 19.4719
# Labels: [1]
# Inference time (ms): 22.306099999999997
# Labels: [1]
# Inference time (ms): 19.529899999999998
# Labels: [1]
# Inference time (ms): 19.5533
# Labels: [1]
# Inference time (ms): 19.4261
# Labels: [1]
# Inference time (ms): 20.4284
# Labels: [1]
# Inference time (ms): 18.9877
# Labels: [1]
# Inference time (ms): 19.319300000000002
# Labels: [1]
# Inference time (ms): 19.7442
# Labels: [1]
# Inference time (ms): 19.0208
# Labels: [1]
# Inference time (ms): 19.6469
# Labels: [1]
# Inference time (ms): 19.4405
# Labels: [1]
# Inference time (ms): 19.5138
# Labels: [1]
# Inference time (ms): 19.6392
# Labels: [1]
# Inference time (ms): 19.534
# Labels: [1]
# Inference time (ms): 20.0412
# Labels: [1]
# Inference time (ms): 20.124699999999997
# Labels: [1]
# Inference time (ms): 20.0459
# Labels: [1]
# Inference time (ms): 19.3654
# Labels: [1]
# Inference time (ms): 19.8466
# Labels: [1]
# Inference time (ms): 19.6856
# Labels: [1]
# Inference time (ms): 19.349800000000002
# Labels: [1]
# Inference time (ms): 22.4675
# Labels: [1]
# Inference time (ms): 19.621
# Labels: [1]
# Inference time (ms): 19.486900000000002
# Labels: [1]
# Inference time (ms): 19.2004
# Labels: [1]
# Inference time (ms): 19.7288
# Labels: [1]
# Inference time (ms): 19.950300000000002
# Labels: [1]
# Inference time (ms): 19.0231
# Labels: [1]
# Inference time (ms): 19.6358
# Labels: []
# Inference time (ms): 19.3909
# Labels: []
# Inference time (ms): 20.1152
# Labels: [1]
# Inference time (ms): 19.27
# Labels: [1]
# Inference time (ms): 19.459899999999998
# Labels: [1]
# Inference time (ms): 19.5273
# Labels: [1]
# Inference time (ms): 19.4457
# Labels: [1]
# Inference time (ms): 19.4333
# Labels: [1]
# Inference time (ms): 20.3403
# Labels: [1]
# Inference time (ms): 19.4004
# Labels: [1]
# Inference time (ms): 19.5792
# Labels: [1]
# Inference time (ms): 18.934099999999997
# Labels: [1]
# Inference time (ms): 19.255000000000003
# Labels: [1]
# Inference time (ms): 19.43
# Labels: [1]
# Inference time (ms): 19.6303
# Labels: [1]
# Inference time (ms): 19.3835
# Labels: [1]
# Inference time (ms): 19.810399999999998
# Labels: [1]
# Inference time (ms): 20.2592
# Labels: [1]
# Inference time (ms): 19.6321
# Labels: [1]
# Inference time (ms): 19.3384
# Labels: [1]
# Inference time (ms): 19.553
# Labels: [1]
# Inference time (ms): 19.3867
# Labels: [1]
# Inference time (ms): 19.6606
# Labels: [1]
# Inference time (ms): 20.0142
# Labels: [1]
# Inference time (ms): 19.3747
# Labels: [1]
# Inference time (ms): 19.6971
# Labels: [1]
# Inference time (ms): 19.5069
# Labels: [1]
# Inference time (ms): 20.6161
# Labels: [1]
# Inference time (ms): 19.1067
# Labels: [1]
# Inference time (ms): 19.9667
# Labels: [1]
# Inference time (ms): 19.9125
# Labels: [1]
# Inference time (ms): 19.4252
# Labels: [1]
# Inference time (ms): 19.4258
# Labels: [1]
# Inference time (ms): 19.557399999999998
# Labels: [1]
# Inference time (ms): 19.3134
# Labels: [1]
# Inference time (ms): 19.4829
# Labels: [1]
# Inference time (ms): 19.4847
# Labels: [1]
# Inference time (ms): 19.9267
# Labels: [1]
# Inference time (ms): 19.9262
# Labels: [1]
# Inference time (ms): 19.5566
# Labels: [1]
# Inference time (ms): 19.463500000000003
# Labels: [1]
# Inference time (ms): 19.2007
# Labels: [1]
# Inference time (ms): 19.402900000000002
# Labels: [1]
# Inference time (ms): 19.623
# Labels: [1]
# Inference time (ms): 19.8885
# Labels: [1]
# Inference time (ms): 19.737299999999998
# Labels: [1]
# Inference time (ms): 19.419900000000002
# Labels: [1]
# Inference time (ms): 19.1769
# Labels: [1]
# Inference time (ms): 19.799
# Labels: [1]
# Inference time (ms): 20.0244
# Labels: [1]
# Inference time (ms): 19.5104
# Labels: [1]
# Inference time (ms): 20.1584
# Labels: [1]
# Inference time (ms): 19.4622
# Labels: [1]
# Inference time (ms): 19.792299999999997
# Labels: [1]
# Inference time (ms): 19.4135
# Labels: [1]
# Inference time (ms): 19.3964
# Labels: [1]
# Inference time (ms): 19.5361
# Labels: [1]
# Inference time (ms): 19.629299999999997
# Labels: [1]
# Inference time (ms): 20.3098
# Labels: [1]
# Inference time (ms): 22.2984
# Labels: []
# Inference time (ms): 27.336
# Labels: [1]
# Inference time (ms): 19.5089
# Labels: [1]
# Inference time (ms): 19.2374
# Labels: [1]
# Inference time (ms): 20.9974
# Labels: [1]
# Inference time (ms): 19.6208
# Labels: [1]
# Inference time (ms): 19.4516
# Labels: [1]
# Inference time (ms): 19.3659
# Labels: [1]
# Inference time (ms): 19.3747
# Labels: [1]
# Inference time (ms): 19.7237
# Labels: [1]
# Inference time (ms): 19.4207
# Labels: [1]
# Inference time (ms): 20.065199999999997
# Labels: [1]
# Inference time (ms): 19.351799999999997
# Labels: [1]
# Inference time (ms): 19.5519
# Labels: [1]
# Inference time (ms): 19.7289
# Labels: [1]
# Inference time (ms): 19.4286
# Labels: [1]
# Inference time (ms): 19.4408
# Labels: [1]
# Inference time (ms): 20.0123
# Labels: [1]
# Inference time (ms): 19.6438
# Labels: [1]
# Inference time (ms): 19.9584
# Labels: [1]
# Inference time (ms): 19.2142
# Labels: [1]
# Inference time (ms): 19.388099999999998
# Labels: [1]
# Inference time (ms): 19.5736
# Labels: []
# Inference time (ms): 19.6118
# Labels: [1]
# Inference time (ms): 19.5357
# Labels: [1]
# Inference time (ms): 19.6437
# Labels: []
# Inference time (ms): 19.8194
# Labels: [1]
# Inference time (ms): 19.6013
# Labels: [1]
# Inference time (ms): 19.2501
# Labels: []
# Inference time (ms): 19.0555
# Labels: [1]
# Inference time (ms): 19.4952
# Labels: [1]
# Inference time (ms): 19.0741
# Labels: [1]
# Inference time (ms): 19.972
# Labels: []
# Inference time (ms): 19.3985
# Labels: []
# Inference time (ms): 19.317999999999998
# Labels: []
# Inference time (ms): 19.4107
# Labels: []
# Inference time (ms): 19.6357
# Labels: [1]
# Inference time (ms): 19.182299999999998
# Labels: [1]
# Inference time (ms): 20.2056
# Labels: [1]
# Inference time (ms): 21.1147
# Labels: [1]
# Inference time (ms): 19.5267
# Labels: []
# Inference time (ms): 19.603099999999998
# Labels: []
# Inference time (ms): 19.3962
# Labels: []
# Inference time (ms): 19.2899
# Labels: [1]
# Inference time (ms): 19.4648
# Labels: [1]
# Inference time (ms): 19.510199999999998
# Labels: [1]
# Inference time (ms): 20.0916
# Labels: [1]
# Inference time (ms): 19.4194
# Labels: [1]
# Inference time (ms): 20.087500000000002
# Labels: [1]
# Inference time (ms): 18.8296
# Labels: [1]
# Inference time (ms): 19.503
# Labels: [1]
# Inference time (ms): 20.577499999999997
# Labels: [1]
# Inference time (ms): 19.1049
# Labels: [1]
# Inference time (ms): 19.4271
# Labels: [1]
# Inference time (ms): 19.3657
# Labels: [1]
# Inference time (ms): 19.9246
# Labels: [1]
# Inference time (ms): 20.195700000000002
# Labels: [1]
# Inference time (ms): 20.153399999999998
# Labels: [1]
# Inference time (ms): 19.6765
# Labels: [1]
# Inference time (ms): 19.177699999999998
# Labels: [1]
# Inference time (ms): 19.9175
# Labels: [1]
# Inference time (ms): 19.4252
# Labels: [1]
# Inference time (ms): 19.562
# Labels: [1]
# Inference time (ms): 19.9789
# Labels: [1]
# Inference time (ms): 19.6291
# Labels: [1]
# Inference time (ms): 20.0369
# Labels: [1]
# Inference time (ms): 22.5456
# Labels: [1]
# Inference time (ms): 20.3841
# Labels: [1]
# Inference time (ms): 19.546999999999997
# Labels: [1]
# Inference time (ms): 18.9215
# Labels: [1]
# Inference time (ms): 19.414299999999997
# Labels: [1]
# Inference time (ms): 19.1938
# Labels: [1]
# Inference time (ms): 19.4742
# Labels: [1]
# Inference time (ms): 19.3338
# Labels: [1]
# Inference time (ms): 19.4077
# Labels: [1]
# Inference time (ms): 19.384800000000002
# Labels: [1]
# Inference time (ms): 19.5075
# Labels: [1]
# Inference time (ms): 20.2193
# Labels: [1]
# Inference time (ms): 19.5672
# Labels: [1]
# Inference time (ms): 19.1915
# Labels: [1]
# Inference time (ms): 19.5703
# Labels: [1]
# Inference time (ms): 20.8977
# Labels: [1]
# Inference time (ms): 19.375400000000003
# Labels: [1]
# Inference time (ms): 19.3216
# Labels: [1]
# Inference time (ms): 19.5855
# Labels: [1]
# Inference time (ms): 19.5439
# Labels: [1]
# Inference time (ms): 19.6634
# Labels: [1]
# Inference time (ms): 20.4598
# Labels: [1]
# Inference time (ms): 19.855500000000003
# Labels: [1]
# Inference time (ms): 19.7061
# Labels: [1]
# Inference time (ms): 19.6172
# Labels: [1]
# Inference time (ms): 19.4205
# Labels: [1]
# Inference time (ms): 19.1884
# Labels: [1]
# Inference time (ms): 19.6291
# Labels: [1]
# Inference time (ms): 19.7658
# Labels: [1]
# Inference time (ms): 19.4158
# Labels: [1]
# Inference time (ms): 19.3264
# Labels: [1]
# Inference time (ms): 20.3558
# Labels: [1]
# Inference time (ms): 21.9472
# Labels: [1]
# Inference time (ms): 19.7583
# Labels: [1]
# Inference time (ms): 19.3535
# Labels: [1]
# Inference time (ms): 19.3766
# Labels: [1]
# Inference time (ms): 19.781
# Labels: [1]
# Inference time (ms): 19.4318
# Labels: [1]
# Inference time (ms): 19.3561
# Labels: [1]
# Inference time (ms): 19.3418
# Labels: [1]
# Inference time (ms): 19.427699999999998
# Labels: [1]
# Inference time (ms): 19.3194
# Labels: [1]
# Inference time (ms): 19.5635
# Labels: [1]
# Inference time (ms): 20.3232
# Labels: [1]
# Inference time (ms): 19.802
# Labels: [1]
# Inference time (ms): 19.247899999999998
# Labels: [1]
# Inference time (ms): 19.1332
# Labels: [1]
# Inference time (ms): 19.485599999999998
# Labels: [1]
# Inference time (ms): 19.3785
# Labels: [1]
# Inference time (ms): 19.6536
# Labels: [1]
# Inference time (ms): 19.6845
# Labels: [1]
# Inference time (ms): 19.5165
# Labels: [1]
# Inference time (ms): 19.842499999999998
# Labels: [1]
# Inference time (ms): 19.7485
# Labels: [1]
# Inference time (ms): 19.161399999999997
# Labels: [1]
# Inference time (ms): 19.4017
# Labels: [1]
# Inference time (ms): 19.4634
# Labels: [1]
# Inference time (ms): 21.0693
# Labels: [1]
# Inference time (ms): 19.6046
# Labels: [1]
# Inference time (ms): 19.2578
# Labels: [1]
# Inference time (ms): 19.1468
# Labels: [1]
# Inference time (ms): 19.2468
# Labels: [1]
# Inference time (ms): 20.069300000000002
# Labels: [1]
# Inference time (ms): 19.2245
# Labels: [1]
# Inference time (ms): 19.9673
# Labels: [1]
# Inference time (ms): 19.4893
# Labels: [1]
# Inference time (ms): 19.1332
# Labels: [1]
# Inference time (ms): 18.6846
# Labels: [1]
# Inference time (ms): 19.0472
# Labels: [1]
# Inference time (ms): 19.7256
# Labels: [1]
# Inference time (ms): 19.4486
# Labels: [1]
# Inference time (ms): 19.974800000000002
# Labels: [1]
# Inference time (ms): 19.325
# Labels: [1]
# Inference time (ms): 19.744600000000002
# Labels: [1]
# Inference time (ms): 19.069
# Labels: [1]
# Inference time (ms): 19.3143
# Labels: [1]
# Inference time (ms): 19.3567
# Labels: [1]
# Inference time (ms): 19.660400000000003
# Labels: [1]
# Inference time (ms): 19.662300000000002
# Labels: [1]
# Inference time (ms): 19.2309
# Labels: [1]
# Inference time (ms): 18.9545
# Labels: [1]
# Inference time (ms): 19.3216
# Labels: [1]
# Inference time (ms): 19.3203
# Labels: [1]
# Inference time (ms): 19.3856
# Labels: [1]
# Inference time (ms): 19.9814
# Labels: [1]
# Inference time (ms): 20.2138
# Labels: [1]
# Inference time (ms): 19.3617
# Labels: [1]
# Inference time (ms): 19.2223
# Labels: [1]
# Inference time (ms): 19.2066
# Labels: [1]
# Inference time (ms): 19.4638
# Labels: [1]
# Inference time (ms): 19.2454
# Labels: [1]
# Inference time (ms): 19.154
# Labels: [1]
# Inference time (ms): 20.145799999999998
# Labels: [1]
# Inference time (ms): 19.7501
# Labels: [1]
# Inference time (ms): 19.6583
# Labels: [1]
# Inference time (ms): 19.029500000000002
# Labels: [1]
# Inference time (ms): 19.0889
# Labels: [1]
# Inference time (ms): 19.2818
# Labels: [1]
# Inference time (ms): 19.3461
# Labels: [1]
# Inference time (ms): 19.307399999999998
# Labels: [1]
# Inference time (ms): 19.0795
# Labels: [1]
# Inference time (ms): 19.7474
# Labels: [1]
# Inference time (ms): 19.739199999999997
# Labels: [1]
# Inference time (ms): 19.1267
# Labels: [1]
# Inference time (ms): 19.1903
# Labels: [1]
# Inference time (ms): 19.4293
# Labels: [1]
# Inference time (ms): 19.9027
# Labels: [1]
# Inference time (ms): 19.4263
# Labels: [1]
# Inference time (ms): 19.292099999999998
# Labels: [1]
# Inference time (ms): 19.132199999999997
# Labels: [1]
# Inference time (ms): 21.5799
# Labels: [1]
# Inference time (ms): 19.4795
# Labels: [1]
# Inference time (ms): 19.9413
# Labels: [1]
# Inference time (ms): 19.9514
# Labels: [1]
# Inference time (ms): 19.4299
# Labels: [1]
# Inference time (ms): 19.567
# Labels: [1]
# Inference time (ms): 19.433200000000003
# Labels: [1]
# Inference time (ms): 19.4185
# Labels: [1]
# Inference time (ms): 19.4289
# Labels: [1]
# Inference time (ms): 19.2917
# Labels: [1]
# Inference time (ms): 19.3412
# Labels: [1]
# Inference time (ms): 19.3031
# Labels: [1]
# Inference time (ms): 19.8034
# Labels: [1]
# Inference time (ms): 19.7355
# Labels: [1]
# Inference time (ms): 19.046899999999997
# Labels: [1]
# Inference time (ms): 19.6485
# Labels: [1]
# Inference time (ms): 19.279899999999998
# Labels: [1]
# Inference time (ms): 21.2216
# Labels: [1]
# Inference time (ms): 19.4308
# ...
# Labels: [1]
# Inference time (ms): 21.2187
# Labels: [1]
# Inference time (ms): 20.990000000000002
# Labels: [1]
# Inference time (ms): 20.797
# Labels: [1]
# Inference time (ms): 21.605900000000002
# Labels: [1]
# Inference time (ms): 20.8961
# Labels: [1]
# Inference time (ms): 20.853099999999998
# Labels: [1]
# Inference time (ms): 20.7372
# Labels: [1]
# Inference time (ms): 20.9763
# Labels: [1]
# Inference time (ms): 20.7971
# Labels: [1]
# Inference time (ms): 21.0458
# Labels: [1]
# Inference time (ms): 20.8526
# Labels: [1]
# Inference time (ms): 21.163
# Labels: [1]
# Inference time (ms): 22.0548
# Labels: [1]
# Inference time (ms): 21.478
# Labels: [1]
# Inference time (ms): 21.998
# Labels: [1]
# Inference time (ms): 20.416
# Labels: [1]
# Inference time (ms): 20.4027
# Labels: [1]
# Inference time (ms): 20.6873
# Labels: [1]
# Inference time (ms): 21.2209
# Labels: [1]
# Inference time (ms): 20.8795
# Labels: [1]
# Inference time (ms): 20.8478
# Labels: [1]
# Inference time (ms): 21.7238
# Labels: [1]
# Inference time (ms): 21.4751
# Labels: [1]
# Inference time (ms): 21.834699999999998
# Labels: [1]
# Inference time (ms): 20.1747
# Labels: [1]
# Inference time (ms): 21.240499999999997
# Labels: [1]
# Inference time (ms): 23.1694
# Labels: [1]
# Inference time (ms): 20.8238
# Labels: [1]
# Inference time (ms): 20.6645
# Labels: [1]
# Inference time (ms): 20.8903
# Labels: [1]
# Inference time (ms): 20.8314
# Labels: [1]
# Inference time (ms): 20.3027
# Labels: [1]
# Inference time (ms): 21.1898
# Labels: [1]
# Inference time (ms): 23.955000000000002
# Labels: [1]
# Inference time (ms): 19.8904
# Labels: [1]
# Inference time (ms): 20.389999999999997
# Labels: []
# Inference time (ms): 20.8166
# Labels: []
# Inference time (ms): 20.7865
# Labels: [1]
# Inference time (ms): 20.794900000000002
# Labels: [1]
# Inference time (ms): 20.3259
# Labels: [1]
# Inference time (ms): 20.9872
# Labels: []
# Inference time (ms): 25.6954
# Labels: []
# Inference time (ms): 21.121299999999998
# Labels: []
# Inference time (ms): 20.766
# Labels: []
# Inference time (ms): 20.6139
# Labels: []
# Inference time (ms): 20.816100000000002
# Labels: []
# Inference time (ms): 21.2103
# Labels: []
# Inference time (ms): 23.5548
# Labels: []
# Inference time (ms): 25.2588
# Labels: []
# Inference time (ms): 20.815
# Labels: []
# Inference time (ms): 21.3045
# Labels: [1]
# Inference time (ms): 25.0517
# Labels: [1]
# Inference time (ms): 20.5167
# Labels: [1]
# Inference time (ms): 20.380200000000002
# Labels: [1]
# Inference time (ms): 20.831
# Labels: []
# Inference time (ms): 20.2363
# Labels: []
# Inference time (ms): 22.444599999999998
# Labels: []
# Inference time (ms): 20.6352
# Labels: [1]
# Inference time (ms): 20.5848
# Labels: [1]
# Inference time (ms): 23.866100000000003
# Labels: [1]
# Inference time (ms): 20.477999999999998
# Labels: [1]
# Inference time (ms): 21.2957
# Labels: [1]
# Inference time (ms): 20.7381
# Labels: [1]
# Inference time (ms): 20.8103
# Labels: [1]
# Inference time (ms): 20.5245
# Labels: [1]
# Inference time (ms): 20.6312
# Labels: [1]
# Inference time (ms): 21.4575
# Labels: [1]
# Inference time (ms): 20.2916
# Labels: [1]
# Inference time (ms): 20.8517
# Labels: [1]
# Inference time (ms): 21.075799999999997
# Labels: [1]
# Inference time (ms): 21.1926
# Labels: [1]
# Inference time (ms): 21.281499999999998
# Labels: [1]
# Inference time (ms): 21.090899999999998
# Labels: [1]
# Inference time (ms): 21.3308
# Labels: [1]
# Inference time (ms): 20.8222
# Labels: [1]
# Inference time (ms): 20.7752
# Labels: [1]
# Inference time (ms): 20.644
# Labels: [1]
# Inference time (ms): 20.7296
# Labels: [1]
# Inference time (ms): 20.4464
# Labels: [1]
# Inference time (ms): 20.6197
# Labels: [1]
# Inference time (ms): 24.2401
# Labels: [1]
# Inference time (ms): 20.7019
# Labels: [1]
# Inference time (ms): 21.543400000000002
# Labels: [1]
# Inference time (ms): 20.8259
# Labels: [1]
# Inference time (ms): 20.292
# Labels: [1]
# Inference time (ms): 21.1599
# Labels: [1]
# Inference time (ms): 21.0414
# Labels: [1]
# Inference time (ms): 21.098499999999998
# Labels: [1]
# Inference time (ms): 20.9367
# Labels: [1]
# Inference time (ms): 20.4016
# Labels: [1]
# Inference time (ms): 21.1297
# Labels: [1]
# Inference time (ms): 22.1861
# Labels: [1]
# Inference time (ms): 20.9668
# Labels: [1]
# Inference time (ms): 20.740000000000002
# Labels: [1]
# Inference time (ms): 21.5206
# Labels: [1]
# Inference time (ms): 20.9801
# Labels: [1]
# Inference time (ms): 20.513199999999998
# Labels: [1]
# Inference time (ms): 20.7523
# Labels: [1]
# Inference time (ms): 20.8416
# Labels: [1]
# Inference time (ms): 20.4694
# Labels: [1]
# Inference time (ms): 21.1969
# Labels: [1]
# Inference time (ms): 21.5449
# Labels: [1]
# Inference time (ms): 21.761699999999998
# Labels: [1]
# Inference time (ms): 20.9822
# Labels: [1]
# Inference time (ms): 20.9914
# Labels: [1]
# Inference time (ms): 21.2088
# Labels: [1]
# Inference time (ms): 20.1119
# Labels: [1]
# Inference time (ms): 20.6234
# Labels: [1]
# Inference time (ms): 20.5928
# Labels: [1]
# Inference time (ms): 20.6895
# Labels: [1]
# Inference time (ms): 22.7551
# Labels: [1]
# Inference time (ms): 21.304199999999998
# Labels: [1]
# Inference time (ms): 20.7023
# Labels: [1]
# Inference time (ms): 20.8278
# Labels: [1]
# Inference time (ms): 20.535899999999998
# Labels: [1]
# Inference time (ms): 21.3845
# Labels: [1]
# Inference time (ms): 20.8837
# Labels: [1]
# Inference time (ms): 20.636100000000003
# Labels: [1]
# Inference time (ms): 21.426000000000002
# Labels: [1]
# Inference time (ms): 20.5717
# Labels: [1]
# Inference time (ms): 21.5954
# Labels: []
# Inference time (ms): 21.3705
# Labels: []
# Inference time (ms): 21.9692
# Labels: []
# Inference time (ms): 21.208399999999997
# Labels: []
# Inference time (ms): 21.5409
# Labels: [1]
# Inference time (ms): 21.2228
# Labels: [1]
# Inference time (ms): 19.9436
# Labels: [1]
# Inference time (ms): 20.7118
# Labels: [1]
# Inference time (ms): 21.2438
# Labels: [1]
# Inference time (ms): 20.6037
# Labels: [1]
# Inference time (ms): 20.6666
# Labels: [1]
# Inference time (ms): 21.2162
# Labels: [1]
# Inference time (ms): 21.2474
# Labels: [1]
# Inference time (ms): 21.4223
# Labels: [1]
# Inference time (ms): 20.862599999999997
# Labels: [1]
# Inference time (ms): 20.3197
# Labels: [1]
# Inference time (ms): 20.6116
# Labels: [1]
# Inference time (ms): 20.552500000000002
# Labels: [1]
# Inference time (ms): 23.124100000000002
# Labels: [1]
# Inference time (ms): 20.9671
# Labels: [1]
# Inference time (ms): 22.0564
# Labels: [1]
# Inference time (ms): 21.458000000000002
# Labels: [1]
# Inference time (ms): 20.5145
# Labels: [1]
# Inference time (ms): 21.3484
# Labels: [1]
# Inference time (ms): 20.992
# Labels: [1]
# Inference time (ms): 21.3856
# Labels: [1]
# Inference time (ms): 20.8472
# Labels: [1]
# Inference time (ms): 20.633200000000002
# Labels: [1]
# Inference time (ms): 20.9938
# Labels: [1]
# Inference time (ms): 21.8471
# Labels: [1]
# Inference time (ms): 20.9746
# Labels: [1]
# Inference time (ms): 21.0683
# Labels: [1]
# Inference time (ms): 21.1896
# Labels: [1]
# Inference time (ms): 20.3034
# Labels: [1]
# Inference time (ms): 20.6673
# Labels: [1]
# Inference time (ms): 20.4255
# Labels: [1]
# Inference time (ms): 21.161800000000003
# Labels: [1]
# Inference time (ms): 21.1448
# Labels: [1]
# Inference time (ms): 20.968799999999998
# Labels: [1]
# Inference time (ms): 20.913600000000002
# Labels: [1]
# Inference time (ms): 21.313599999999997
# Labels: [1]
# Inference time (ms): 20.933500000000002
# Labels: [1]
# Inference time (ms): 21.7816
# Labels: [1]
# Inference time (ms): 21.2669
# Labels: [1]
# Inference time (ms): 20.892
# Labels: [1]
# Inference time (ms): 20.5683
# Labels: [1]
# Inference time (ms): 20.453699999999998
# Labels: [1]
# Inference time (ms): 20.8062
# Labels: [1]
# Inference time (ms): 20.8968
# Labels: [1]
# Inference time (ms): 20.8609
# Labels: [1]
# Inference time (ms): 21.052
# Labels: [1]
# Inference time (ms): 22.0123
# Labels: [1]
# Inference time (ms): 21.741300000000003
# Labels: [1]
# Inference time (ms): 24.8364
# Labels: [1]
# Inference time (ms): 21.0792
# Labels: [1]
# Inference time (ms): 20.8162
# Labels: [1]
# Inference time (ms): 21.0868
# Labels: [1]
# Inference time (ms): 21.429199999999998
# Labels: [1]
# Inference time (ms): 21.1114
# Labels: [1]
# Inference time (ms): 20.7171
# Labels: [1]
# Inference time (ms): 22.511799999999997
# Labels: [1]
# Inference time (ms): 20.1638
# Labels: [1]
# Inference time (ms): 21.4359
# Labels: [1]
# Inference time (ms): 20.3446
# Labels: [1]
# Inference time (ms): 20.9313
# Labels: [1]
# Inference time (ms): 21.223
# Labels: [1]
# Inference time (ms): 21.025599999999997
# Labels: [1]
# Inference time (ms): 20.929
# Labels: [1]
# Inference time (ms): 21.483700000000002
# Labels: [1]
# Inference time (ms): 21.7331
# Labels: [1]
# Inference time (ms): 20.7561
# Labels: [1]
# Inference time (ms): 20.8847
# Labels: [1]
# Inference time (ms): 20.8155
# Labels: [1]
# Inference time (ms): 20.8522
# Labels: [1]
# Inference time (ms): 22.238500000000002
# Labels: [1]
# Inference time (ms): 20.991300000000003
# Labels: [1]
# Inference time (ms): 20.8601
# Labels: [1]
# Inference time (ms): 20.867900000000002
# Labels: [1]
# Inference time (ms): 21.4565
# Labels: [1]
# Inference time (ms): 23.275000000000002
# Labels: [1]
# Inference time (ms): 21.6403
# Labels: [1]
# Inference time (ms): 21.6967
# Labels: [1]
# Inference time (ms): 20.7595
# Labels: [1]
# Inference time (ms): 20.9149
# Labels: [1]
# Inference time (ms): 20.469
# Labels: [1]
# Inference time (ms): 21.177
# Labels: [1]
# Inference time (ms): 26.449199999999998
# Labels: [1]
# Inference time (ms): 20.9361
# Labels: [1]
# Inference time (ms): 21.0659
# Labels: [1]
# Inference time (ms): 21.2153
# Labels: [1]
# Inference time (ms): 25.2669
# Labels: [1]
# Inference time (ms): 21.783299999999997
# Labels: [1]
# Inference time (ms): 20.8517
# Labels: []
# Inference time (ms): 20.8942
# Labels: [1]
# Inference time (ms): 20.9322
# Labels: [1]
# Inference time (ms): 21.1596
# Labels: [1]
# Inference time (ms): 21.1313
# Labels: [1]
# Inference time (ms): 20.950300000000002
# Labels: []
# Inference time (ms): 20.9509
# Labels: [1]
# Inference time (ms): 22.1769
# Labels: [1]
# Inference time (ms): 21.3575
# Labels: [1]
# Inference time (ms): 21.4831
# Labels: [1]
# Inference time (ms): 21.3868
# Labels: [1]
# Inference time (ms): 20.4178
# Labels: [1]
# Inference time (ms): 21.172
# Labels: [1]
# Inference time (ms): 20.9767
# Labels: [1]
# Inference time (ms): 21.5356
# Labels: [1]
# Inference time (ms): 21.0953
# Labels: [1]
# Inference time (ms): 20.5913
# Labels: [1]
# Inference time (ms): 20.9024
# Labels: [1]
# Inference time (ms): 21.0932
# Labels: [1]
# Inference time (ms): 21.0979
# Labels: [1]
# Inference time (ms): 25.818299999999997
# Labels: [1]
# Inference time (ms): 24.2667
# Labels: [1]
# Inference time (ms): 20.9028
# Labels: [1]
# Inference time (ms): 22.9808
# Labels: [1]
# Inference time (ms): 23.4488
# Labels: [1]
# Inference time (ms): 20.5209
# Labels: [1]
# Inference time (ms): 21.9481
# Labels: [1]
# Inference time (ms): 22.4693
# Labels: [1]
# Inference time (ms): 21.8311
# Labels: [1]
# Inference time (ms): 21.0684
# Labels: [1]
# Inference time (ms): 20.7525
# Labels: [1]
# Inference time (ms): 21.3458
# Labels: [1]
# Inference time (ms): 21.1353
# Labels: [1]
# Inference time (ms): 21.1322
# Labels: [1]
# Inference time (ms): 22.1905
# Labels: [1]
# Inference time (ms): 20.202399999999997
# Labels: [1]
# Inference time (ms): 22.3261
# Labels: [1]
# Inference time (ms): 20.026100000000003
# Labels: [1]
# Inference time (ms): 21.1241
# Labels: [1]
# Inference time (ms): 20.7807
# Labels: [1]
# Inference time (ms): 21.1942
# Labels: [1]
# Inference time (ms): 21.7838
# Labels: [1]
# Inference time (ms): 21.5949
# Labels: [1]
# Inference time (ms): 25.2697
# Labels: [1]
# Inference time (ms): 20.7807
# Labels: [1]
# Inference time (ms): 20.4798
# Labels: [1]
# Inference time (ms): 20.9447
# Labels: [1]
# Inference time (ms): 22.535800000000002
# Labels: [1]
# Inference time (ms): 20.266099999999998
# Labels: [1]
# Inference time (ms): 21.1995
# Labels: [1]
# Inference time (ms): 20.839
# Labels: [1]
# Inference time (ms): 20.9222
# Labels: [1]
# Inference time (ms): 21.203
# Labels: [1]
# Inference time (ms): 24.8957
# Labels: [1]
# Inference time (ms): 21.857499999999998
# Labels: [1]
# Inference time (ms): 21.6141
# Labels: [1]
# Inference time (ms): 21.1643
# Labels: [1]
# Inference time (ms): 20.5185
# Labels: [1]
# Inference time (ms): 20.543100000000003
# Labels: [1]
# Inference time (ms): 20.7173
# Labels: [1]
# Inference time (ms): 20.8156
# Labels: [1]
# Inference time (ms): 20.903000000000002
# Labels: [1]
# Inference time (ms): 20.7927
# Labels: [1]
# Inference time (ms): 21.5348
# Labels: [1]
# Inference time (ms): 21.563599999999997
# Labels: [1]
# Inference time (ms): 20.540200000000002
# Labels: [1]
# Inference time (ms): 23.351
# Labels: [1]
# Inference time (ms): 20.305799999999998
# Labels: [1]
# Inference time (ms): 20.96
# Labels: [1]
# Inference time (ms): 21.3066
# Labels: [1]
# Inference time (ms): 20.9132
# Labels: [1]
# Inference time (ms): 21.3425
# Labels: [1]
# Inference time (ms): 21.0622
# Labels: [1]
# Inference time (ms): 20.7255
# Labels: [1]
# Inference time (ms): 21.0016
# Labels: [1]
# Inference time (ms): 21.171100000000003
# Labels: [1]
# Inference time (ms): 23.5086
# Labels: [1]
# Inference time (ms): 20.6567
# Labels: [1]
# Inference time (ms): 20.6967
# Labels: [1]
# Inference time (ms): 21.0795
# Labels: [1]
# Inference time (ms): 21.3264
# Labels: [1]
# Inference time (ms): 20.3856
# Labels: [1]
# Inference time (ms): 20.586
# Labels: [1]
# Inference time (ms): 21.4399
# Labels: [1]
# Inference time (ms): 22.623
# Labels: [1]
# Inference time (ms): 20.7795
# Labels: [1]
# Inference time (ms): 23.2213
# Labels: [1]
# Inference time (ms): 20.5395
# Labels: [1]
# Inference time (ms): 20.6725
# Labels: [1]
# Inference time (ms): 21.118399999999998
# Labels: [1]
# Inference time (ms): 21.0769
# Labels: [1]
# Inference time (ms): 21.643099999999997
# Labels: [1]
# Inference time (ms): 24.818900000000003
# Labels: [1]
# Inference time (ms): 25.8231
# Labels: [1]
# Inference time (ms): 22.134600000000002
# Labels: [1]
# Inference time (ms): 22.9573
# Labels: [1]
# Inference time (ms): 22.6482
# Labels: [1]
# Inference time (ms): 21.8467
# Labels: [1]
# Inference time (ms): 23.596
# Labels: [1]
# Inference time (ms): 27.749
# Labels: [1]
# Inference time (ms): 27.1223
# Labels: [1]
# Inference time (ms): 25.2107
# Labels: [1]
# Inference time (ms): 22.8037
# Labels: [1]
# Inference time (ms): 25.9677
# Labels: [1]
# Inference time (ms): 26.3003
# Labels: [1]
# Inference time (ms): 24.2538
# Labels: [1]
# Inference time (ms): 30.287100000000002
# Labels: [1]
# Inference time (ms): 32.0678
# Labels: [1]
# Inference time (ms): 24.0731
# Labels: [1]
# Inference time (ms): 28.336299999999998
# Labels: [1]
# Inference time (ms): 21.0967
# Labels: [1]
# Inference time (ms): 20.973200000000002
# Labels: [1]
# Inference time (ms): 21.0178
# Labels: [1]
# Inference time (ms): 20.6539
# Labels: [1]
# Inference time (ms): 21.0134
# Labels: [1]
# Inference time (ms): 21.3017
# Labels: [1]
# Inference time (ms): 23.7536
# Labels: [1]
# Inference time (ms): 24.2815
# Labels: [1]
# Inference time (ms): 21.6623
# Labels: [1]
# Inference time (ms): 22.5554
# Labels: [1]
# Inference time (ms): 24.998
# Labels: [1]
# Inference time (ms): 21.919500000000003
# Labels: [1]
# Inference time (ms): 21.078
# Labels: [1]
# Inference time (ms): 21.3577
# Labels: [1]
# Inference time (ms): 21.9427
# Labels: [1]
# Inference time (ms): 23.0159
# Labels: [1]
# Inference time (ms): 25.1656
# Labels: [1]
# Inference time (ms): 21.5727
# Labels: [1]
# Inference time (ms): 21.3843
# Labels: [1]
# Inference time (ms): 21.205499999999997
# Labels: [1]
# Inference time (ms): 23.5243
# Labels: [1]
# Inference time (ms): 21.353199999999998
# Labels: [1]
# Inference time (ms): 21.876900000000003
# Labels: [1]
# Inference time (ms): 22.5482
# Labels: [1]
# Inference time (ms): 21.2025
# Labels: [1]
# Inference time (ms): 21.6787
# Labels: [1]
# Inference time (ms): 20.9098
# Labels: [1]
# Inference time (ms): 21.7395
# Labels: [1]
# Inference time (ms): 20.9274
# Labels: [1]
# Inference time (ms): 21.3028
# Labels: [1]
# Inference time (ms): 21.001700000000003
# Labels: [1]
# Inference time (ms): 20.8686
# Labels: [1]
# Inference time (ms): 24.257
# Labels: [1]
# Inference time (ms): 20.8588
# Labels: [1]
# Inference time (ms): 21.964199999999998
# Labels: [1]
# Inference time (ms): 22.202800000000003
# Labels: [1]
# Inference time (ms): 21.4863
# Labels: [1]
# Inference time (ms): 21.1005
# Labels: [1]
# Inference time (ms): 20.2293
# Labels: [1]
# Inference time (ms): 20.910899999999998
# Labels: [1]
# Inference time (ms): 21.0127
# Labels: [1]
# Inference time (ms): 20.831200000000003
# Labels: [1]
# Inference time (ms): 21.1317
# Labels: [1]
# Inference time (ms): 22.1098
# Labels: [1]
# Inference time (ms): 21.7267
# Labels: [1]
# Inference time (ms): 20.4739
# Labels: [1]
# Inference time (ms): 25.9374
# Labels: [1]
# Inference time (ms): 21.9844
